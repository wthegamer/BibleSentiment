# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                transcripts
# John     Title: The Gospel of John for Readers Editor: ...
# Luke     Title: The Gospel of Luke for Readers Editor: ...
# Mark     Title: The Gospel of Mark for Readers Editor: ...
# Matthew  Title: The Gospel of Matthew for Readers Edito...

# %%
# Extract only John's gospel
john_text = data.transcripts.loc['John']
john_text[:200]
# Out:
# 'Title: The Gospel of John for Readers Editor: Lightheart Release date: May 1, 2004 [eBook #5656]\r\n                Most recently updated: August 21, 2012 Language: English Copyright (C) 2002 by Lighthe'

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for John's gospel, take a look at it
john_dict = markov_chain(john_text)
john_dict
# Out:
# {'Title:': ['The'],
#  'The': ['Gospel',
#   'Gospel',
#   'Practice',
#   'way',
#   'gospel',
#   'Gospel',
#   'Gospel',
#   'same',
#   'light',
#   'only',
#   'next',
#   'two',
#   'passover',
#   'zeal',
#   'same',
#   'Father',
#   'Jews',
#   'woman',
#   'water',
#   'woman',
#   'woman',
#   'woman',
#   'woman',
#   'woman',
#   'man',
#   'impotent\r\nman',
#   'Jews',
#   'Son',
#   'hour',
#   'Father\r\nHimself',
#   'passover,\r\na',
#   'day',
#   'Jews',
#   'Jews',
#   'living',
#   'flesh\r\nprofiteth',
#   'words',
#   'world',
#   'Jews',
#   'people',
#   'Pharisees',
#   'Holy',
#   'officers',
#   'Pharisees',
#   'Father',
#   'same',
#   'servant',
#   'Jews',
#   'night',
#   'neighbours',
#   'man',
#   'sheep',
#   'good',
#   'hireling',
#   'Father',
#   'Jews',
#   'Master',
#   'chief',
#   'house',
#   'chief',
#   'people',
#   'Pharisees',
#   'people',
#   'people',
#   'Son',
#   'devil',
#   'servant',
#   'words',
#   'word',
#   'Comforter,',
#   'servant',
#   'servant',
#   'world',
#   "servant's",
#   'cup\r\nwhich',
#   'high',
#   'Jews',
#   'soldiers\r\nplatted',
#   'Jews',
#   'chief',
#   'writing',
#   'King',
#   'King',
#   'Jews',
#   'napkin',
#   'other',
#   'disciples',
#   'other',
#   'Gospel'],
#  'Gospel': ['of', 'of', 'is', 'of', 'of', 'of'],
#  'of': ['John',
#   'John',
#   'Him.',
#   'the',
#   'God.',
#   'John',
#   'love.',
#   'John',
#   'love.',
#   'John',
#   'men.',
#   'the',
#   'that',
#   'God,',
#   'blood,',
#   'the',
#   'the',
#   'man,',
#   'God.',
#   'the',
#   'the',
#   'grace',
#   'Him',
#   'whom',
#   'His',
#   'the',
#   'John,',
#   'thyself?',
#   'one',
#   'God',
#   'the',
#   'whom',
#   'God.',
#   'his',
#   'God!',
#   'the',
#   'Jona.',
#   'Bethsaida,',
#   'Andrew',
#   'Nazareth,\r\nthe',
#   'Joseph.',
#   'Nazareth?',
#   'him,',
#   'God.',
#   'Israel.',
#   'God',
#   'man.',
#   'Galilee.',
#   'Jesus',
#   'Jesus',
#   'stone,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'miracles',
#   'Galilee.',
#   'money',
#   'small',
#   'the',
#   'merchandise.',
#   'thine',
#   'the',
#   'His',
#   'the\r\nJews.',
#   'God.',
#   'the',
#   'God.',
#   'the',
#   'the',
#   'Israel',
#   'heavenly',
#   'man.',
#   'man',
#   'the',
#   'God.',
#   "John's",
#   'the',
#   'the',
#   'the',
#   'the',
#   'God\r\nbecause',
#   'God',
#   'Samaria',
#   'ground',
#   'Samaria',
#   'me,\r\na',
#   'Samaria?',
#   'God,',
#   'Him\r\nand',
#   'this',
#   'the',
#   'the\r\nJews.',
#   'the',
#   'Him',
#   'the',
#   'that',
#   'His\r\nown',
#   'thy\r\nsaying',
#   'the',
#   'Galilee',
#   'Judaea',
#   'the',
#   'impotent',
#   'blind,',
#   'the',
#   'Himself',
#   'God.',
#   'man.',
#   'life.',
#   'damnation.',
#   'myself',
#   'the',
#   'myself,',
#   'me;',
#   'me.',
#   'me.',
#   'another',
#   'me.',
#   'Galilee,',
#   'Tiberias.',
#   'the',
#   'bread',
#   'His',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'man',
#   'God,',
#   'God',
#   'life.',
#   'Him',
#   'all',
#   'Him',
#   'Joseph,\r\nwhose',
#   'God.',
#   'the',
#   'God.',
#   'life.',
#   'this',
#   'the',
#   'the',
#   'man,',
#   'this',
#   'His',
#   'man\r\nascend',
#   'you',
#   'my',
#   'His\r\nfollowers',
#   'eternal\r\nlife.',
#   'you',
#   'Judas',
#   'Simon,\r\nfor',
#   'that',
#   'Him',
#   'the',
#   'the',
#   'God',
#   'myself.',
#   'himself',
#   'you',
#   'Moses,',
#   'the',
#   'Moses',
#   'them',
#   'myself',
#   'the',
#   'saying',
#   'the',
#   'his',
#   'living',
#   'the',
#   'the',
#   'Galilee?',
#   'the',
#   'David',
#   'Bethlehem,',
#   'Him.',
#   'them',
#   'the',
#   'the',
#   'them,)',
#   'Galilee?',
#   'Galilee,\r\nariseth',
#   'Olives.',
#   'the',
#   'Thyself.',
#   'myself,',
#   'two',
#   'myself.',
#   'me.',
#   'this',
#   'this',
#   'man\r\nthen',
#   'myself.',
#   'sin.',
#   'God.',
#   'your',
#   'fornication;',
#   'myself,',
#   'Him',
#   'your',
#   'your',
#   'all',
#   'you',
#   'sin?',
#   'God',
#   'God.',
#   'death.',
#   'the',
#   'them,\r\nand',
#   'God',
#   'Him',
#   'the\r\nworld.',
#   'the',
#   'Siloam',
#   'Siloam',
#   'the',
#   'God',
#   'He',
#   'age.',
#   'the',
#   'age;',
#   'God,\r\nand',
#   'one',
#   'God',
#   'God?',
#   'the',
#   'the\r\nsheep.',
#   'strangers.',
#   'the',
#   'this',
#   'my',
#   'them',
#   'Him',
#   'the',
#   'the',
#   'me.',
#   'my',
#   'my\r\nhand.',
#   'my',
#   'those',
#   'God',
#   'Him',
#   'my',
#   'their\r\nhand',
#   'this',
#   'God,',
#   'God',
#   'this',
#   'sleep.',
#   'death',
#   'taking',
#   'the',
#   'God,',
#   'God,\r\nwhich',
#   'them',
#   'the',
#   'him',
#   'God?',
#   'the',
#   'them',
#   'them,',
#   'himself,',
#   'the',
#   'those',
#   'very',
#   'spikenard',
#   'the',
#   'His',
#   'the',
#   'the',
#   'palm',
#   'Israel',
#   'the',
#   'Sion.',
#   'Him,',
#   'his',
#   'them',
#   'Galilee,\r\nand',
#   'man',
#   'wheat',
#   'me,',
#   'this',
#   'this',
#   'the',
#   'man',
#   'man?',
#   'light.',
#   'Esaias',
#   'the',
#   'Him.',
#   'men',
#   'myself,',
#   'the',
#   'the',
#   'this',
#   'Judas\r\nIscariot,',
#   'all',
#   'you.',
#   'you',
#   'whom',
#   'His',
#   'Simon.',
#   'for',
#   'man\r\nglorified,',
#   'myself\r\nbut',
#   'the',
#   'truth',
#   'my\r\nFather.',
#   'this',
#   'itself',
#   'my',
#   'the',
#   'the\r\nworld,',
#   'the',
#   'the',
#   'sin.',
#   'truth',
#   'me.',
#   'the',
#   'them.',
#   'you',
#   'sin,',
#   'judgment.',
#   'this',
#   'truth',
#   'Himself.',
#   'His',
#   'that',
#   'the',
#   'her',
#   'good\r\ncheer.',
#   'the',
#   'them',
#   'perdition\r\nthat',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'men',
#   'Nazareth.',
#   'the',
#   'the',
#   'this',
#   'His',
#   'His\r\ndoctrine.',
#   'the',
#   'his\r\nhand,',
#   'the',
#   'His',
#   'the',
#   'judgment.',
#   'Jesus',
#   'what',
#   'the',
#   'thyself,',
#   'me?',
#   'this',
#   'the',
#   'the',
#   'thorns',
#   'the',
#   'thorns',
#   'God.',
#   'the',
#   'a',
#   'Nazareth',
#   'the',
#   'the',
#   'the',
#   'the\r\nJews.',
#   'Jesus',
#   'Cleophas,',
#   'vinegar.',
#   'the',
#   'the',
#   'the',
#   'Him',
#   'Arimathaea,',
#   'the',
#   'Jesus,',
#   'about',
#   'myrrh\r\nand',
#   'Jesus,',
#   'the',
#   'the',
#   'the',
#   'Jesus',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'His',
#   'God;',
#   'Tiberias.',
#   'Cana',
#   'His',
#   'the',
#   'coals',
#   'great',
#   'the',
#   'Jonas,\r\nlovest',
#   'Jonas,',
#   'Jonas,',
#   'these',
#   'Project',
#   'John'],
#  'John': ['for',
#   'for',
#   'is',
#   'for',
#   '1.',
#   'was\r\nnot',
#   'bore',
#   'answered',
#   'was',
#   'bore',
#   'and',
#   'speak',
#   'speak',
#   'also',
#   'was',
#   'and',
#   'answered',
#   'at',
#   'spoke',
#   'for'],
#  'for': ['Readers',
#   'Readers',
#   'our',
#   'Readers',
#   'easy',
#   'grace.',
#   'a',
#   'thou\r\nhast',
#   'the',
#   'the\r\nmoving',
#   'thee',
#   'what',
#   'a\r\nseason,',
#   'the',
#   'every',
#   'Him.',
#   'the',
#   'that',
#   'God',
#   'ever.',
#   'the',
#   'fear',
#   'I',
#   'I',
#   'it.',
#   'the\r\nsheep.',
#   'the',
#   'the',
#   'these',
#   'which',
#   'the',
#   'your',
#   'thee.',
#   'he',
#   'this',
#   'the',
#   'that',
#   'that\r\nnation',
#   'Jesus,',
#   'its',
#   'the',
#   "Jesus'\r\nsake",
#   'the',
#   'it',
#   'your',
#   'he',
#   'He',
#   'so',
#   'what',
#   'the',
#   'another.',
#   'Thy',
#   'my',
#   'you.',
#   'you,',
#   'the\r\nvery',
#   'He',
#   'my',
#   'the',
#   'without',
#   'his\r\nfriends.',
#   'all',
#   'my',
#   'you',
#   'He',
#   'you.',
#   'them.',
#   'the',
#   'them',
#   'their',
#   'these',
#   'them',
#   'Thou',
#   'Jesus\r\nofttimes',
#   'he',
#   'the',
#   'us\r\nto',
#   'the',
#   'whose',
#   'my\r\nvesture',
#   'the',
#   'fear',
#   'burial.',
#   'I\r\nam',
#   'fear',
#   'the',
#   'Readers,'],
#  'Readers': ['Editor:', "Editor's", 'is'],
#  'Editor:': ['Lightheart'],
#  'Lightheart': ['Release',
#   'PracticeGodsPresence.com',
#   'PracticeGodsPresence.com'],
#  'Release': ['date:'],
#  'date:': ['May'],
#  'May': ['1,', 'it\r\nhelp', 'they'],
#  '1,': ['2004'],
#  '2004': ['[eBook'],
#  '[eBook': ['#5656]\r\n'],
#  '#5656]\r\n': [''],
#  '': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Most',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'In',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Three',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'There',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'When',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'After',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'After',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'After',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Jesus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Jesus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Verily,',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Now',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Six',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'It',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Let',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'I',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'These',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'These',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'When',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Then',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'On',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'After'],
#  'Most': ['recently'],
#  'recently': ['updated:'],
#  'updated:': ['August'],
#  'August': ['21,', '2002'],
#  '21,': ['2012'],
#  '2012': ['Language:'],
#  'Language:': ['English'],
#  'English': ['Copyright'],
#  'Copyright': ['(C)'],
#  '(C)': ['2002'],
#  '2002': ['by', 'The'],
#  'by': ['Lightheart.',
#   'reading',
#   'that',
#   'Him.',
#   'Him,',
#   'Moses,',
#   'Jesus',
#   'the',
#   'night',
#   'the',
#   'force',
#   'the',
#   'the',
#   'me.',
#   'night,',
#   'their',
#   'one,',
#   'a',
#   'what',
#   'the\r\ndoor',
#   'the',
#   'name',
#   'me',
#   'my',
#   'this',
#   'I',
#   'and',
#   'me.',
#   'the',
#   'struck',
#   'many',
#   'the',
#   'itself.',
#   'what',
#   'Lightheart'],
#  'Lightheart.': ['The'],
#  "Editor's": ['Preface'],
#  'Preface': ['"We'],
#  '"We': ['must'],
#  'must': ['know',
#   'often\r\nthink',
#   'have',
#   'be',
#   'the',
#   'increase,',
#   'decrease.',
#   'worship\r\nHim',
#   'work\r\nthe',
#   'bring',
#   'be',
#   'rise'],
#  'know': ['before',
#   'God,',
#   'God',
#   'and',
#   'and',
#   'not.',
#   'that\r\nThou',
#   'not',
#   'what',
#   'that',
#   'not',
#   'that',
#   'that',
#   'you',
#   'indeed\r\nthat',
#   'this',
#   'me',
#   'whence',
#   'not.',
#   'Him',
#   'what',
#   'whence',
#   'me',
#   'that',
#   'the',
#   'that',
#   'that',
#   'Him',
#   'Him',
#   'Him',
#   'not.',
#   'that',
#   'not.',
#   'not.',
#   'that',
#   'not.',
#   'that',
#   'not',
#   'not',
#   'not',
#   'the',
#   'them',
#   'and',
#   'that',
#   'that',
#   'nothing',
#   'that',
#   'hereafter.',
#   'these',
#   'whom',
#   'that',
#   'not',
#   'the',
#   'Him.',
#   'Him',
#   'that',
#   'that',
#   'that',
#   'not',
#   'Thee',
#   'that',
#   'surely',
#   'that',
#   'what',
#   'that',
#   'not',
#   'not',
#   'that'],
#  'before': ['we',
#   'me',
#   'me',
#   'me.',
#   'Him.',
#   'my',
#   'me.',
#   'had',
#   'them',
#   'me',
#   'the',
#   'the',
#   'them,',
#   'the',
#   'it',
#   'the',
#   'it',
#   'the\r\nworld',
#   'the'],
#  'we': ['can',
#   'must',
#   'come',
#   'shall',
#   'must',
#   'beheld',
#   'may',
#   'know',
#   'know,\r\ntestify',
#   'have',
#   'worship',
#   'believe,',
#   'have',
#   'buy',
#   'do',
#   'might',
#   'may',
#   'know?',
#   'go?',
#   'know',
#   'shall',
#   'have',
#   'not',
#   'know',
#   'know',
#   'know',
#   'know',
#   'are',
#   'know',
#   'blind',
#   'stone',
#   'may',
#   'for',
#   'let',
#   'would',
#   'have',
#   'know',
#   'know',
#   'cannot',
#   'would',
#   'know',
#   'know'],
#  'can': ['love.',
#   'do',
#   'a',
#   'these',
#   'receive',
#   'do',
#   'of',
#   'ye',
#   'come',
#   'this',
#   'hear',
#   'come\r\nunto',
#   'work.',
#   'a',
#   'we',
#   'ye',
#   'do',
#   'take'],
#  'love.': ['In', 'And,', 'in', 'If\r\nye', 'These'],
#  'In': ['order',
#   'the',
#   'Him',
#   'the',
#   'the',
#   'them',
#   'the',
#   'Jerusalem',
#   'my',
#   'a',
#   'that',
#   'the',
#   'secret'],
#  'order': ['to', 'to'],
#  'to': ['know',
#   'love',
#   'know',
#   'His',
#   'know',
#   'allow',
#   'see',
#   'bear\r\nwitness',
#   'bear',
#   'them',
#   'become',
#   'ask',
#   'them',
#   'unloose.',
#   'Israel.',
#   'baptize',
#   'me,',
#   'Him,',
#   'Jesus.',
#   'Him',
#   'Capernaum,',
#   'Jerusalem',
#   'them',
#   'Jesus',
#   'heaven',
#   'condemn',
#   'the',
#   'the',
#   'Salim',
#   'John',
#   'whom',
#   'Him.',
#   'his',
#   'go',
#   'a',
#   'his',
#   'draw',
#   'buy',
#   'thee',
#   'drink,',
#   'draw',
#   'come\r\nhither',
#   'draw',
#   'worship.',
#   'worship',
#   'eat',
#   'another,',
#   'do',
#   'complete',
#   'harvest.',
#   'reap',
#   'tarry',
#   'Him',
#   'come',
#   'mend.',
#   'him,',
#   'put\r\nme',
#   'him',
#   'carry',
#   'slay',
#   'kill',
#   'the',
#   'have',
#   'execute',
#   'rejoice',
#   'complete',
#   'me',
#   'the',
#   'test',
#   'take',
#   'the',
#   'them\r\nthat',
#   'make',
#   'the',
#   'Capernaum',
#   'look',
#   'eat.',
#   'me',
#   'you',
#   'me.',
#   'me',
#   'do',
#   'me',
#   'me.',
#   'eat?',
#   'whom',
#   'kill',
#   'be',
#   'the',
#   'the',
#   'kill',
#   'kill',
#   'kill?',
#   'Him.',
#   'take',
#   'take',
#   'the',
#   'Jesus',
#   'Him',
#   'accuse',
#   'them,',
#   'the',
#   'you',
#   'say',
#   'judge\r\nof',
#   'the',
#   'them\r\nof',
#   'those',
#   'any',
#   'kill',
#   'see',
#   'cast',
#   'the',
#   'him,',
#   'the',
#   'him',
#   'Moses.',
#   'steal',
#   'take',
#   'you,',
#   'me,',
#   'stone',
#   'take',
#   'the',
#   'Jesus,',
#   'His',
#   'stone',
#   'them,',
#   'the\r\nextent',
#   'his',
#   'Martha',
#   'comfort',
#   'comfort',
#   'weep',
#   'Mary,',
#   'the',
#   'put',
#   'death.',
#   'the',
#   'Jerusalem',
#   'purify',
#   'the',
#   'Bethany',
#   'the',
#   'Jerusalem.',
#   'worship',
#   'Philip,',
#   'Him.',
#   'whom',
#   'judge',
#   'save',
#   'betray',
#   'Simon',
#   'him,',
#   'you?',
#   'wash',
#   'you.',
#   'him,',
#   'whom',
#   'Judas',
#   'him,',
#   'him.',
#   'the',
#   'prepare',
#   'abide\r\nwith',
#   'him.',
#   'the',
#   'your',
#   'you,',
#   'pass,',
#   'be',
#   'hide',
#   'pass',
#   'Him',
#   'you.',
#   'you.',
#   'my',
#   'say',
#   'come.',
#   'the',
#   'the',
#   'ask',
#   'the',
#   'you.',
#   'the',
#   'heaven\r\nand',
#   'as',
#   'do.',
#   'Thee,',
#   'Thee',
#   'Peter,',
#   'Caiaphas,',
#   'the',
#   'the',
#   'your',
#   'him,',
#   'death.',
#   'the',
#   'them,',
#   'you',
#   'die',
#   'crucify',
#   'release',
#   'be',
#   'the',
#   'Pilate,\r\nWrite',
#   'eachother,',
#   'the',
#   'His',
#   'Jesus',
#   'Jesus\r\nby',
#   'their',
#   'her,',
#   'be',
#   'say,',
#   'my',
#   'my',
#   'my',
#   'them',
#   'Thomas,',
#   'the\r\ndisciples.',
#   'him,',
#   'draw',
#   'them,',
#   'His',
#   'Simon',
#   'him\r\na',
#   'him',
#   'Jesus,',
#   'thee?',
#   'thee?'],
#  'God,': ['we',
#   'and\r\nthe',
#   'even',
#   'and',
#   'that\r\nye',
#   'that',
#   'that',
#   'God',
#   'and',
#   'and'],
#  'often\r\nthink': ['of'],
#  'Him.': ['And',
#   'The',
#   'Without',
#   'And',
#   'I',
#   'After',
#   'Jesus',
#   'John',
#   'He',
#   'God',
#   'In',
#   'Verily,',
#   'Now',
#   'Then',
#   'And',
#   '7.',
#   'Now',
#   'Then',
#   'Some',
#   'Did',
#   'Do',
#   'Jesus',
#   'Some',
#   'Then',
#   'He',
#   'But\r\nJesus',
#   'They',
#   'As',
#   'Jesus',
#   'But',
#   'But',
#   'Then',
#   'Jesus',
#   'Therefore',
#   'When',
#   'Now\r\nJesus',
#   'Some',
#   'But',
#   '12.',
#   'Then',
#   'The',
#   'There',
#   'Jesus',
#   'Thus\r\nit',
#   'Nevertheless',
#   'But',
#   'Jesus',
#   'After',
#   'If',
#   'If',
#   'Philip',
#   'But',
#   'This',
#   'Then',
#   'Pilate',
#   'The',
#   'Away',
#   'Crucify',
#   'Pilate',
#   'But',
#   'Peter'],
#  'And': ['when',
#   'the',
#   'we',
#   'this',
#   'he',
#   'they',
#   'he',
#   'they',
#   'Nathanael',
#   'He',
#   'both',
#   'when',
#   'when',
#   'John',
#   'herein',
#   'many',
#   'He',
#   'he',
#   'he\r\nthat',
#   'He',
#   'He',
#   'my',
#   'a',
#   'Jesus',
#   'they',
#   'they',
#   'Jesus',
#   'he',
#   'him',
#   'this',
#   'I\r\nwill',
#   'they',
#   'I',
#   'the',
#   'He',
#   'the',
#   'the',
#   'where',
#   'every',
#   'yet,',
#   'He',
#   'Jesus',
#   'he',
#   'there',
#   'they\r\nasked',
#   'they',
#   'Jesus',
#   'he',
#   'he',
#   'when',
#   'I',
#   'many',
#   'I',
#   'whosoever\r\nliveth',
#   'when',
#   'some',
#   'Jesus',
#   'I',
#   'when',
#   'this',
#   'Jesus,',
#   'I,',
#   'to',
#   'he',
#   'ye',
#   'if',
#   'whither',
#   'greater',
#   'he',
#   'now',
#   'ye',
#   'these',
#   'none',
#   'He',
#   'in',
#   'your',
#   'ye',
#   'I',
#   'now,',
#   'I',
#   'for',
#   'the',
#   'I',
#   'Judas',
#   'they',
#   'they',
#   'they\r\ntook',
#   'from',
#   'in',
#   'when',
#   'many',
#   'He',
#   'there'],
#  'when': ['we',
#   'the',
#   'thou',
#   'they',
#   'men',
#   'He\r\nhad',
#   'they',
#   'ye',
#   'the',
#   'the',
#   'the',
#   'the',
#   'they',
#   'camest',
#   'they\r\nheard',
#   'they',
#   'Jesus',
#   'he',
#   'she',
#   'Mary',
#   'He',
#   'He',
#   'Jesus',
#   'He',
#   'he',
#   'it',
#   'I\r\nhave',
#   'it',
#   'whoever',
#   'the',
#   'the',
#   'she',
#   'He\r\nspoke',
#   'they',
#   'it',
#   'the',
#   'He\r\nhad',
#   'they',
#   'thou'],
#  'come': ['to',
#   'baptizing',
#   'from',
#   'into',
#   'to',
#   'He',
#   'unto',
#   'into',
#   'down',
#   'before',
#   'out',
#   'another',
#   'unto',
#   'into\r\ncondemnation',
#   'forth.',
#   'to',
#   'in',
#   'in',
#   'unto\r\nHim,',
#   'into',
#   'and',
#   'to\r\nthem.',
#   'to',
#   'to',
#   'but',
#   'of',
#   'unto',
#   'out',
#   'into',
#   'that\r\nthey',
#   'into',
#   'and',
#   'into',
#   'and',
#   'to',
#   'for',
#   'upon',
#   'as',
#   'and',
#   'again',
#   'to\r\nyou.',
#   'and',
#   'to',
#   'into',
#   'to',
#   'I',
#   'upon',
#   'what',
#   'what'],
#  'love': ['Him,',
#   'Him',
#   'Him.',
#   'story,',
#   'me',
#   'me',
#   'one',
#   'me,',
#   'him',
#   'me,',
#   'him.',
#   'as',
#   'one',
#   'hath',
#   'one',
#   'his',
#   'wherewith',
#   'thee.',
#   'thee.',
#   'Thee.'],
#  'Him,': ['we',
#   'and',
#   'to',
#   'this',
#   'and',
#   'Rabbi,',
#   'Whence',
#   'They',
#   'What',
#   'Rabbi,',
#   'How',
#   'How',
#   'How',
#   'Sir,',
#   'Sir,',
#   'I',
#   'saying,',
#   'they',
#   'Sir,',
#   'Two',
#   'There',
#   'What',
#   'Lord,',
#   'may',
#   'Lord,',
#   'no',
#   'that',
#   'He',
#   'Thou',
#   'Where',
#   'Who',
#   'If',
#   'We',
#   'Abraham',
#   'We',
#   'Thou',
#   'Master,',
#   'Are',
#   'saying,',
#   'and',
#   'I',
#   'Yes,',
#   'she',
#   'Lord,',
#   'Lord,\r\ncome',
#   'Why',
#   'and',
#   'and',
#   'We',
#   'Lord,',
#   'Thou',
#   'Lord,',
#   'Lord,\r\nwho',
#   'God\r\nshall',
#   'Lord,',
#   'Lord,',
#   'Lord,',
#   'Lord,',
#   'Lord,',
#   'and\r\nsaid',
#   'Lo,',
#   'also',
#   'went',
#   'Jesus',
#   'stood',
#   'and',
#   'Art',
#   'Art',
#   'Speakest',
#   'Sir,\r\nif',
#   'my',
#   'No.',
#   'Who',
#   'Yea,',
#   'Lord,'],
#  'shall': ['then',
#   'see',
#   'ye',
#   'give\r\nhim',
#   'never',
#   'be',
#   'not',
#   'hear',
#   'live.',
#   'hear',
#   'come',
#   'come',
#   'ye',
#   'we',
#   'give',
#   'we',
#   'never',
#   'never\r\nthirst.',
#   'come',
#   'be',
#   'live',
#   'live',
#   'see',
#   'we',
#   'know\r\nwhether',
#   'seek',
#   'not',
#   'not',
#   'seek',
#   'not',
#   'flow\r\nrivers',
#   'not',
#   'have',
#   'seek',
#   'die',
#   'die',
#   'die',
#   'ye',
#   'know',
#   'be',
#   'make',
#   'be',
#   'never',
#   'speak\r\nfor',
#   'be',
#   'go',
#   'be',
#   'never',
#   'any',
#   'do',
#   'rise',
#   'rise',
#   'he',
#   'never',
#   'come',
#   'lose',
#   'my\r\nservant',
#   'I',
#   'judge',
#   'betray',
#   'give',
#   'seek',
#   'all',
#   'also',
#   'ask',
#   'give',
#   'be',
#   'see',
#   'know',
#   'be',
#   'teach',
#   'ask',
#   'be',
#   'ye',
#   'abide',
#   'ask',
#   'testify',
#   'bear',
#   'put',
#   'not',
#   'hear,\r\nthat',
#   'He',
#   'glorify\r\nme',
#   'receive',
#   'show',
#   'take',
#   'show',
#   'not',
#   'see',
#   'not',
#   'see',
#   'not',
#   'see',
#   'weep',
#   'rejoice.',
#   'be',
#   'be',
#   'rejoice.',
#   'need',
#   'ask\r\nthe',
#   'receive',
#   'no',
#   'show',
#   'ask',
#   'be',
#   'leave',
#   'have',
#   'I',
#   'be.',
#   'not',
#   'look',
#   'see',
#   'find',
#   'gird',
#   'this',
#   'not'],
#  'then': ['also',
#   'if',
#   'that',
#   'left',
#   'murmured',
#   'that',
#   'went',
#   'I',
#   'doth',
#   'they\r\nremembered',
#   'departed',
#   'wiped',
#   'thou',
#   'saith',
#   'asked',
#   'went',
#   'read',
#   'of',
#   'returned'],
#  'also': ['think\r\nof',
#   'totally',
#   'was\r\nbaptizing',
#   'were\r\nat',
#   'that',
#   'doeth\r\nthe',
#   'because',
#   'said',
#   'go',
#   'may',
#   'to',
#   'deceived?',
#   'of',
#   'written',
#   'be\r\nHis',
#   'I',
#   'go',
#   'weeping,',
#   'He',
#   'see',
#   'put',
#   'the',
#   'shall',
#   'said,',
#   'ought',
#   'glorify',
#   'do',
#   'do.',
#   'persecute',
#   'shall',
#   'sent',
#   'might',
#   'for',
#   'may',
#   'knew',
#   'one',
#   'one',
#   'go',
#   'many'],
#  'think\r\nof': ['Him'],
#  'Him': ['often,',
#   'as',
#   'was',
#   'was\r\nlife;',
#   'might',
#   'not.',
#   'and',
#   'not',
#   'that',
#   'and',
#   'is',
#   'the',
#   'must',
#   'ought',
#   'that',
#   'for',
#   'to',
#   'ourselves',
#   'after',
#   'and\r\nbesought',
#   'to',
#   'because',
#   'all',
#   'greater',
#   'that',
#   'authority',
#   'because',
#   'by',
#   'a',
#   'into',
#   'whom',
#   'that',
#   'that',
#   'because',
#   'no',
#   'at',
#   'for',
#   'for',
#   'and',
#   'but',
#   'because',
#   'and',
#   'come',
#   'would',
#   'a',
#   'becuase',
#   'who',
#   'and,',
#   'not,',
#   'and',
#   'that',
#   'and',
#   'that',
#   'and\r\nsaid,',
#   'whom',
#   'but',
#   'there.',
#   'but',
#   'thus',
#   'to',
#   'a',
#   'when',
#   'because',
#   'lest',
#   'that',
#   'that',
#   'that',
#   'in',
#   'and',
#   'not',
#   'for',
#   'that',
#   'that\r\nsent',
#   'to',
#   'power',
#   'sent',
#   'and',
#   'no',
#   'scourged.',
#   'a\r\npurple',
#   'with',
#   'they',
#   'and',
#   'but',
#   'unto',
#   'away.',
#   'and',
#   'shall',
#   'whom',
#   'to',
#   'hence,',
#   'and',
#   'away.'],
#  'often,': ['for'],
#  'our': ['heart',
#   'treasure',
#   'witness.',
#   'father',
#   'law',
#   'father.',
#   'son',
#   'place',
#   'report?',
#   'law,'],
#  'heart': ['will', 'was', 'was', 'and', 'of', 'be', 'be', 'shall'],
#  'will': ['be',
#   'of',
#   'of',
#   'raise',
#   'tell\r\nus',
#   'of',
#   'not',
#   'show',
#   'but',
#   'not',
#   'receive.',
#   'accuse',
#   'of',
#   'that',
#   'of',
#   'raise',
#   'give',
#   'give',
#   'raise',
#   'do',
#   'he',
#   'He',
#   'He\r\ngo',
#   'not',
#   'flee\r\nbecause',
#   'give',
#   'believe',
#   'my',
#   'draw',
#   'come',
#   'do,',
#   'do\r\nit.',
#   'ask',
#   'not',
#   'not',
#   'come',
#   'love',
#   'keep',
#   'love',
#   'send',
#   'bring',
#   'not',
#   'wither.',
#   'and',
#   'also',
#   'keep',
#   'they',
#   'think',
#   'they',
#   'not',
#   'reprove',
#   'guide',
#   'show',
#   'see',
#   'give',
#   'pray',
#   'that',
#   'declare',
#   'not',
#   'that'],
#  'be': ['with',
#   'not',
#   'made',
#   'called',
#   'with',
#   'born',
#   'born\r\nwhen',
#   'born\r\nof',
#   'born',
#   'lifted',
#   'saved.',
#   'reproved.',
#   'shown',
#   'given\r\nhim',
#   'a',
#   'made',
#   'wasted.',
#   'all',
#   'known',
#   'of',
#   'broken,',
#   'stoned.',
#   'made',
#   'free',
#   'made',
#   'put',
#   'a',
#   'a',
#   'made',
#   'saved,',
#   'One',
#   'the',
#   'broken;',
#   'glorified.',
#   'cast',
#   'lifted',
#   'lifted',
#   'the',
#   'fulfilled,',
#   'converted,\r\nand',
#   'put',
#   'fulfilled,',
#   'of\r\nwhom',
#   'glorified',
#   'troubled.',
#   'also.',
#   'in',
#   'loved',
#   'troubled,\r\nneither',
#   'afraid.',
#   'burned.',
#   'done',
#   'my',
#   'full.',
#   'innocent',
#   'fulfilled\r\nthat',
#   'sorrowful',
#   'turned\r\ninto',
#   'full.',
#   'scattered,',
#   'of',
#   'one',
#   'fulfilled.',
#   'sanctified',
#   'One,',
#   'One',
#   'One,',
#   'made',
#   'with',
#   'in',
#   'delivered',
#   'crucified.',
#   'fulfilled,',
#   'broken',
#   'taken',
#   'fulfilled:',
#   'broken.',
#   'the',
#   'unto',
#   'unto',
#   'unto\r\nyou.',
#   'old,',
#   'written.'],
#  'with': ['our',
#   'God,',
#   'God.',
#   'water',
#   'water.',
#   'water',
#   'the',
#   'Him',
#   'water.',
#   'Him.',
#   'them',
#   'thee\r\nbeyond',
#   'the',
#   'and',
#   'the\r\nwoman.',
#   'her?',
#   'five\r\nporches',
#   'God.',
#   'His',
#   'the',
#   'the',
#   'His',
#   'Him',
#   'you',
#   'His',
#   'the',
#   'me.',
#   'my',
#   'your\r\nfather.',
#   'the',
#   'thee.',
#   'Him\r\nheard',
#   'Him.',
#   'her',
#   'her',
#   'a',
#   'a',
#   'His',
#   'Him.',
#   'her',
#   'you;\r\nbut',
#   'Him',
#   'their',
#   'their',
#   'the',
#   'me.',
#   'me',
#   'you.',
#   'you',
#   'him.',
#   'you.',
#   'you.',
#   'you,',
#   'me',
#   'you.',
#   'me.',
#   'Thine',
#   'the',
#   'Thee',
#   'them',
#   'me',
#   'His\r\ndisciples',
#   'His',
#   'lanterns',
#   'both\r\nofficers',
#   'the',
#   'Him?',
#   'the',
#   'their\r\nhands.',
#   'Him.',
#   'Him.',
#   'Him.',
#   'a',
#   'the',
#   'the\r\nlinen',
#   'them',
#   'them.',
#   'thee.',
#   'the'],
#  'treasure': ['"'],
#  '"': ['…'],
#  '…': ["Brother\r\nLawrence's"],
#  "Brother\r\nLawrence's": ['The'],
#  'Practice': ['of'],
#  'the': ['Presence',
#   'gospels.',
#   'new',
#   'gospel',
#   'KJV',
#   'exquisite',
#   'beginning',
#   'Word,',
#   'Word',
#   'beginning',
#   'life',
#   'light',
#   'darkness',
#   'Light',
#   'world.',
#   'world,',
#   'world',
#   'world',
#   'sons',
#   'flesh,',
#   'will',
#   'Word\r\nwas',
#   'glory\r\nas',
#   'only',
#   'Father,',
#   'Father,',
#   'record',
#   'Jews',
#   'Christ.',
#   'voice',
#   'wilderness,',
#   'way\r\nof',
#   'Lord,',
#   'prophet',
#   'Pharisees',
#   'Lamb',
#   'sin',
#   'world.',
#   'Spirit\r\ndescending',
#   'Spirit',
#   'Holy',
#   'Son',
#   'Lamb',
#   'tenth',
#   'two',
#   'messias,',
#   'Christ)',
#   'city',
#   'law',
#   'prophets',
#   'fig',
#   'Son',
#   'King',
#   'fig',
#   'angels',
#   'Son',
#   'marriage.',
#   'mother',
#   'servants,\r\nWhatsoever',
#   'manner',
#   'Jews,',
#   'waterpots',
#   'feast.',
#   'ruler',
#   'feast',
#   'water',
#   'servants',
#   'water',
#   'feast',
#   'bridegroom.',
#   'beginning',
#   'good',
#   'temple',
#   'temple\r\nand',
#   'tables.',
#   'Jews',
#   'temple',
#   'dead,',
#   'scripture',
#   'word\r\nwhich',
#   'passover',
#   'miracles',
#   'kingdom',
#   'second',
#   'Spirit',
#   'kingdom',
#   'flesh',
#   'Spirit\r\nis',
#   'sound',
#   'Spirit.',
#   'serpent',
#   'wilderness',
#   'Son',
#   'world\r\nthat',
#   'world',
#   'world',
#   'world,',
#   'only',
#   'condemnation:',
#   'world',
#   'light',
#   'light',
#   'light',
#   'land',
#   'Jews',
#   'bride',
#   'friend',
#   'bridegroom,',
#   "bridegroom's",
#   'earth',
#   'earth.',
#   'words',
#   'Spirit',
#   'Son',
#   'wrath',
#   'Lord',
#   'Pharisees',
#   'parcel',
#   'well.',
#   'sixth',
#   'city',
#   'Samaritans?',
#   'gift',
#   'well',
#   'water',
#   'place',
#   'hour',
#   'Father',
#   'hour',
#   'true',
#   'Father',
#   'Father',
#   'city',
#   'men,',
#   'things',
#   'Christ?',
#   'city',
#   'meanwhile',
#   'disciples',
#   'will',
#   'Samaritans',
#   'saying\r\nof',
#   'woman',
#   'woman,',
#   'Christ,',
#   'Saviour',
#   'world.',
#   'Galilaeans',
#   'feast',
#   'feast.',
#   'hour',
#   'son',
#   'fever',
#   'father',
#   'second',
#   'Jews.',
#   'sheep',
#   'water.',
#   'water.',
#   'water',
#   'pool.',
#   'man',
#   'sabbath',
#   'sabbath',
#   'multitude',
#   'temple',
#   'Jews',
#   'Jews',
#   'sabbath',
#   'Jews',
#   'more',
#   'sabbath',
#   'Father',
#   'Father',
#   'Son',
#   'Father',
#   'dead',
#   'Son',
#   'Father',
#   'Son.',
#   'Son,',
#   'Father.',
#   'Father',
#   'dead',
#   'voice',
#   'Father',
#   'Son',
#   'Son',
#   'hour',
#   'resurrection',
#   'Father',
#   'witness',
#   'truth.',
#   'works',
#   'Father',
#   'Father',
#   'scriptures.',
#   'love\r\nof',
#   'honour',
#   'Father.',
#   'sea',
#   'sea',
#   'miracles',
#   'Jews,',
#   'men',
#   'grass.',
#   'men,',
#   'loaves.',
#   'disciples,',
#   'disciples',
#   'same',
#   'fishes.',
#   'fragments',
#   'leftover',
#   'five',
#   'miracle',
#   'world.',
#   'sea',
#   'sea',
#   'force',
#   'boat.',
#   'boat\r\nand',
#   'land',
#   'people',
#   'other',
#   'sea\r\nsaw',
#   'one',
#   'place',
#   'Lord',
#   'other',
#   'sea,',
#   'miracles,',
#   'loaves',
#   'meat\r\nwhich',
#   'Son',
#   'Father',
#   'works\r\nof',
#   'work',
#   'desert;',
#   'true',
#   'bread',
#   'world.',
#   'bread',
#   'Father',
#   'will',
#   "Father's",
#   'last\r\nday.',
#   'will',
#   'Son,',
#   'last',
#   'bread',
#   'son',
#   'Father',
#   'last',
#   'prophets',
#   'Father,',
#   'Father',
#   'wilderness\r\nand',
#   'bread',
#   'living',
#   'bread\r\nthat',
#   'life',
#   'world.',
#   'flesh',
#   'Son',
#   'last',
#   'Father.',
#   'synagogue',
#   'Son',
#   'spirit',
#   'beginning',
#   'twelve,',
#   'words',
#   'Son',
#   'son',
#   'Jews',
#   "Jews'",
#   'works\r\nthat',
#   'world.',
#   'feast,',
#   'feast',
#   'people',
#   'people.',
#   'Jews.',
#   'midst',
#   'feast',
#   'temple',
#   'Jews',
#   'doctrine',
#   'law',
#   'law?',
#   'fathers)',
#   'sabbath',
#   'sabbath',
#   'rulers',
#   'very',
#   'people',
#   'people',
#   'Pharisees',
#   'chief',
#   'Jews',
#   'dispersed',
#   'Gentiles?',
#   'last',
#   'feast,',
#   'scripture',
#   'Spirit',
#   'people',
#   'Prophet.',
#   'Christ.',
#   'scripture',
#   'seed',
#   'town',
#   'people',
#   'officers',
#   'chief',
#   'Pharisees,',
#   'rulers',
#   'Pharisees',
#   'law',
#   'Mount',
#   'morning',
#   'temple',
#   'people',
#   'scribes',
#   'midst,',
#   'very',
#   'ground',
#   'ground.',
#   'eldest',
#   'last.',
#   'woman',
#   'midst.',
#   'woman,',
#   'light',
#   'world.',
#   'light',
#   'flesh.',
#   'Father',
#   'testimony',
#   'treasury',
#   'temple.',
#   'Jews,',
#   'beginning.',
#   'world',
#   'Father.',
#   'Son',
#   'truth',
#   'truth\r\nshall',
#   'servant',
#   'house',
#   'Son,',
#   'works\r\nof',
#   'truth\r\nwhich',
#   'deeds',
#   'devil,',
#   'lusts',
#   'beginning.',
#   'truth,\r\nbecause',
#   'father',
#   'truth,',
#   'Jews,',
#   'prophets.',
#   'prophets',
#   'temple,',
#   'midst',
#   'works',
#   'world,',
#   'light',
#   'ground,',
#   'eyes',
#   'blind',
#   'clay,\r\nand',
#   'pool',
#   'pool',
#   'Pharisees.',
#   'sabbath',
#   'clay',
#   'Pharisees',
#   'Pharisees,',
#   'sabbath',
#   'blind',
#   'Jews',
#   'Jews,\r\nfor',
#   'Jews',
#   'Christ,\r\nthat',
#   'synagogue.',
#   'man',
#   'praise:',
#   'world',
#   'eyes',
#   'Son',
#   'Pharisees',
#   'sheepfold,',
#   'door',
#   'shepherd',
#   'porter',
#   'sheep',
#   'voice',
#   'door',
#   'sheep.',
#   'sheep',
#   'door.',
#   'Good',
#   'shepherd,',
#   'wolf',
#   'sheep',
#   'sheep.',
#   'sheep.',
#   'Good',
#   'Father.',
#   'sheep.',
#   'words',
#   'eyes',
#   'blind?',
#   'feast',
#   'dedication.',
#   'temple',
#   'Jews',
#   'Christ,',
#   'word',
#   'scripture\r\ncannot',
#   'Father',
#   'world,',
#   'Son',
#   'works',
#   'works',
#   'Father',
#   'place',
#   'glory',
#   'Son',
#   'same',
#   'Jews',
#   'day?',
#   'light',
#   'night,',
#   'grave\r\nfour',
#   'Jews',
#   'house.',
#   'resurrection',
#   'last\r\nday.',
#   'resurrection,',
#   'life.',
#   'Christ,',
#   'Son',
#   'world.',
#   'town',
#   'house',
#   'grave',
#   'spirit',
#   'Jews,',
#   'eyes',
#   'blind,',
#   'grave.',
#   'stone.',
#   'sister',
#   'glory',
#   'stone',
#   'dead',
#   'Jews',
#   'things',
#   'Pharisees',
#   'chief',
#   'Romans',
#   'high',
#   'people',
#   'whole',
#   'children\r\nof',
#   'Jews',
#   'wilderness,',
#   "Jews'",
#   'country',
#   'passover',
#   'temple,',
#   'feast?',
#   'Pharisees',
#   'passover,',
#   'dead.',
#   'table',
#   'feet\r\nof',
#   'ointment.',
#   'poor?',
#   'poor',
#   'bag,',
#   'day\r\nof',
#   'poor',
#   'Jews',
#   'reason',
#   'Jews',
#   'next',
#   'feast',
#   'King',
#   'name',
#   'Lord.',
#   'dead,',
#   'people',
#   'world',
#   'Son',
#   'ground',
#   'judgment',
#   'prince',
#   'earth,',
#   'law',
#   'light\r\nwith',
#   'light',
#   'light,',
#   'children',
#   'saying',
#   'prophet',
#   'arm',
#   'Lord',
#   'chief',
#   'Pharisees',
#   'synagogue.',
#   'praise',
#   'praise',
#   'world',
#   'world',
#   'world.',
#   'last',
#   'Father',
#   'Father',
#   'feast',
#   'passover.',
#   'world,',
#   'heart',
#   'Father',
#   "disciples'",
#   'towel',
#   'sop',
#   'sop,',
#   'table',
#   'bag,',
#   'feast,',
#   'poor.',
#   'sop,',
#   'Son',
#   'Jews,',
#   'cock',
#   'way',
#   'way?',
#   'way,\r\nthe',
#   'life.',
#   'Father',
#   'Father',
#   'Father.',
#   'Father?',
#   'Father',
#   'Father',
#   'works.',
#   'Father',
#   'Father',
#   'works',
#   'Father',
#   'Son.',
#   'Father,',
#   'world',
#   'world',
#   'world?',
#   "Father's",
#   'Holy',
#   'Father',
#   'world',
#   'Father,',
#   'prince',
#   'world',
#   'Father',
#   'true',
#   'husbandman.',
#   'word',
#   'branch',
#   'vine,',
#   'vine.',
#   'same',
#   'fire',
#   'Father',
#   'Father',
#   'world',
#   'world',
#   'world.',
#   'world.',
#   'world',
#   'works',
#   'word',
#   'Spirit',
#   'Father,\r\nHe',
#   'beginning.',
#   'synagogues.',
#   'time',
#   'Father\r\nnor',
#   'time',
#   'beginning',
#   'truth,',
#   'Comforter',
#   'world',
#   'evil',
#   'Spirit',
#   'Father',
#   'Father.',
#   'Father?',
#   'child',
#   'world.',
#   'time',
#   'Father.',
#   'Father',
#   'Father',
#   'Father',
#   'world.',
#   'Father.',
#   'hour\r\ncometh,',
#   'world',
#   'world.',
#   'hour',
#   'only',
#   'earth.',
#   'glory',
#   'men',
#   'world.',
#   'words',
#   'world,',
#   'world',
#   'world.',
#   'world',
#   'son',
#   'scripture',
#   'world',
#   'world',
#   'world.',
#   'world,',
#   'world',
#   'world.',
#   'world.',
#   'truth.',
#   'glory',
#   'world',
#   'foundation',
#   'world.',
#   'world',
#   'love',
#   'brook',
#   'place',
#   'chief',
#   'saying',
#   'high',
#   'sheath.',
#   'band',
#   'Jews',
#   'high',
#   'Jews',
#   'people.',
#   'palace',
#   'high',
#   'door.',
#   'other',
#   'door,',
#   'door',
#   'fire',
#   'cold',
#   'world.',
#   'temple',
#   'Jews',
#   'officers',
#   'palm',
#   'high',
#   'evil.',
#   'high',
#   'servants',
#   'high',
#   'garden',
#   'cock',
#   'hall',
#   'judgment',
#   'passover.',
#   'saying',
#   'judgment',
#   'King',
#   'Jews?',
#   'chief',
#   'Jews.',
#   'world,',
#   'truth',
#   'passover.',
#   'King',
#   'Jews?',
#   'Jews!',
#   'crown',
#   'purple',
#   'man!',
#   'chief',
#   'Son',
#   'more',
#   'greater',
#   'judgment',
#   'Pavement,',
#   'preparation',
#   'passover',
#   'Jews,',
#   'place',
#   'Hebrew,',
#   'midst.',
#   'cross.',
#   'Jews',
#   'place',
#   'city',
#   'title',
#   'chief',
#   'Jews',
#   'Jews',
#   'cross',
#   'soldiers',
#   'top',
#   'scripture\r\nwas',
#   'cross',
#   'wife',
#   'disciple',
#   'disciple,',
#   'scripture',
#   'vinegar,\r\nHe',
#   'preparation',
#   'sabbath,',
#   'cross.',
#   'legs',
#   'first',
#   'other',
#   'soldiers\r\npierced',
#   'Jews,',
#   'first',
#   'body',
#   'spices',
#   'custom',
#   'Jews',
#   'garden\r\nwas',
#   'first',
#   'week,',
#   'sepulchre.',
#   'stone',
#   'entrance.',
#   'Lord',
#   'sepulchre',
#   'other',
#   'other',
#   'entrance',
#   'linen',
#   'sepulchre,',
#   'linen',
#   'napkin',
#   'scripture,',
#   'dead.',
#   'entrance',
#   'sepulchre,',
#   'head',
#   'other',
#   'feet',
#   'body',
#   'gardener,',
#   'disciples',
#   'Lord,\r\nand',
#   'same',
#   'first',
#   'week,',
#   'doors',
#   'disciples',
#   'Jews,',
#   'midst,',
#   'Lord.',
#   'Holy',
#   'twelve,',
#   'nails,',
#   'print',
#   'nails,',
#   'midst,',
#   'presence',
#   'Christ,',
#   'Son',
#   'sea',
#   'sons',
#   'morning',
#   'shore.',
#   'net\r\non',
#   'right',
#   'boat',
#   'net.',
#   'multitude',
#   'net.',
#   'disciple',
#   'Lord.',
#   'Lord,',
#   'sea.',
#   'net',
#   'fishes.',
#   'shore.',
#   'shore,',
#   'fish',
#   'net.',
#   'net',
#   'disciples\r\ndurst',
#   'Lord.',
#   'third',
#   'disciple',
#   'disciple',
#   'saying',
#   'brethren',
#   'disciple',
#   'books'],
#  'Presence': ['of'],
#  'God.': ['The',
#   'The',
#   'All',
#   'And',
#   'The',
#   'Thou',
#   'Nicodemus',
#   'That\r\nwhich',
#   'This',
#   'After',
#   'Then',
#   'They',
#   'Every\r\nman',
#   'Verily,',
#   'Jesus',
#   'Ye',
#   'Jesus\r\nsaid',
#   'I',
#   'The',
#   'Jesus\r\nanswered',
#   'Believe\r\nin',
#   'I\r\ncame',
#   'When\r\nPilate',
#   'Mary',
#   'Jesus',
#   'When'],
#  'way': ['to', 'therefore,', 'is', 'ye'],
#  'God': ['is',
#   'whose',
#   'at',
#   'who\r\ntaketh',
#   'ascending',
#   'because',
#   'be',
#   'so',
#   'sent',
#   'is',
#   'hath',
#   'giveth',
#   'abideth',
#   'is',
#   'was',
#   'in',
#   'the',
#   'is',
#   'or',
#   'were',
#   "heareth\r\nGod's",
#   'should',
#   'because',
#   'spoke',
#   'heareth',
#   'He',
#   'came,',
#   'might',
#   'will',
#   'that',
#   'is',
#   'be',
#   'a',
#   'and'],
#  'is': ['by',
#   'interpreted\r\nGood',
#   'the',
#   'called',
#   'the',
#   'preferred',
#   'in',
#   'the',
#   'preferred\r\nbefore',
#   'He',
#   'preferred',
#   'the',
#   'interpreted,',
#   'interpreted,',
#   'interpreted,',
#   'no',
#   'not',
#   'worse,',
#   'old?',
#   'born',
#   'flesh',
#   'born',
#   'as',
#   'not',
#   'condemned',
#   'the',
#   'come',
#   'the\r\nbridegroom,',
#   'fulfilled.',
#   'above',
#   'of',
#   'above\r\nall.',
#   'true.',
#   'near',
#   'it',
#   'deep.',
#   'not',
#   'the',
#   'of',
#   'now,',
#   'a',
#   'called',
#   'come',
#   'to',
#   'that',
#   'the',
#   'a',
#   'called',
#   'stirred,',
#   'the',
#   'that',
#   'so',
#   'coming,',
#   'now,',
#   'the',
#   'coming',
#   'just',
#   'not',
#   'another',
#   'true.',
#   'not\r\nsufficient',
#   'a',
#   'truly',
#   'I.',
#   'the',
#   'written,',
#   'He',
#   'the',
#   'the',
#   'it',
#   'of',
#   'the',
#   'my',
#   'drink',
#   'that',
#   'a',
#   'the',
#   'a',
#   'no',
#   'not',
#   'always\r\nready.',
#   'not',
#   'a',
#   'not\r\nmine',
#   'in',
#   'of',
#   'the',
#   'but\r\nwhen',
#   'true,',
#   'this',
#   'the',
#   'the',
#   'without',
#   'not',
#   'true',
#   'also',
#   'true.',
#   'Thy',
#   'true.',
#   'with',
#   'our',
#   'no',
#   'a',
#   'of',
#   'One',
#   'dead,',
#   'nothing.',
#   'my\r\nFather,',
#   'your',
#   'day.',
#   'he.',
#   'like',
#   'called',
#   'not',
#   'a',
#   'a',
#   'our',
#   'of',
#   'of',
#   'a',
#   'a',
#   'come,',
#   'He',
#   'a',
#   'the',
#   'a',
#   'mad;\r\nwhy',
#   'greater',
#   'able\r\nto',
#   'in',
#   'sick.',
#   'not\r\nunto',
#   'no',
#   'dead.',
#   'come',
#   'expedient\r\nfor',
#   'the',
#   'written,',
#   'gone',
#   'come,',
#   'the',
#   'this\r\nSon',
#   'the',
#   'washed',
#   'clean',
#   'not',
#   'sent',
#   'come\r\nto',
#   'it?',
#   'to',
#   'the',
#   'glorified',
#   'it',
#   'not',
#   'the',
#   'greater',
#   'the',
#   'cut',
#   'my\r\nFather',
#   'my',
#   'not',
#   'written',
#   'best',
#   'come,',
#   'prince',
#   'judged.',
#   'come,',
#   'this',
#   'this',
#   'in',
#   'delivered',
#   'now',
#   'with',
#   'come.',
#   'life\r\neternal,',
#   'lost',
#   'Truth.',
#   'not',
#   'not\r\nof',
#   'not\r\nfrom',
#   'of',
#   'truth?',
#   'finished.',
#   'true.',
#   'to',
#   'the',
#   'the',
#   'now',
#   'he',
#   'that',
#   'that',
#   'the',
#   'true.'],
#  'reading': ['the', 'enjoyment.'],
#  'gospels.': ['Gospel'],
#  'interpreted\r\nGood': ['News'],
#  'News': ['-'],
#  '-': ["God's"],
#  "God's": ['good', 'good'],
#  'good': ['news',
#   'news',
#   'thing',
#   'wine,',
#   'wine\r\nuntil',
#   'man.',
#   'shepherd',
#   'works\r\nhave',
#   'work'],
#  'news': ['to', 'through'],
#  'His': ['world.',
#   'gentle',
#   'own,',
#   'own',
#   'name:',
#   'glory,',
#   'fullness,',
#   'disciples',
#   'mother',
#   'glory',
#   'disciples',
#   'mother,',
#   'brethren,\r\nand',
#   'disciples.',
#   'body.',
#   'disciples',
#   'only',
#   'Son\r\ninto',
#   'disciples',
#   'testimony',
#   'hand.',
#   'disciples)',
#   'disciples',
#   'disciples',
#   'disciples',
#   'work.',
#   'Father,',
#   'voice',
#   'voice',
#   'shape.',
#   'word\r\nabiding',
#   'disciples.',
#   'disciples,',
#   'disciples,',
#   'disciples',
#   'disciples\r\nentered.',
#   'disciples',
#   'disciples,',
#   'flesh',
#   'blood,\r\nye',
#   'disciples',
#   'disciples',
#   'brethren,',
#   'own',
#   'that',
#   'will',
#   'glory\r\nthat',
#   'finger,',
#   'hour',
#   'saying.',
#   'disciples\r\nasked',
#   'parents',
#   'disciple;\r\nbut',
#   'will,',
#   'life',
#   'name',
#   'sisters',
#   'disciples,',
#   'disciples',
#   'disciples,',
#   'feet',
#   'eyes,',
#   'disciples.',
#   'feet',
#   'disciples,',
#   'disciples\r\ndid',
#   'glory\r\nand',
#   'commandment\r\nis',
#   'own',
#   'hands',
#   'garments,',
#   'garments,',
#   'disciples,',
#   'love.',
#   'disciples',
#   'disciples',
#   'eyes',
#   'disciples.',
#   'disciples,',
#   'disciples?',
#   'head.',
#   'cross',
#   'garments\r\nand',
#   'coat',
#   'mouth.',
#   'head',
#   'legs.',
#   'side',
#   'side',
#   'head.',
#   'hands',
#   'side.',
#   'hands',
#   'side,',
#   'disciples',
#   'disciples\r\nwhich',
#   'Name.',
#   'disciples.',
#   'disciples.'],
#  'world.': ['It',
#   'He\r\nwas',
#   'This',
#   'Now',
#   'When',
#   'Then',
#   'The',
#   'For',
#   'He\r\nthat',
#   'I',
#   'I',
#   'But',
#   'And',
#   'Now\r\nshall',
#   'He\r\nthat',
#   'I',
#   'Therefore',
#   'So',
#   'Now',
#   '17.',
#   'Thine',
#   'I',
#   'I',
#   'Sanctify\r\nthem',
#   'And',
#   'O',
#   'I',
#   'If'],
#  'It': ['is',
#   'was',
#   'was',
#   'is',
#   'was',
#   'grew',
#   'is',
#   'is',
#   'is',
#   'was\r\nalso',
#   'was',
#   'was',
#   'was',
#   'is',
#   'was',
#   'is',
#   'was',
#   'is',
#   'was',
#   'was'],
#  'new': ['testament', 'commandment.', 'birth', 'sepulchre'],
#  'testament': ['and\r\nperspective'],
#  'and\r\nperspective': ['we'],
#  'have': ['in',
#   'all',
#   'found',
#   'found',
#   'no',
#   'said\r\nof',
#   'seen,',
#   'eternal',
#   'everlasting',
#   'no',
#   'asked',
#   'given',
#   'to',
#   'no',
#   'no',
#   'meat',
#   'heard',
#   'no',
#   'life',
#   'done\r\ngood',
#   'done',
#   'greater',
#   'neither\r\nheard',
#   'not',
#   'eternal',
#   'not',
#   'believed',
#   'seen',
#   'everlasting',
#   'no',
#   'taken',
#   'ye',
#   'reason',
#   'the',
#   'many',
#   'heard',
#   'lifted',
#   'seen',
#   'heard',
#   'one',
#   'not',
#   'not\r\nknown',
#   'told',
#   'no',
#   'life',
#   'it',
#   'power\r\nto',
#   'power',
#   'sought',
#   'died.',
#   'ye',
#   'caused',
#   'died?',
#   'with',
#   'not',
#   'both',
#   'heard',
#   'the',
#   'spoken',
#   'not\r\nspoken',
#   'done',
#   'done',
#   'chosen.',
#   'need',
#   'loved',
#   'love',
#   'told',
#   'known',
#   'seen',
#   'I',
#   'said',
#   'heard',
#   'told',
#   'spoken',
#   'I',
#   'kept',
#   'I',
#   'loved\r\nyou.',
#   'heard',
#   'not',
#   'chosen',
#   'persecuted',
#   'kept\r\nmy',
#   'no',
#   'seen',
#   'I',
#   'not',
#   'I',
#   'yet',
#   'asked\r\nnothing',
#   'spoken',
#   'loved',
#   'believed',
#   'spoken',
#   'peace.',
#   'tribulation.',
#   'overcome',
#   'glorified',
#   'finished\r\nthe',
#   'manifested',
#   'given',
#   'kept.',
#   'my',
#   'given',
#   'I',
#   'given',
#   'known',
#   'known',
#   'declared',
#   'told',
#   'lost',
#   'spoken',
#   'delivered\r\nHim',
#   'delivered\r\nThee',
#   'a\r\ncustom',
#   'a',
#   'power',
#   'no',
#   'no',
#   'written',
#   'written.',
#   'taken\r\naway',
#   'taken',
#   'laid\r\nHim.',
#   'borne',
#   'seen\r\nthe',
#   'not',
#   'believed.',
#   'life',
#   'ye\r\nanything?',
#   'caught.'],
#  'in': ['order',
#   'doing',
#   'His',
#   'the',
#   'darkness;\r\nand',
#   'the',
#   'the\r\nbosom',
#   'the',
#   'Bethabara',
#   'the',
#   'Cana',
#   'Cana',
#   'the',
#   'three',
#   'building,',
#   'three',
#   'Jerusalem',
#   'the',
#   'Him\r\nshould',
#   'Him\r\nshould',
#   'the\r\nname',
#   'God.',
#   'Aenon',
#   'him',
#   'this',
#   'Jerusalem',
#   'this',
#   'spirit',
#   'truth',
#   'spirit',
#   'truth.',
#   'his',
#   'Galilee,',
#   'which',
#   'Hebrew,',
#   'was',
#   'that',
#   'the',
#   'Himself.',
#   'which',
#   'his',
#   'you',
#   'you.',
#   'my',
#   'his',
#   'whom',
#   'the',
#   'the',
#   'the',
#   'you.',
#   'me,',
#   'him.',
#   'the',
#   'Capernaum.',
#   'Galilee.',
#   'Jewry',
#   'secret,\r\nand',
#   'Him.',
#   'Galilee.',
#   'secret.',
#   'Him.',
#   'the\r\ntemple',
#   'the',
#   'adultery.',
#   'the',
#   'adultery,',
#   'the',
#   'the',
#   'darkness,',
#   'your',
#   'the',
#   'the',
#   'your\r\nsins',
#   'your',
#   'my',
#   'bondage',
#   'the',
#   'you.',
#   'the',
#   'him.',
#   'him.',
#   'the',
#   'the',
#   'sin.',
#   'by',
#   'and',
#   'my',
#   'your',
#   'me,',
#   'Him.',
#   'the',
#   'the',
#   'the\r\nday,',
#   'the',
#   'him.',
#   'sleep.',
#   'the',
#   'the',
#   'the',
#   'me,',
#   'me',
#   'that',
#   'the',
#   'the',
#   'Himself',
#   'one',
#   'the',
#   'this',
#   'darkness',
#   'the',
#   'darkness.',
#   'the',
#   'the',
#   'spirit',
#   'Him.',
#   'Him,',
#   'Himself.',
#   'God.',
#   'the',
#   'me?',
#   'me.',
#   'the',
#   'me,',
#   'my',
#   'the',
#   'my',
#   'you.',
#   'me,',
#   'you.',
#   'my\r\nname,',
#   'me',
#   'me,\r\nand',
#   'you.',
#   'me.',
#   'me,',
#   'him,',
#   'me',
#   'me',
#   'you,\r\nye',
#   'my',
#   'my',
#   'His',
#   'you',
#   'my',
#   'their',
#   'a',
#   'a\r\nlittle',
#   'a',
#   'travail',
#   'my',
#   'my',
#   'proverbs.',
#   'proverbs',
#   'my',
#   'me',
#   'them.',
#   'the',
#   'the',
#   'the',
#   'Thy',
#   'the',
#   'themselves.',
#   'me,',
#   'Thee.',
#   'Us',
#   'them',
#   'me,',
#   'One,\r\nand',
#   'them',
#   'them.',
#   'law',
#   'the',
#   'the\r\nsynagogue,',
#   'the',
#   'the',
#   'Him',
#   'Him.',
#   'Him.',
#   'the',
#   'a',
#   'the\r\nHebrew,',
#   'the',
#   'Hebrew,\r\nand',
#   'linen',
#   'the',
#   'a',
#   'also,',
#   'white',
#   'the',
#   'His',
#   'the',
#   'the',
#   'this',
#   'Galilee,',
#   'the',
#   'the\r\nboat',
#   'the'],
#  'and': ['love',
#   'love',
#   'direct.',
#   'faithfully',
#   'simple',
#   'the',
#   'the',
#   'the',
#   'the',
#   'His',
#   'dwelt',
#   'truth.',
#   'cried,',
#   'truth',
#   'Levites\r\nfrom',
#   'did\r\nnot',
#   'whose',
#   'it',
#   'remaining',
#   'bare',
#   'two',
#   'saith',
#   'see.',
#   'saw\r\nwhere',
#   'abode',
#   'followed',
#   'saith\r\nto',
#   'findeth',
#   'saith\r\nunto',
#   'saith',
#   'the',
#   'see.',
#   'saith',
#   'said',
#   'saith',
#   'said',
#   'the',
#   'descending\r\nupon',
#   'His',
#   'carry',
#   'His',
#   'found',
#   'sheep',
#   'doves',
#   'changers',
#   'said',
#   'said',
#   'in',
#   'six',
#   'wilt',
#   'they',
#   'the',
#   'a',
#   'said',
#   'said',
#   'of',
#   'that',
#   'thou',
#   'whither',
#   'said',
#   'said',
#   'knowest',
#   'ye',
#   'ye',
#   'men',
#   'cometh',
#   'His',
#   'baptized.',
#   'were',
#   'the',
#   'said,',
#   'said,',
#   'heareth\r\nHim,',
#   'speaketh',
#   'heard',
#   'no',
#   'hath',
#   'departed',
#   'said',
#   'who',
#   'the\r\nwell',
#   'drank',
#   'his',
#   'said',
#   'never',
#   'come\r\nhither.',
#   'said,',
#   'ye',
#   'is',
#   'in',
#   'in',
#   'they',
#   'went',
#   'came\r\nunto',
#   'then\r\ncometh',
#   'look',
#   'gathereth',
#   'another',
#   'ye',
#   'know',
#   'went',
#   'was',
#   'heal',
#   'wonders',
#   'he',
#   'stirred',
#   'eight\r\nyears.',
#   'knew',
#   'walk.',
#   'walked.',
#   'walk.',
#   'walk?',
#   'said',
#   'told',
#   'I',
#   'said',
#   'showeth',
#   'quickeneth',
#   'believeth\r\non',
#   'shall',
#   'is',
#   'shall',
#   'I',
#   'he',
#   'a',
#   'ye',
#   'ye',
#   'seek',
#   'there',
#   'two',
#   'the',
#   'filled',
#   'take',
#   'entered',
#   'went',
#   'Jesus',
#   'twenty',
#   'drawing',
#   'said,',
#   'were',
#   'said',
#   'believe',
#   'believe',
#   'believeth',
#   'mother',
#   'said',
#   'hath',
#   'not',
#   'drink',
#   'drinketh',
#   'my',
#   'I',
#   'I',
#   'if',
#   'who',
#   'walked',
#   'are',
#   'said,',
#   'said,',
#   'yet',
#   'said,',
#   'said',
#   'ye',
#   'ye',
#   'they',
#   'know',
#   'He',
#   'said,',
#   'the',
#   'then',
#   'shall',
#   'teach',
#   'shall',
#   'cried,\r\nsaying,',
#   'drink.',
#   'out\r\nof',
#   'Pharisees.',
#   'know',
#   'said',
#   'look,',
#   'all',
#   'Pharisees',
#   'wrote',
#   'down',
#   'the',
#   'saw',
#   'sin',
#   'said',
#   'whither',
#   'the',
#   'shall',
#   'to',
#   'the',
#   'were\r\nnever',
#   'ye',
#   'said',
#   'came',
#   'the',
#   'the',
#   'ye',
#   'hast',
#   'ye\r\ndishonour',
#   'so',
#   'the',
#   'keep',
#   'was',
#   'hast',
#   'went',
#   'made',
#   'He',
#   'washed,',
#   'came',
#   'said,',
#   'anointed\r\nmy',
#   'said',
#   'wash.',
#   'I',
#   'opened',
#   'I',
#   'do',
#   'received',
#   'that\r\nhe',
#   'said',
#   'said,\r\nWhether',
#   'said,',
#   'said',
#   'yet',
#   'said',
#   'said,',
#   'it',
#   'they\r\nwhich',
#   'said',
#   'leadeth',
#   'the',
#   'shall',
#   'out',
#   'find',
#   'kill',
#   'destroy.',
#   'that',
#   'not',
#   'leaves',
#   'flees.',
#   'scattereth',
#   'careth',
#   'am',
#   'they',
#   'One',
#   'I',
#   'is',
#   'the',
#   'ye',
#   'I',
#   'they',
#   'my',
#   'because',
#   'the',
#   'believe\r\nthat',
#   'I',
#   'went',
#   'said,',
#   'her',
#   'Lazarus.',
#   'Mary',
#   'the',
#   'believeth',
#   'calleth',
#   'came',
#   'go',
#   'see.',
#   'a',
#   'said,',
#   'foot',
#   'his',
#   'let',
#   'had',
#   'the\r\nPharisees',
#   'said,',
#   'take',
#   'nation.',
#   'not',
#   'spoke',
#   'the',
#   'anointed',
#   'wiped',
#   'given',
#   'held',
#   'believed\r\non',
#   'cried,',
#   'that',
#   'raised',
#   'telleth\r\nAndrew.',
#   'Philip',
#   'die,\r\nit',
#   'he',
#   'heard',
#   'said,',
#   'then',
#   'hid',
#   'hardened',
#   'be',
#   'said,',
#   'believe',
#   'receives',
#   'what',
#   'that',
#   'that',
#   'went',
#   'began',
#   'said',
#   'my',
#   'sat',
#   'Master,\r\nhave',
#   'testified',
#   'God',
#   'receive',
#   'the',
#   'from',
#   'have',
#   'it',
#   'still',
#   'the',
#   'He',
#   'will',
#   'shall',
#   'ye',
#   'I',
#   'show',
#   'not',
#   'said,',
#   'my',
#   'make',
#   'do',
#   'my',
#   'I',
#   'will',
#   'cast',
#   'my',
#   'it',
#   'so',
#   'abide',
#   'that',
#   'bring',
#   'that',
#   'spoken',
#   'hated',
#   'of',
#   'ye',
#   'shall',
#   'ye',
#   'ye',
#   'ye',
#   'ye',
#   'ye',
#   'in',
#   'lament,',
#   'have',
#   'am',
#   'go',
#   'speakest\r\nno',
#   'Jesus',
#   'Thou',
#   'know',
#   'they',
#   'Thine',
#   'speak',
#   'I',
#   'Thou',
#   'hast',
#   'these',
#   'will',
#   'I',
#   'officers',
#   'Pharisees,\r\ncometh',
#   'torches',
#   'weapons.',
#   'said',
#   'cut',
#   'officers',
#   'took',
#   'so',
#   'who',
#   'brought',
#   'servants',
#   'of',
#   'in',
#   'warmed',
#   'said,',
#   'might',
#   'judge',
#   'called',
#   'said\r\nunto',
#   'the',
#   'for\r\nthis',
#   'saith',
#   'had',
#   'put',
#   'said,',
#   'saith,',
#   'the',
#   'officers',
#   'crucify',
#   'saith',
#   'sat\r\ndown',
#   'in',
#   'about',
#   'led',
#   'two',
#   'Jesus',
#   'put\r\nit',
#   'the',
#   'Latin.',
#   'woven',
#   'for',
#   'his',
#   'Mary',
#   'the',
#   'put',
#   'said,',
#   'that',
#   'then',
#   'saw',
#   'from',
#   'water.',
#   'his',
#   'met',
#   'the\r\nother',
#   'we',
#   'the',
#   'looking\r\nin,',
#   'in',
#   'he',
#   'believed.',
#   'saw',
#   'the',
#   'I',
#   'saw',
#   'knew\r\nnot',
#   'I',
#   'saith',
#   'say',
#   'your',
#   'to',
#   'your',
#   'told',
#   'saith',
#   'His',
#   'saith',
#   'put',
#   'Thomas',
#   'stood',
#   'said,',
#   'behold',
#   'reach',
#   'thrust',
#   'said',
#   'yet',
#   'two',
#   'ye',
#   'cast',
#   'fish',
#   'drew',
#   'fifty',
#   'dine.',
#   'served',
#   'fish',
#   'walkedst\r\nwhither',
#   'another',
#   'carry',
#   'saw',
#   'what',
#   'wrote',
#   'we'],
#  'as': ['He',
#   'many',
#   'was',
#   'He',
#   'I',
#   'the',
#   'they',
#   'the',
#   'it',
#   'He',
#   'He',
#   'the',
#   'if',
#   'I',
#   'soon',
#   'she',
#   'she',
#   'they',
#   'a',
#   'the',
#   'I',
#   'I',
#   'the',
#   'the',
#   'I',
#   'I',
#   'soon',
#   'she',
#   'Thou',
#   'many',
#   'Thou',
#   'We',
#   'I',
#   'I',
#   'Thou,\r\nFather,',
#   'We',
#   'Jesus',
#   'the',
#   'my',
#   'they'],
#  'He': ['means',
#   'came',
#   'came',
#   'gave',
#   'of',
#   'that',
#   'was\r\nbefore',
#   'confessed,',
#   'said,\r\nI',
#   'it',
#   'of',
#   'was',
#   'should',
#   'who',
#   'walked.',
#   'saith',
#   'dwelt',
#   'said,',
#   'saith',
#   'saith',
#   'saith',
#   'saith',
#   'went',
#   'drove',
#   'said',
#   'spoke',
#   'was',
#   'was',
#   'did.',
#   'came',
#   'that',
#   'gave',
#   'that',
#   'tarried',
#   'that',
#   'baptizeth',
#   'that',
#   'must',
#   'that',
#   'that',
#   'that',
#   'hath',
#   'testifieth',
#   'that',
#   'whom',
#   'that',
#   'that',
#   'left',
#   'came',
#   'would',
#   'whom',
#   'is',
#   'will',
#   'talked',
#   'that',
#   'told',
#   'abode',
#   'departed',
#   'did',
#   'turned\r\nthe',
#   'was',
#   'saith',
#   'answered',
#   'that',
#   'had',
#   'not',
#   'said',
#   'doeth,',
#   'Himself',
#   'will',
#   'will.',
#   'that',
#   'that',
#   'given',
#   'hath\r\ngiven',
#   'is',
#   'was',
#   'hath',
#   'did',
#   'sat',
#   'saith',
#   'said',
#   'had',
#   'distributed',
#   'departed',
#   'saith',
#   'hath',
#   'gave',
#   'which',
#   'that\r\ncometh',
#   'hath\r\ngiven',
#   'said,',
#   'saith,',
#   'which',
#   'that',
#   'that',
#   'that',
#   'in',
#   'taught',
#   'was',
#   'said,',
#   'spoke',
# ...
#  'you': ['earthly',
#   'of',
#   'to',
#   'because',
#   'that',
#   'to',
#   'for',
#   'the',
#   'that',
#   'that',
#   'that',
#   'twelve',
#   'is',
#   'but',
#   'the',
#   'keepeth',
#   'circumcision',
#   'and',
#   'from',
#   'free.',
#   'free,\r\nye',
#   'the',
#   'convinceth',
#   'say',
#   'already\r\nand',
#   'and',
#   'from',
#   'an',
#   'before',
#   'that',
#   'shall',
#   'a',
#   'unto',
#   'and',
#   'another',
#   'forever.',
#   'comfortless.',
#   'being',
#   'all',
#   'that',
#   'and',
#   'friends',
#   'out',
#   'for',
#   'that',
#   'out',
#   'will',
#   'because',
#   'so',
#   'of',
#   'asketh',
#   'sorrow',
#   'the',
#   'that',
#   'into',
#   'things',
#   'again.',
#   'in',
#   'in',
#   'plainly\r\nof',
#   'so',
#   'that',
#   'at',
#   'the',
#   'that'],
#  'earthly': ['things'],
#  'not,': ['how', 'I', 'daughter', 'I'],
#  'how': ['shall', 'the', 'shall', 'he', 'He', 'is', 'I'],
#  'I\r\ntell': ['you'],
#  'heavenly': ['things?'],
#  'No': ['man', 'man', 'man', 'man,', 'man', 'man', 'man', 'man', 'man'],
#  'ascended': ['up', 'to'],
#  'heaven,\r\nthe': ['Son'],
#  'As': ['Moses',
#   'he',
#   'I',
#   'my',
#   'He',
#   'long',
#   'for\r\nthis',
#   'I',
#   'soon',
#   'the',
#   'the',
#   'Thou',
#   'soon',
#   'Simon',
#   'yet',
#   'she',
#   'soon'],
#  'lifted': ['up',
#   'up',
#   'Himself',
#   'up',
#   'up',
#   'up\r\nfrom',
#   'up?',
#   'up\r\nhis',
#   'up'],
#  'serpent': ['in'],
#  'wilderness': ['even\r\nso'],
#  'even\r\nso': ['must'],
#  'so': ['that',
#   'loved',
#   'that',
#   'the',
#   'all',
#   'hath',
#   'many?',
#   'that\r\nnothing',
#   'are',
#   'passed',
#   'said,',
#   'the',
#   'I',
#   'when',
#   'long',
#   'that',
#   'that,',
#   'the',
#   'shall',
#   'have',
#   'whatever',
#   'that',
#   'that',
#   'your',
#   'that',
#   'they',
#   'have',
#   'that\r\nthe',
#   'that',
#   'that',
#   'did',
#   'I',
#   'said,',
#   'send',
#   'many,'],
#  'whosoever': ['believeth', 'believeth', 'drinketh', 'believeth'],
#  'believeth': ['in',
#   'in',
#   'on',
#   'on\r\nthe',
#   'not',
#   'on',
#   'on',
#   'on',
#   'in',
#   'on',
#   'not',
#   'on',
#   'on\r\nme'],
#  'Him\r\nshould': ['not', 'not'],
#  'perish': ['but'],
#  'eternal': ['life.', 'so', 'life.', 'life.', 'life'],
#  'life.': ['For',
#   'For',
#   'He',
#   'The',
#   'Verily,',
#   'They',
#   'They',
#   'It\r\nis',
#   'He',
#   'And',
#   'Your',
#   'I',
#   'But',
#   'He',
#   'No'],
#  'For': ['God',
#   'God',
#   'John',
#   'He',
#   'the',
#   'as',
#   'the',
#   'as',
#   'had',
#   'the',
#   'my',
#   'Jesus\r\nknew',
#   'there',
#   'neither',
#   'judgment\r\nI',
#   'a',
#   'the',
#   'I',
#   'I\r\nhave',
#   'the',
#   'I'],
#  'loved': ['the',
#   'Martha',
#   'him!',
#   'the',
#   'His',
#   'them',
#   'you.',
#   'of',
#   'me',
#   'me,',
#   'you.',
#   'me',
#   'them\r\nas',
#   'me.',
#   'me',
#   'standing',
#   'saith',
#   'following\r\nthem.'],
#  'world\r\nthat': ['He'],
#  'perish,': ['but', 'nor'],
#  'everlasting': ['life.', 'life.', 'life.', 'life', 'life.', 'life.'],
#  'Son\r\ninto': ['the'],
#  'condemn': ['the', 'thee.'],
#  'Him,\r\nmight': ['be'],
#  'saved.': ['He'],
#  'condemned.': ['But'],
#  'that\r\nbelieveth': ['not', 'on', 'in'],
#  'condemned': ['already', 'thee?'],
#  'already': ['because', 'one', 'lain', 'dead,', 'laid'],
#  'the\r\nname': ['of'],
#  'condemnation:': ['light'],
#  'loved\r\ndarkness': ['rather'],
#  'rather': ['than'],
#  'than': ['light',
#   'John,',
#   'these',
#   'that',
#   'these',
#   'our\r\nfather',
#   'all.',
#   'the',
#   'his',
#   'his',
#   'He',
#   'these',
#   'I.',
#   'that',
#   'his',
#   'these?'],
#  'their': ['deeds',
#   'labours.',
#   'own',
#   'eyes',
#   'hearts',
#   'eyes,',
#   'heart',
#   'feet,',
#   'sin.',
#   'law,',
#   'sakes\r\nI',
#   'word',
#   'way.',
#   'own'],
#  'deeds': ['were', 'may', 'of'],
#  'evil.': ['Every', 'Go', 'They', 'But'],
#  'Every': ['one', 'branch', 'one'],
#  'that\r\ndoeth': ['evil'],
#  'evil': ['hateth', 'go', 'one'],
#  'hateth': ['the', 'because', 'his', 'you.', 'me', 'my\r\nFather'],
#  'lest': ['his', 'a', 'darkness', 'they', 'they'],
#  'deeds\r\nshould': ['be'],
#  'reproved.': ['But'],
#  'doeth': ['truth', 'any', 'His', 'the', 'God'],
#  'that\r\nhis': ['deeds'],
#  'shown': ['that'],
#  'are': ['wrought',
#   'yet',
#   'all',
#   'entered',
#   'in\r\ngraves',
#   'the\r\nsame',
#   'they',
#   'dead.',
#   'spirit',
#   'life.',
#   'some',
#   'sure',
#   'evil.',
#   'ye',
#   'cursed.',
#   'one.',
#   'from',
#   'of',
#   'ye',
#   "Abraham's",
#   "Abraham's",
#   'of',
#   'not',
#   'the',
#   'dead?',
#   "Moses'",
#   'thieves',
#   'not',
#   'not',
#   'not',
#   'one.',
#   'gods?',
#   'clean.',
#   'clean.',
#   'ye',
#   'my',
#   'many',
#   'in',
#   'my',
#   'not',
#   'mine.',
#   'of\r\nThee.',
#   'Thine.',
#   'Thine,',
#   'one.',
#   'not',
#   'remitted',
#   'retained.',
#   'they',
#   'not',
#   'written',
#   'also'],
#  'wrought': ['in'],
#  'land': ['of\r\nJudaea.', 'whither'],
#  'of\r\nJudaea.': ['There'],
#  'tarried': ['with'],
#  'baptized.': ['And', 'For'],
#  'was\r\nbaptizing': ['in'],
#  'Aenon': ['near'],
#  'near': ['to', 'the', 'death.', 'the', 'Jerusalem,', 'to', 'at\r\nhand.'],
#  'Salim': ['because'],
#  'much': ['water', 'murmuring', 'fruit.', 'with', 'fruit'],
#  'there,': ['so\r\nmany', 'except', 'nor', 'to', 'and'],
#  'so\r\nmany': ['people'],
#  'people': ['came',
#   'who',
#   'saw',
#   'concerning',
#   'answered',
#   'believed',
#   'murmured',
#   'therefore,',
#   'because',
#   'came',
#   'so',
#   'who',
#   'that',
#   'met',
#   'that',
#   'answered'],
#  'cast': ['into',
#   'out',
#   'at',
#   'him',
#   'him',
#   'out.',
#   'them\r\ninto',
#   'lots',
#   'lots.',
#   'himself'],
#  'prison.': ['A'],
#  'question': ['arose'],
#  'arose': ['between', 'by', 'quickly', 'from'],
#  'between': ['some'],
#  'some': ['of', 'of', 'said,', 'of', 'other', 'of', 'of', 'of'],
#  "John's": ['disciples'],
#  'about\r\npurifying.': ['They'],
#  'thee\r\nbeyond': ['Jordan,'],
#  'Jordan,': ['to'],
#  'barest': ['witness,'],
#  'witness,': ['behold,'],
#  'behold,': ['He', 'he'],
#  'and\r\nall': ['men'],
#  'nothing': ['unless', 'to', 'of', 'to', 'of', 'at', 'on'],
#  'given\r\nhim': ['from'],
#  'heaven.': ['Ye', 'My', 'And', 'Not\r\nthe'],
#  'yourselves': ['bear', 'of'],
#  'not\r\nthe': ['Christ', 'Son'],
#  'Christ': ['but', 'cometh', 'come', 'cometh', 'abideth\r\nfor'],
#  'bride': ['is'],
#  'the\r\nbridegroom,': ['but'],
#  'friend': ['of', 'Lazarus'],
#  'bridegroom,': ['which'],
#  'heareth\r\nHim,': ['rejoiceth'],
#  'rejoiceth': ['greatly'],
#  'greatly': ['because'],
#  "bridegroom's": ['voice.'],
#  'voice.': ['This', 'He', 'A', 'There', 'Pilate'],
#  'joy\r\ntherefore': ['is'],
#  'fulfilled.': ['He', 'Now'],
#  'increase,': ['but'],
#  'decrease.': ['He'],
#  'above': ['is', 'all.'],
#  'all.': ['He', 'No', 'But'],
#  'earth': ['is\r\nearthly'],
#  'is\r\nearthly': ['and'],
#  'speaketh': ['of', 'the', 'a', 'of\r\nhis', 'against'],
#  'earth.': ['He', 'I'],
#  'above\r\nall.': ['All'],
#  'testifieth': ['and', 'of'],
#  'receiveth\r\nHis': ['testimony.'],
#  'testimony.': ['He'],
#  'testimony': ['hath', 'from', 'of', 'is'],
#  'seal\r\nthat': ['God'],
#  'true.': ['For',
#   'There',
#   'Ye',
#   'Jesus',
#   'I\r\nam',
#   'I',
#   'And\r\nmany',
#   'He',
#   'There'],
#  'words': ['of',
#   'that',
#   'of',
#   'unto',
#   'in',
#   'many',
#   'spoke',
#   'and',
#   'of',
#   'and',
#   'I',
#   'that',
#   'and',
#   'abide',
#   'spoke',
#   'which'],
#  'God\r\nbecause': ['God'],
#  'giveth': ['unto', 'you', 'me', 'His'],
#  'without': ['limit.', 'sin', 'me', 'a'],
#  'limit.': ['The'],
#  'Father': ['loveth\r\nthe',
#   'in',
#   'in',
#   'seeketh\r\nsuch',
#   'worketh',
#   'do,',
#   'loveth',
#   'raiseth',
#   'judgeth',
#   'which',
#   'hath',
#   'who',
#   'hath',
#   'hath',
#   'hath',
#   'giveth',
#   'giveth',
#   'which\r\nhath',
#   'except',
#   'hath\r\nsent',
#   'that',
#   'that',
#   'also.',
#   'ye',
#   'and',
#   'knoweth',
#   'love',
#   'are',
#   'hath',
#   'is',
#   'honour.',
#   'who',
#   'said',
#   'had\r\ngiven',
#   'but',
#   'also,',
#   'and',
#   'and\r\nthe',
#   'in',
#   'that',
#   'and',
#   'in',
#   'may\r\nbe',
#   'will',
#   'will',
#   'is',
#   'commanded',
#   'is',
#   'hath',
#   'I\r\nhave',
#   'in',
#   'and',
#   'hath',
#   'in',
#   'for',
#   'Himself',
#   'and',
#   'hath',
#   'hath'],
#  'loveth\r\nthe': ['Son'],
#  'on\r\nthe': ['Son', 'fields.', 'sabbath'],
#  'shall\r\nnot': ['see'],
#  'wrath': ['of'],
#  'abideth': ['on', 'not', 'alone.', 'in'],
#  'him.': ['4.',
#   'So',
#   'The',
#   'When',
#   'I',
#   'But',
#   'He',
#   'They',
#   'After',
#   'Then',
#   'He\r\nWhose',
#   'Then',
#   'Some',
#   'Judas,',
#   'We',
#   'He'],
#  '4.': [''],
#  'Lord': ['knew', 'had', 'been\r\nrevealed?', 'and', 'out', 'and'],
#  'made\r\nand': ['baptized'],
#  'baptized': ['more', 'not,\r\nbut'],
#  'more': ['disciples',
#   'believed',
#   'lest',
#   'to',
#   'miracles',
#   'abundantly.',
#   'days',
#   'openly',
#   'than',
#   'than',
#   'fruit.',
#   'can',
#   'speak',
#   'in',
#   'afraid.',
#   'than'],
#  '(Though': ['Jesus'],
#  'Himself': ['baptized',
#   'except',
#   'doeth.',
#   'knew',
#   'seeketh',
#   'up\r\nand',
#   'and',
#   'cometh\r\nto',
#   'loveth\r\nyou',
#   'the',
#   'again',
#   'to'],
#  'not,\r\nbut': ['His'],
#  'disciples)': ['He'],
#  'left': ['Judaea', 'her', 'Judea', 'him.', 'alone.', 'alone', 'me'],
#  'Judaea': ['and', 'into', 'that'],
#  'departed': ['again', 'from', 'and', 'alone\r\ninto', 'and'],
#  'He\r\nneeded': ['to'],
#  'go': ['through',
#   'unto',
#   'unto\r\nthe',
#   'away?',
#   'not',
#   'unto\r\nHim',
#   'unto',
#   'my',
#   'in',
#   'into',
#   'unto',
#   'that',
#   'out.',
#   'thou',
#   'to',
#   'and\r\nprepare',
#   'ye',
#   'away,',
#   'hence.',
#   'and',
#   'away',
#   'away.',
#   'not',
#   'to',
#   'to',
#   'to',
#   'to',
#   'their',
#   'thou',
#   'in.',
#   'to',
#   'a',
#   'with'],
#  'Samaria.': ['There'],
#  'Samaria': ['called\r\nSychar,', 'to'],
#  'called\r\nSychar,': ['which'],
#  'parcel': ['of'],
#  'ground': ['that', 'as', 'and'],
#  'Jacob': ['gave', 'who'],
#  'son\r\nJoseph.': ['Now'],
#  "Jacob's": ['well'],
#  'well': ['was', 'and', 'of\r\nwater', 'said,', 'for'],
#  'Jesus,': ['therefore,',
#   'the',
#   'When',
#   'saying,',
#   'and',
#   'when',
#   'bound',
#   'and',
#   'Whence',
#   'knowing',
#   'besought',
#   'wound',
#   'Lord,'],
#  'therefore,': ['being', 'said', 'when', 'shall', 'hear', 'and', 'started'],
#  'being': ['wearied',
#   'a',
#   'one',
#   'convicted',
#   'a',
#   'the',
#   'high',
#   'yet',
#   'his',
#   'the',
#   'shut,'],
#  'wearied': ['with\r\nHis'],
#  'with\r\nHis': ['journey,', 'disciples.'],
#  'journey,': ['sat'],
#  'sat': ['down',
#   'with',
#   'down.',
#   'down\r\nand',
#   'her',
#   'and\r\nbegged?',
#   'at',
#   'down'],
#  'well.': ['It', 'However,'],
#  'sixth': ['hour.'],
#  'There\r\ncometh': ['a'],
#  'woman': ['of',
#   'of',
#   'saith',
#   'saith',
#   'answered',
#   'saith',
#   'saith',
#   'then',
#   'who',
#   'was',
#   'was',
#   'when'],
#  'draw': ['water.', 'with', 'it.', 'him', 'all', 'it'],
#  'Give': ['me\r\nto', 'me'],
#  'me\r\nto': ['drink.'],
#  'drink.': ['(For', 'He'],
#  '(For': ['His'],
#  'gone': ['away', 'up,', 'after'],
#  'buy': ['meat.)', 'bread'],
#  'meat.)': ['She'],
#  'She': ['said',
#   'said,',
#   'saith\r\nunto',
#   'goeth\r\nunto',
#   'saw',
#   'saith',
#   'saith',
#   'turned'],
#  'Thou,': ['being', 'Ye', 'being', 'The'],
#  'Jew,': ['askest'],
#  'askest': ['drink', 'thou'],
#  'drink': ['of', 'His', 'indeed.', 'it?'],
#  'me,\r\na': ['woman'],
#  'Samaria?': ['The'],
#  'dealings': ['with'],
#  'Samaritans?': ['Jesus\r\nanswered'],
#  'knewest': ['the'],
#  'gift': ['of'],
#  'drink,': ['thou'],
#  'wouldest': ['have', 'believe,\r\nthou'],
#  'Him\r\nand': ['He', 'the'],
#  'would': ['have',
#   'have',
#   'not\r\nwalk',
#   'receive.',
#   'have',
#   'do',
#   'love',
#   'ye',
#   'not',
#   'betray',
#   'see',
#   'have',
#   'rejoice',
#   'love',
#   'be',
#   'not',
#   'not'],
#  'living': ['water.', 'water?', 'bread', 'Father', 'God.', 'water.'],
#  'Sir,': ['Thou', 'give', 'I', 'come', 'I', 'we'],
#  'the\r\nwell': ['is'],
#  'deep.': ['From'],
#  'From': ['whence', 'that'],
#  'water?': ['Art'],
#  'greater\r\nthan': ['our'],
#  'father': ['Jacob', 'knew', 'and', 'the', 'ye', 'of', 'in'],
#  'drank': ['thereof'],
#  'thereof': ['himself,\r\nand', 'are'],
#  'himself,\r\nand': ['his'],
#  'children,': ['and', 'yet'],
#  'cattle?': ['Jesus'],
#  'Whosoever': ['drinketh', 'eateth', 'committeth'],
#  'drinketh': ['of', 'of', 'my'],
#  'shall\r\nthirst': ['again.'],
#  'give\r\nhim': ['shall'],
#  'never': ['thirst.',
#   'have',
#   'hunger.',
#   'learned?',
#   'see',
#   'taste',
#   'perish,',
#   'die.',
#   'man'],
#  'thirst.': ['The', 'Now'],
#  'give': ['him',
#   'me',
#   'you',
#   'is',
#   'for',
#   'you',
#   'them',
#   'it\r\nThee.',
#   'a',
#   'you',
#   'you',
#   'unto',
#   'I',
#   'it',
#   'it',
#   'eternal'],
#  'of\r\nwater': ['springing'],
#  'springing': ['up'],
#  'unto\r\nHim,': ['Sir,', 'He', 'Rabbi,', 'What'],
#  'thirst': ['not'],
#  'come\r\nhither': ['to'],
#  'Go,': ['call', 'wash'],
#  'call': ['thy', 'me'],
#  'thy': ['husband',
#   'husband.',
#   'way.',
#   'bed',
#   'bed.',
#   'bed',
#   'bed',
#   'life',
#   'sword',
#   'son!',
#   'finger,',
#   'hand,',
#   'hands,'],
#  'husband': ['and', 'for'],
#  'come\r\nhither.': ['The'],
#  'husband.': ['Jesus', 'In\r\nthat'],
#  'thou\r\nhast': ['had'],
#  'five': ['husbands.', 'barley', 'and'],
#  'husbands.': ['He'],
#  'now': ['hast',
#   'receiveth\r\nwages',
#   'evening.',
#   'ye',
#   'seeth,',
#   'I',
#   'ye',
#   'put',
#   'I',
#   'on',
#   'I',
#   'they',
#   'I',
#   'ye',
#   'speakest',
#   'believe?',
#   'come,',
#   'accomplished,',
#   'the',
#   'seeing'],
#  'In\r\nthat': ['saidst'],
#  'saidst': ['thou'],
#  'truly.': ['The'],
#  'perceive': ['that\r\nThou'],
#  'prophet.': ['Our', 'And', 'But'],
#  'Our': ['fathers', 'friend', 'abode'],
#  'fathers': ['worshipped', 'ate', 'ate.'],
#  'worshipped': ['in', 'Him.'],
#  'mountain': ['and', 'nor', 'and'],
#  'say\r\nthat': ['in'],
#  'place': ['where',
#   'where',
#   'in',
#   'where',
#   'where',
#   'where',
#   'where',
#   'and',
#   'for',
#   'for',
#   'for',
#   'called',
#   'called',
#   'of',
#   'where\r\nJesus',
#   'where',
#   'by'],
#  'ought': ['to', 'to\r\neat?', 'to', 'to'],
#  'worship.': ['Jesus'],
#  'Woman,': ['believe', 'where', 'behold', 'why', 'why'],
#  'shall,\r\nneither': ['worship'],
#  'worship': ['the', 'because', 'Him.', 'Him', 'at'],
#  'Jerusalem.': ['Ye', 'They'],
#  'worship\r\nye': ['know'],
#  'what.': ['We'],
#  'salvation': ['is'],
#  'cometh,': ['and', 'sitting'],
#  'worshippers': ['shall\r\nworship'],
#  'shall\r\nworship': ['the'],
#  'spirit': ['and', 'and', 'that', 'and\r\nthey', 'and\r\nwas', 'and'],
#  'seeketh\r\nsuch': ['to'],
#  'worship\r\nHim': ['in'],
#  'a\r\nmessias': ['cometh'],
#  'tell\r\nus': ['all'],
#  'things.': ['Jesus', 'He', 'He', 'Thou'],
#  'He.': ['At\r\nthis', 'I', 'Verily,', 'And', 'If'],
#  'At\r\nthis': ['time'],
#  'marvelled': ['that'],
#  'talked': ['with'],
#  'the\r\nwoman.': ['Yet'],
#  'Yet': ['no', 'ye', 'a', 'ye', 'they', 'a', 'Jesus'],
#  'seekest': ['Thou?'],
#  'or,': ['Why'],
#  'talkest': ['Thou'],
#  'her?': ['The'],
#  'her': ['waterpot',
#   'way.',
#   'in',
#   'sister',
#   'sister,',
#   'in',
#   'weeping,\r\nand',
#   'also',
#   'hair.',
#   'alone.',
#   'hour',
#   'joy',
#   'that',
#   'unto'],
#  'waterpot': ['and'],
#  'way.': ['In', 'Thy', 'As', 'Ye', 'This'],
#  'she': ['saith\r\nto',
#   'heard',
#   'had',
#   'went',
#   'heard',
#   'arose',
#   'fell',
#   'kept',
#   'is',
#   'is',
#   'remembereth',
#   'ran',
#   'wept,',
#   'stooped\r\ndown,',
#   'had',
#   'turned',
#   'had'],
#  'men,': ['Come,', 'about\r\nfive'],
#  'Come,': ['see'],
#  'told': ['me',
#   'me',
#   'the',
#   'you',
#   'you',
#   'you',
#   'Jesus.',
#   'you.',
#   'you\r\nbeforehand',
#   'you',
#   'you',
#   'you',
#   'the'],
#  'ever\r\ndid.': ['Is'],
#  'Is': ['not', 'not', 'not', 'it', 'not', 'this', 'it'],
#  'Christ?': ['Then', 'Howbeit'],
#  'came\r\nunto': ['Him.'],
#  'meanwhile': ['His'],
#  'prayed': ['Him,'],
#  'Master,': ['eat.', 'who'],
#  'eat.': ['But\r\nHe', 'Then'],
#  'But\r\nHe': ['said'],
#  'meat': ['to', 'is', 'which'],
#  'eat': ['that', 'of', 'the', 'the'],
#  'of.': ['Therefore\r\nsaid'],
#  'Therefore\r\nsaid': ['the'],
#  'another,': ['Hath', 'doubting'],
#  'Hath': ['any', 'no'],
#  'to\r\neat?': ['Jesus'],
#  'me\r\nand': ['to'],
#  'complete': ['His', 'are'],
#  'work.': ['Say', 'Therefore', 'As'],
#  'Say': ['not', 'ye'],
#  'ye,': ['There', 'that'],
#  'four': ['months', 'days.', 'parts.'],
#  'months': ['and'],
#  'then\r\ncometh': ['harvest?'],
#  'harvest?': ['Behold,'],
#  'Behold,': ['I', 'the', 'the', 'they', 'I'],
#  'Lift': ['up'],
#  'your': ['eyes',
#   'fathers',
#   'time',
#   'law,',
#   'sins.',
#   'father.',
#   'Father',
#   'father',
#   'father',
#   'God,',
#   'son',
#   'sin',
#   'law,',
#   'sakes',
#   'sake.',
#   'Lord',
#   'feet,',
#   'heart',
#   'remembrance.',
#   'heart',
#   'joy',
#   'heart.',
#   'sorrow',
#   'heart',
#   'joy',
#   'law.',
#   'King!',
#   'King?',
#   'Father;',
#   'God.'],
#  'look': ['on\r\nthe', 'for', 'on'],
#  'fields.': ['They'],
#  ...}

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(john_dict)
# Out:
# 'Miracles, but\r\nbecause ye shall have said unto him from the cross. The servant is flesh.'

# %%
matthew_text = data.transcripts.loc['Matthew']
# Create the dictionary for Matthew's gospel, take a look at it
matthew_dict = markov_chain(matthew_text)
matthew_dict
# Out:
# {'Title:': ['The'],
#  'The': ['Gospel',
#   'Gospel',
#   'answer',
#   'Gospel',
#   'first',
#   'wise',
#   'angel',
#   'voice',
#   'same',
#   'axe',
#   'devil',
#   'light',
#   'centurion',
#   'foxes',
#   'disciples',
#   'devils',
#   'herders',
#   'day',
#   'woman',
#   'maid',
#   'multitude',
#   'disciple',
#   'very',
#   'blind',
#   'lame',
#   'lepers',
#   'deaf',
#   'man',
#   'men',
#   'queen',
#   'disciples',
#   'understanding',
#   'kingdom',
#   'householder\r\nanswered,',
#   'servants',
#   'kingdom',
#   'kingdom',
#   'good',
#   'enemy',
#   'harvest',
#   'reapers',
#   'Son',
#   'good',
#   'angels',
#   'people\r\nwere',
#   'multitude',
#   'disciples',
#   'gates',
#   'Son',
#   'disciples',
#   'Son',
#   'disciples',
#   'Son',
#   'kingdom',
#   'servant',
#   'fellowservant',
#   'Pharisees',
#   'two',
#   'young',
#   'young',
#   'mother',
#   'Lord',
#   'disciples',
#   'multitude',
#   'blind',
#   'fig',
#   'things',
#   'chief',
#   'son',
#   'second',
#   'first',
#   'publicans',
#   'husbandsmen',
#   'stone',
#   'kingdom',
#   "king's\r\noxen",
#   'wedding',
#   'king',
#   'man\r\nmade',
#   'same',
#   'son',
#   'moon',
#   'stars',
#   'powers',
#   'coming',
#   'lord',
#   'foolish',
#   'foolish',
#   'kingdom',
#   'servant',
#   'unprofitable',
#   'King',
#   'Son',
#   'poor',
#   'disciples\r\nheard',
#   'Son',
#   'one\r\nwho',
#   'chief',
#   'high',
#   'Field',
#   'custom',
#   'governor',
#   'people',
#   'King',
#   'Jews.',
#   'chief',
#   'rest\r\nsaid,',
#   'bodies\r\nof',
#   'next',
#   'chief',
#   'guards',
#   'angel',
#   'women',
#   'eleven',
#   'Gospel'],
#  'Gospel': ['of', 'of', 'of', 'of', 'of'],
#  'of': ['Matthew',
#   'Matthew',
#   'the\r\nGospel',
#   'Matthew,',
#   'information',
#   'the',
#   'Matthew\r\nholds',
#   'the',
#   'Matthew',
#   'Jesus',
#   'other',
#   'Jesus',
#   'the',
#   'David,',
#   'the',
#   'the',
#   'the',
#   'Judaea,',
#   'King',
#   'the',
#   'Judaea.',
#   'Juda,',
#   'Juda,',
#   'gold,',
#   'the',
#   'Herod.',
#   'Egypt',
#   'the',
#   'Israel.',
#   'his',
#   'Judaea.',
#   'heaven',
#   'by',
#   'one',
#   'the',
#   'the',
#   'vipers,',
#   'the',
#   'the',
#   'God',
#   'God,',
#   'God.',
#   'the',
#   'God,\r\ncast',
#   'the',
#   'Zabulon',
#   'Nephthalim',
#   'death,',
#   'repentance',
#   'God',
#   'Galilee,',
#   'men.\r\n\r\nThey',
#   'the\r\nkingdom,',
#   'sickness',
#   'people',
#   'heaven.',
#   'heart',
#   'God.',
#   'heaven.\r\nBlessed',
#   'the',
#   'the\r\nprophets.',
#   'these',
#   'heaven.',
#   'the\r\nscribes',
#   'old',
#   'the',
#   'the',
#   'the\r\ncouncil.',
#   'hell',
#   'old,',
#   'thy',
#   'thy',
#   'fornication,',
#   'old,',
#   'the',
#   'making',
#   'thee.',
#   'thee,',
#   'your',
#   'men.',
#   'the',
#   'the',
#   'light.',
#   'darkness.',
#   'the',
#   'you,',
#   'the',
#   'them.',
#   'the',
#   'little',
#   'God',
#   'itself.\r\nThe',
#   'today',
#   'you',
#   'the',
#   'false',
#   'heaven.',
#   'my',
#   'authority,\r\nunderstand',
#   'heaven.',
#   'the',
#   'teeth.',
#   'the',
#   'the',
#   'man',
#   'little',
#   'man',
#   'the',
#   'the',
#   'God?',
#   'swine.',
#   'swine.',
#   'the',
#   'swine',
#   'good',
#   'the',
#   'man',
#   'custom.',
#   'the',
#   'new',
#   'blood',
#   'His',
#   'this.',
#   'the',
#   'the',
#   'sickness',
#   'the',
#   'Zebedee,',
#   'Alphaeus;\r\n\r\nLebbaeus,',
#   'the',
#   'the',
#   'Israel.',
#   'his',
#   'Sodom',
#   'wolves.',
#   'men.',
#   'me.',
#   'your',
#   'all',
#   "God's\r\nhousehold?",
#   'them',
#   'your',
#   'more',
#   'his',
#   'me.',
#   'me.',
#   'me.',
#   'a',
#   'a',
#   'the',
#   'cold',
#   'a',
#   'Christ,',
#   'his',
#   'whom',
#   'woman',
#   'heaven.',
#   'John',
#   'heaven',
#   'John.',
#   'man',
#   'publicans',
#   'her',
#   'His',
#   'judgment',
#   'Sodom',
#   'judgment',
#   'heaven',
#   'corn',
#   'God\r\nand',
#   'man',
#   'the',
#   'the',
#   'God,',
#   'God',
#   'sin',
#   'man,',
#   'vipers,',
#   'the',
#   'the\r\ngood',
#   'the',
#   'the',
#   'judgment.',
#   'the',
#   'the\r\nprophet',
#   'man',
#   'the',
#   'Nineveh',
#   'this',
#   'Jonas.\r\nBehold,',
#   'the',
#   'this',
#   'the',
#   'that',
#   'my',
#   'the',
#   'the\r\nkingdom',
#   'heaven,',
#   'Esaias:',
#   'the',
#   'the',
#   'this',
#   'riches.',
#   'the',
#   'heaven',
#   'heaven',
#   'all',
#   'the',
#   'heaven',
#   'meal',
#   'the',
#   'the',
#   'man.\r\nThe',
#   'the',
#   'the',
#   'the',
#   'this',
#   'man',
#   'His',
#   'teeth.',
#   'their',
#   'heaven',
#   'heaven',
#   'great\r\nprice,',
#   'heaven',
#   'fish.',
#   'the',
#   'teeth.',
#   'heaven',
#   'his\r\ntreasure',
#   'their',
#   'the',
#   'Jesus.',
#   'Herodia,',
#   'the\r\ncities.',
#   'Him',
#   'the',
#   'the',
#   'good',
#   'the',
#   'little',
#   'Gennesaret.',
#   'Him,',
#   'His',
#   'the',
#   'God',
#   'God',
#   'the\r\nmouth',
#   'the',
#   'the',
#   'the',
#   'Tyre',
#   'Canaan\r\ncame',
#   'David.',
#   'the',
#   'Galilee',
#   'Israel.',
#   'the',
#   'the',
#   'the\r\nprophet,',
#   'the',
#   'the',
#   'little',
#   'leftovers',
#   'leftovers',
#   'the',
#   'the',
#   'the',
#   'Caesarea',
#   'man,',
#   'the',
#   'the',
#   'hell',
#   'the',
#   'heaven.',
#   'the\r\nelders,',
#   'God,',
#   'men.',
#   'man\r\nshall',
#   'His',
#   'man',
#   'man',
#   'them.',
#   'the',
#   'your',
#   'a',
#   'mustard',
#   'devil',
#   'men.',
#   'the',
#   'strangers?',
#   'heaven?',
#   'them,',
#   'heaven.',
#   'heaven.',
#   'these',
#   'the',
#   'offences!',
#   'these\r\nlittle',
#   'my',
#   'man',
#   'them',
#   'these',
#   'two',
#   'you',
#   'them.',
#   'heaven',
#   'his\r\nservants.',
#   'that',
#   'his',
#   'me.',
#   'Judaea',
#   'divorcement',
#   'the',
#   'your',
#   'the',
#   "heaven's",
#   'such',
#   'heaven.',
#   'heaven.',
#   'God.',
#   'man\r\nshall',
#   'His',
#   'Israel.',
#   'heaven',
#   'the',
#   'the',
#   'us\r\nwho',
#   'the',
#   'them',
#   'the',
#   'Zebedee',
#   'Him.',
#   'the\r\ncup',
#   'worldliness',
#   'man',
#   'David.',
#   'David.',
#   'the',
#   'Sion,\r\nBehold,',
#   'an',
#   'David.',
#   'Galilee.',
#   'God',
#   'the',
#   'those',
#   'prayer;',
#   'thieves.',
#   'the\r\nmouth',
#   'babes',
#   'the\r\npeople',
#   'John',
#   'these',
#   'his',
#   'God',
#   'righteousness\r\nand',
#   'the\r\nharvest',
#   'it.',
#   'the',
#   'the',
#   'God',
#   'laying',
#   'heaven',
#   'it',
#   'teeth,',
#   'their',
#   'God',
#   'the',
#   'God',
#   'Abraham,',
#   'Jacob?',
#   'the',
#   'the\r\nliving.',
#   'them,',
#   'Christ?',
#   'David.',
#   'heaven,',
#   'hell',
#   'the',
#   'praise.',
#   'God',
#   'mint\r\nand',
#   'the\r\nlaw;',
#   'extortion',
#   'hypocrisy',
#   'the',
#   'our',
#   'the',
#   'those',
#   'vipers,',
#   'them',
#   'them',
#   'righteous',
#   'Zacharias,',
#   'Barachias,',
#   'the\r\nLord.',
#   'all',
#   'Olives,',
#   'Thy',
#   'the',
#   'wars.',
#   'sorrows.',
#   'many',
#   'the',
#   'desolation',
#   'by',
#   'his',
#   'the\r\neast',
#   'the\r\nSon',
#   'man.',
#   'those',
#   'the',
#   'the',
#   'man',
#   'heaven',
#   'a',
#   'heaven',
#   'the',
#   'heaven,',
#   'the',
#   'man',
#   'Noah.',
#   'the',
#   'man.',
#   'the',
#   'man',
#   'that',
#   'teeth.',
#   'heaven',
#   'them',
#   'your',
#   'man',
#   'heaven',
#   'thy',
#   'thy',
#   'teeth.',
#   'man',
#   'His',
#   'my\r\nFather.',
#   'the\r\nworld.',
#   'the',
#   'the',
#   'my',
#   'the',
#   'man\r\n\r\nwill',
#   'the',
#   'the',
#   'Simon',
#   'the',
#   'silver',
#   'the',
#   'unleavened',
#   'you',
#   'man',
#   'the',
#   'sins.',
#   'this',
#   'the',
#   'Olives.',
#   'me',
#   'the',
#   'thee,',
#   'Zebedee',
#   'man',
#   'sinners.',
#   'the',
#   'the',
#   'Jesus.',
#   'angels?',
#   'me.',
#   'Jesus,',
#   'God',
#   'God.',
#   'man',
#   'power',
#   'heaven.',
#   'witnesses?',
#   'death.',
#   'their',
#   'Galilee.',
#   'Nazareth.',
#   'the',
#   'them.',
#   'Jesus',
#   'silver',
#   'silver',
#   'strangers,',
#   'Blood.',
#   'Jeremy',
#   'the',
#   'Israel,\r\nand',
#   'the',
#   'the',
#   'Him.',
#   'the',
#   'the\r\nblood',
#   'this',
#   'thorns',
#   'the',
#   'Cyrene,',
#   'a',
#   'God,',
#   'God.',
#   'those',
#   'them',
#   'the',
#   'God.',
#   'the',
#   'Galilee',
#   "Zebedee's",
#   'Jesus.',
#   'rock.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Him',
#   'the',
#   'the',
#   'money',
#   'the',
#   'the',
#   'the',
#   'Project',
#   'Matthew'],
#  'Matthew': ['for', 'for', 'is', 'for'],
#  'for': ['Readers',
#   'Readers',
#   'us?',
#   'easy',
#   'we',
#   'Herod',
#   'her\r\nchildren',
#   'the',
#   'repentance.',
#   'our',
#   'repentance',
#   'it',
#   'it',
#   'they\r\nshall',
#   'they',
#   'they',
#   'they',
#   "righteousness'",
#   'theirs',
#   'my',
#   'thee',
#   'thee',
#   'anything',
#   'an',
#   'a',
#   'those',
#   'their',
#   'yourselves',
#   'your',
#   'raiment?',
#   'the',
#   'the',
#   'today.',
#   'with',
#   'a',
#   'a',
#   'the',
#   'that',
#   'twelve\r\nyears',
#   'the',
#   'that',
#   'a',
#   "my\r\nname's",
#   'the',
#   'a',
#   'my\r\nsake',
#   'another?',
#   'Tyre',
#   'you.',
#   'the\r\nland',
#   'thee.',
#   'it',
#   'your',
#   'him',
#   'the',
#   'the',
#   'fear\r\nthey',
#   'they',
#   'they',
#   'a',
#   'the',
#   'fear.',
#   'she',
#   'the',
#   'the',
#   'the',
#   'flesh',
#   'my',
#   'his',
#   'us',
#   'thee,',
#   'Moses,',
#   'me',
#   'him',
#   'thee',
#   'I',
#   'them',
#   'a',
#   'every',
#   'the',
#   'of',
#   'a',
#   'a',
#   'my',
#   'his',
#   'a',
#   'a',
#   'me',
#   'many',
#   'whom',
#   'many.',
#   'you?',
#   'they',
#   'a',
#   'his',
#   'many',
#   'show',
#   'only',
#   'only\r\none',
#   'a',
#   'one',
#   "my\r\nname's",
#   'the',
#   'ye',
#   'our',
#   'us',
#   'ye',
#   'you',
#   'the',
#   'much',
#   'my',
#   'thee',
#   'him',
#   'this',
#   'this',
#   'many',
#   'the',
#   'it',
#   'the\r\nburial',
#   'Him',
#   'the',
#   'the',
#   'Jesus.',
#   'He\r\nsaid,',
#   'the',
#   'I',
#   'Readers,'],
#  'Readers': ['Editor:', "Editor's"],
#  'Editor:': ['Lightheart'],
#  'Lightheart': ['Release'],
#  'Release': ['date:'],
#  'date:': ['May'],
#  'May': ['1,'],
#  '1,': ['2004'],
#  '2004': ['[eBook'],
#  '[eBook': ['#6356]\r\n'],
#  '#6356]\r\n': [''],
#  '': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Most',
#   'to',
#   'Behold',
#   'But',
#   'but\r\nhe',
#   'wise'],
#  'Most': ['recently'],
#  'recently': ['updated:'],
#  'updated:': ['August'],
#  'August': ['21,'],
#  '21,': ['2012'],
#  '2012': ['Language:'],
#  'Language:': ['English'],
#  'English': ['Copyright'],
#  'Copyright': ['(C)'],
#  '(C)': ['2002'],
#  '2002': ['by'],
#  'by': ['Lightheart.',
#   'Lightheart\r\nPracticeGodsPresence.com',
#   'the',
#   'the',
#   'God',
#   'another\r\nway.',
#   'night,',
#   'the',
#   'the',
#   'the',
#   'Jeremy\r\nthe',
#   'God',
#   'the',
#   'the',
#   'him,',
#   'thee.\r\nJesus',
#   'the',
#   'bread',
#   'every',
#   'Esaias',
#   'the',
#   'the',
#   'them',
#   'them',
#   'heaven',
#   'Jerusalem',
#   'thy',
#   'others.',
#   'worrying,',
#   'saying,',
#   'their',
#   'their',
#   'Esaias',
#   'the',
#   'the',
#   'Him.',
#   'force.\r\nAll',
#   'my',
#   'a',
#   'Esaias',
#   'Beelzebub,',
#   'Beelzebub,',
#   'whom',
#   'its',
#   'saying,',
#   'the',
#   'the',
#   'seeing',
#   'the',
#   'things',
#   'the',
#   'Him.',
#   'her',
#   'boat',
#   'your',
#   'whatever',
#   'me,\r\ndishonoring',
#   'my',
#   'prayer',
#   'whom',
#   'my',
#   'the',
#   'men.',
#   'my',
#   'the',
#   'what',
#   'what',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'all',
#   'the',
#   'it',
#   'Him',
#   'the',
#   'Him',
#   'all',
#   'the',
#   'stealth',
#   'a',
#   'whom',
#   'the',
#   'the',
#   'thy\r\nvoice',
#   'the',
#   'name,',
#   'casting',
#   'they',
#   'heard',
#   'night,',
#   'sealing',
#   'the\r\nfeet,',
#   'night',
#   'Lightheart\r\nPracticeGodsPresence.com',
#   'Lightheart'],
#  'Lightheart.': ['The'],
#  "Editor's": ['Preface'],
#  'Preface': ['What'],
#  'What': ['is',
#   'shall',
#   'shall',
#   'kind',
#   'have',
#   'I',
#   'went',
#   'went',
#   'man\r\nis',
#   'is',
#   'can',
#   'think\r\nthou,',
#   'God',
#   'shall\r\nwe',
#   'wilt',
#   'shall',
#   'is',
#   'is',
#   'shall',
#   'will',
#   'further',
#   'is\r\nthat',
#   'shall'],
#  'is': ["God's",
#   'designed',
#   'conceived',
#   'of',
#   'He',
#   'written',
#   'at',
#   'the\r\none',
#   'now\r\nlaid',
#   'hewn',
#   'in',
#   'my',
#   'written,',
#   'written,',
#   'written,',
#   'sprung',
#   'at',
#   'the',
#   'the',
#   'your',
#   'good\r\nfor',
#   'set',
#   'fulfilled.',
#   'no',
#   'angry',
#   'in',
#   'paid.',
#   'more',
#   'more\r\nprofitable',
#   'divorced',
#   "God's",
#   'His',
#   'the',
#   'perfect.',
#   'in',
#   'the',
#   'in\r\nsecret,',
#   'the',
#   'in',
#   'here',
#   'cast',
#   'in',
#   'holy',
#   'there',
#   'the',
#   'the',
#   'the',
#   'strait\r\nand',
#   'narrow,',
#   'hewn\r\ndown',
#   'this',
#   'with',
#   'almost',
#   'not',
#   'plenteous,',
#   'called',
#   'at',
#   'worthy',
#   'worthy.',
#   'worthy,',
#   'not',
#   'not',
#   'not',
#   'enough',
#   'nothing',
#   'able',
#   'not',
#   'not',
#   'not',
#   'he,',
#   'more',
#   'he',
#   'written:',
#   'Elias,',
#   'like',
#   'a',
#   'so,',
#   'easy',
#   'not',
#   'one',
#   'Lord\r\neven',
#   'lawful',
#   'well',
#   'brought',
#   'divided',
#   'come',
#   'he',
#   'not',
#   'against',
#   'known',
#   'so',
#   'here.',
#   'here.',
#   'worse',
#   'how',
#   'my',
#   'my',
#   'given',
#   'not',
#   'fulfilled',
#   'uprooted.',
#   'too',
#   'choked',
#   'he',
#   'like',
#   'to',
#   'like',
#   'the\r\nleast',
#   'grown,',
#   'the',
#   'like',
#   'the',
#   'the',
#   'the',
#   'like',
#   'like\r\na',
#   'like',
#   'instructed',
#   'like',
#   'not\r\nwithout',
#   'John',
#   'risen',
#   'a',
#   'a',
#   'expelled.\r\nBut',
#   'grievously',
#   'not',
#   'thy',
#   'evening,\r\nye',
#   'red.',
#   'red.',
#   'a',
#   'it',
#   'in',
#   'a',
#   'good',
#   'my',
#   'lunatic',
#   'the\r\ngreatest',
#   'greatest',
#   'better\r\nfor',
#   'here',
#   'gone',
#   'not',
#   'like',
#   'put',
#   'given.',
#   'able',
#   'God.',
#   'easier',
#   'like',
#   'right',
#   'thine',
#   'not',
#   'prepared',
#   'He',
#   'this?',
#   'written',
#   'the',
#   'the',
#   'marvellous',
#   'like',
#   'prepared.',
#   'ready.',
#   'ready,',
#   'this?',
#   'no',
#   'not',
#   'the',
#   'the',
#   'like',
#   'He?',
#   'he',
#   'your',
#   'in',
#   'your',
#   'greatest',
#   'made,',
#   'worth',
#   'greater,',
#   'worth',
#   'upon',
#   'worthy',
#   'greater,',
#   'inside',
#   'left',
#   'He',
#   'not',
#   'in',
#   'Christ,',
#   'in',
#   'in',
#   'yet',
#   'near.',
#   'near.',
#   'a',
#   'that\r\nservant',
#   'an',
#   'unaware,',
#   'likened',
#   'coming.',
#   'like',
#   'thine.',
#   'the',
#   'at',
#   'written:',
#   'betrayed!',
#   'it',
#   'my',
#   'shed',
#   'written:',
#   'exceedingly',
#   'weak.',
#   'betrayed',
#   'at',
#   'He.',
#   'the',
#   'guilty',
#   'he',
#   'not',
#   'blood\r\nmoney.',
#   'called\r\n\r\nChrist?',
#   'the',
#   'not',
#   'risen.',
#   'risen',
#   'common',
#   'given'],
#  "God's": ['will', 'throne.'],
#  'will': ['for',
#   'save',
#   'seek\r\nthe',
#   'give',
#   'bow',
#   'make',
#   'be',
#   'also\r\nforgive',
#   'be',
#   'either',
#   'hold',
#   'give',
#   'give',
#   'of',
#   'say',
#   'I',
#   'come',
#   'follow',
#   'perish.',
#   'have',
#   'come',
#   'be\r\ntaken',
#   'fast.',
#   'send',
#   'deliver',
#   'scourge',
#   'be',
#   'speak,',
#   'confess',
#   'deny',
#   'set',
#   'receive',
#   'reveal',
#   'give',
#   'not',
#   'put',
#   'of',
#   'be',
#   'say',
#   'open\r\nmy',
#   'utter',
#   'not',
#   'be',
#   'be',
#   'build\r\nmy',
#   'give\r\nthee',
#   'come',
#   'of\r\nyour',
#   'hear',
#   'not',
#   'pay',
#   'pay',
#   'be',
#   'give',
#   'with',
#   'deliver',
#   'be',
#   'be',
#   'send',
#   'ask',
#   'tell',
#   'not.',
#   'go,',
#   'of',
#   'respect',
#   'he',
#   'destroy',
#   'rent',
#   'render',
#   'be',
#   'not',
#   'these\r\nthings',
#   'deliver',
#   'be',
#   'betray',
#   'wax',
#   'never',
#   'show',
#   'deceive',
#   'be\r\ndarkened.',
#   'not',
#   'fall',
#   'appear.',
#   'gather',
#   'not',
#   'come.',
#   'be',
#   'make',
#   'ye',
#   'deliver',
#   'keep\r\nthe',
#   'not',
#   'smite',
#   'go',
#   'not',
#   'be',
#   'ye',
#   'believe',
#   'have',
#   'come',
#   'be'],
#  'us?': ['The', 'Where', 'So'],
#  'answer': ['can', 'a', 'them,'],
#  'can': ['be',
#   'serve',
#   'you',
#   'make',
#   'someone',
#   'ye,',
#   'come\r\nand',
#   'discern',
#   'a',
#   'be',
#   'ye'],
#  'be': ['found',
#   'found',
#   'fulfilled:',
#   'with',
#   'born.',
#   'fulfilled',
#   'slayed.',
#   'comforted',
#   'called',
#   'baptized',
#   'baptized',
#   'so',
#   'tempted',
#   'the',
#   'made',
#   'the',
#   'fulfilled:',
#   'comforted.',
#   'filled.',
#   'called',
#   'exceedingly',
#   'cast',
#   'hidden.',
#   'put',
#   'called',
#   'called',
#   'in',
#   'in',
#   'in',
#   'cast',
#   'cast',
#   'cast',
#   'only',
#   'the',
#   'ye',
#   'seen',
#   'like',
#   'seen.',
#   'heard',
#   'Thy',
#   'done',
#   'single,',
#   'full',
#   'evil,',
#   'full',
#   'that',
#   'clothed?',
#   'added',
#   'not',
#   'judged.',
#   'measured',
#   'given',
#   'opened',
#   'healed.',
#   'cast',
#   'weeping',
#   'it',
#   'fulfilled',
#   'of',
#   'forgiven',
#   'it',
#   'given',
#   'aware',
#   'put',
#   'hated',
#   'saved.',
#   'as\r\nhis',
#   'revealed;',
#   'known.',
#   'those',
#   'offended',
#   'more',
#   'brought',
#   'more',
#   'your',
#   'forgiven,',
#   'forgiven.',
#   'forgiven',
#   'forgiven\r\nHim;',
#   'justified',
#   'condemned.',
#   'no',
#   'three',
#   'with',
#   'given',
#   'taken\r\naway',
#   'converted',
#   'fulfilled',
#   'wailing',
#   'at',
#   'wailing',
#   'given',
#   'thou,',
#   'put',
#   'free.',
#   'fair',
#   'foul',
#   'no',
#   'bound',
#   'loosed',
#   'killed',
#   'it',
#   'here.',
#   'betrayed',
#   'raised',
#   'that',
#   'cast',
#   'cast',
#   'treated',
#   'bound',
#   'loosed',
#   'sold,',
#   'made.',
#   'one?\r\nTherefore,',
#   'for\r\nfornication,',
#   'so',
#   'perfect,',
#   'saved?',
#   'last;',
#   'first.',
#   'first,',
#   'betrayed',
#   'baptized',
#   'baptized',
#   'so',
#   'great',
#   'chief',
#   'your\r\nservant.',
#   'ministered',
#   'opened.',
#   'fulfilled:',
#   'done.',
#   'taken',
#   'broken.\r\nOn',
#   'ground',
#   'of',
#   'borne,',
#   'called',
#   'ye',
#   'ye',
#   'your',
#   'abased;\r\nand',
#   'humbled',
#   'exalted.',
#   'clean',
#   'the',
#   'thrown',
#   'the',
#   'famines,\r\npestilence,',
#   'hated',
#   'offended',
#   'saved.',
#   'preached',
#   'not',
#   'great',
#   'seen',
#   'saved.',
#   'numbered.',
#   'the',
#   'shaken.',
#   'like',
#   'in',
#   'taken',
#   'grinding',
#   'taken\r\nand',
#   'broken',
#   'ready.',
#   'weeping\r\nand',
#   'not',
#   'given,',
#   'taken',
#   'cast',
#   'weeping',
#   'gathered',
#   'betrayed',
#   'an',
#   'told',
#   'offended',
#   'scattered',
#   'offended',
#   'offended.',
#   'possible,',
#   'it',
#   'done.\r\nReturning',
#   'fulfilled',
#   'fulfilled.',
#   'crucified.\n',
#   'crucified.',
#   'crucified.',
#   'crucified,\r\nthey',
#   'the',
#   'made',
#   'worse',
#   'protected'],
#  'found': ['in',
#   'at',
#   'with',
#   'Him',
#   'such',
#   'others',
#   'nothing\r\non',
#   'them',
#   'that',
#   'a'],
#  'in': ['the',
#   'chapter',
#   'a',
#   'her',
#   'Bethlehem',
#   'the',
#   'the',
#   'the',
#   'a',
#   'Bethlehem',
#   'a',
#   'the',
#   'a',
#   'a',
#   'the',
#   'His',
#   'whom',
#   'their',
#   'all',
#   'Capernaum',
#   'darkness',
#   'the',
#   'a',
#   'the',
#   'spirit',
#   'heaven.',
#   'the',
#   'heaven.',
#   'the',
#   'the',
#   'danger',
#   'danger',
#   'danger',
#   'danger',
#   'lust',
#   'his',
#   'heaven.',
#   'heaven',
#   'heaven.',
#   'the',
#   'the',
#   'secret',
#   'secret,',
#   'the',
#   'the',
#   'secret.',
#   'secret,',
#   'heaven,',
#   'heaven.',
#   'and',
#   'heaven,',
#   'and',
#   'thee',
#   'all',
#   'thy',
#   'thine',
#   'heaven',
#   'at',
#   'that',
#   "sheep's",
#   'heaven\r\nshall',
#   'thy',
#   'Capernaum,',
#   'Israel.',
#   'the\r\nkingdom',
#   'a',
#   'the',
#   'the',
#   'your',
#   'to',
#   'Israel.',
#   'their',
#   'your',
#   'it',
#   'the',
#   'the',
#   'their',
#   'one',
#   'darkness,',
#   'light.',
#   'the',
#   'heaven.',
#   'heaven.',
#   'the',
#   'the',
#   'their',
#   'prison,',
#   'me.',
#   'soft',
#   "kings'",
#   'the\r\nkingdom',
#   'you',
#   'Tyre',
#   'sackcloth\r\nand',
#   'Capernaum',
#   'Sodom,',
#   'the',
#   'thy\r\nsight.',
#   'heart.\r\nYe',
#   'the',
#   'whom',
#   'the',
#   'His',
#   'this',
#   'the',
#   'the',
#   "the\r\nwhale's",
#   'judgment',
#   'the',
#   'parables.',
#   'parables?',
#   'parables',
#   'them',
#   'his',
#   'the\r\ngood',
#   'his',
#   'the',
#   'bundles.',
#   'the',
#   'his',
#   'its',
#   'three',
#   'parables',
#   'parables.',
#   'the',
#   'the',
#   'the',
#   'a',
#   'the',
#   'His',
#   'His',
#   'him.\n',
#   'prison.',
#   'addition',
#   'the',
#   'the\r\nboat',
#   'at',
#   'the',
#   'heaven.',
#   'heaven.',
#   'heaven.',
#   'exchange',
#   'the',
#   'His',
#   'whom',
#   'Galilee,',
#   'the',
#   'the',
#   'the',
#   'my',
#   'me,',
#   'heaven',
#   'the',
#   'heaven.',
#   'heaven.',
#   'heaven.',
#   'my',
#   'the',
#   'heaven.\r\nThen',
#   'the',
#   'the\r\nmorning',
#   'the\r\nmarketplace.',
#   'my',
#   'thy',
#   'the',
#   'the',
#   'the',
#   'the',
#   'prayer,',
#   'turn,',
#   'my',
#   'the',
#   'it,',
#   'the',
#   'our',
#   'to',
#   'here',
#   'His\r\nwords.',
#   'truth.',
#   'marriage,\r\nbut',
#   'heaven.',
#   'the',
#   'spirit,',
#   "Moses'",
#   'the',
#   'the',
#   'heaven.',
#   'yourselves,',
#   'the',
#   'the',
#   'your',
#   'the',
#   'divers',
#   'Judaea',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'what',
#   'due',
#   'a',
#   'their',
#   'with',
#   'the',
#   'prison',
#   'prison',
#   'prison',
#   'prison,',
#   'the',
#   'Bethany',
#   'the',
#   'the',
#   'my',
#   'to',
#   'the\r\ntemple',
#   'and',
#   'order',
#   'three',
#   'the',
#   'His\r\nface.',
#   'the',
#   'the',
#   'a',
#   'His',
#   'three',
#   'God.',
#   'a',
#   'two',
#   'a',
#   'his',
#   'three',
#   'heaven',
#   'the'],
#  'the': ['pages',
#   'Son',
#   'old.',
#   'new',
#   'new',
#   'keys',
#   'kingdom',
#   'Gospel',
#   'birth',
#   'geneological',
#   'beginning',
#   'Lord',
#   'Holy',
#   'Lord',
#   'prophet\r\nmight',
#   'angel',
#   'Lord',
#   'days',
#   'east',
#   'Jews',
#   'east',
#   'chief',
#   'prophet:',
#   'land',
#   'least',
#   'princes',
#   'wise',
#   'time',
#   'star',
#   'young',
#   'king',
#   'star',
#   'east',
#   'young',
#   'star',
#   'place\r\nand',
#   'young',
#   'Lord',
#   'young',
#   'young',
#   'Lord',
#   'prophet:',
#   'wise',
#   'children',
#   'coasts',
#   'wise',
#   'sound',
#   'Lord',
#   'young',
#   'land',
#   "young\r\nchild's",
#   'young',
#   'way',
#   'place',
#   'prophets:',
#   'Baptist',
#   'wilderness',
#   'kingdom',
#   'prophet',
#   'wilderness,',
#   'way',
#   'Lord.',
#   'region',
#   'Pharisees',
#   'wrath',
#   'root',
#   'trees.',
#   'fire.',
#   'Holy',
#   'fire',
#   'garner.',
#   'chaff',
#   'water',
#   'heavens\r\nopened',
#   'Spirit',
#   'Spirit',
#   'wilderness',
#   'Son',
#   'holy',
#   'temple.',
#   'Son',
#   'Lord',
#   'devil',
#   'kingdoms',
#   'world',
#   'Lord',
#   'devil\r\nleft',
#   'sea',
#   'borders',
#   'prophet',
#   'land',
#   'land',
#   'sea,',
#   'Gentiles,',
#   'people',
#   'region',
#   'sea',
#   'son',
#   'synagogues,',
#   'gospel',
#   'multitudes,',
#   'poor',
#   'kingdom',
#   'meek',
#   'merciful',
#   'peacemakers',
#   'children',
#   'kingdom',
#   'salt',
#   'earth.',
#   'salt',
#   'light',
#   'house.',
#   'law',
#   'words',
#   'law',
#   'kingdom',
#   'kingdom',
#   'righteousness',
#   'kingdom',
#   'judgment.',
#   'judgment.\r\nWhoever',
#   'altar',
#   'gift',
#   'altar.',
#   'judge,',
#   'judge\r\ndeliver',
#   'officer,',
#   'Lord.',
#   'earth',
#   'city',
#   'great',
#   'children',
#   'evil',
#   'good.',
#   'just',
#   'unjust.',
#   'publicans',
#   'publicans',
#   'synagogues',
#   'streets',
#   'glory',
#   'hypocrites.',
#   'synagogues',
#   'corners',
#   'streets',
#   'heathen.',
#   'kingdom,',
#   'power,',
#   'glory,',
#   'hypocrites.',
#   'body',
#   'eye.',
#   'light',
#   'one',
#   'one',
#   'other.',
#   'body',
#   'fowls',
#   'air.',
#   'lilies',
#   'field',
#   'grass',
#   'field,',
#   'oven,',
#   'kingdom',
#   'morrow,',
#   'morrow',
#   'mote',
#   'beam',
#   'mote',
#   'beam',
#   'mote',
#   'law',
#   'meaning',
#   'prophets.',
#   'strait',
#   'gate',
#   'way',
#   'gate',
#   'way',
#   'fire.',
#   'will',
#   'rain',
#   'floods\r\ncame,',
#   'winds',
#   'house,',
#   'sand.',
#   'rain',
#   'winds',
#   'mountain,',
#   'priest',
#   'gift',
#   'word',
#   'east',
#   'children',
#   'kingdom',
#   'centurion,',
#   'servant',
#   'fever',
#   'spirits',
#   'prophet:',
#   'water.',
#   'birds',
#   'air',
#   'Son',
#   'dead\r\nbury',
#   'other\r\nside.',
#   'sea.',
#   'waves.',
#   'sea.',
#   'winds',
#   'sea',
#   'other',
#   'country',
#   'Gergesenes.',
#   'tombs',
#   'time?',
#   'herd',
#   'men,',
#   'herd',
#   'whole',
#   'sea',
#   'waters.',
#   'city',
#   'devils.',
#   'whole',
#   'scribes',
#   'Son',
#   'sick',
#   'multitude',
#   'receipt',
#   'Pharisees',
#   'righteous,',
#   'children',
#   'bridechamber',
#   'bridegroom',
#   'space',
#   'garment',
#   'rent',
#   'wine',
#   'bottles',
#   'way,',
#   'hem',
#   "ruler's",
#   'people',
#   'hand,',
#   'blind',
#   'devil',
#   'man',
#   'Pharisees',
#   'devils.',
#   'cities',
#   'gospel',
#   'kingdom.',
#   'people.',
#   'crowds,',
#   'laborers',
#   'twelve',
#   'son',
#   'publican;',
#   'son',
#   'Canaanite;',
#   'way\r\nof',
#   'Gentiles',
#   'Samaritans.',
#   'house',
#   'kingdom',
#   'sick.',
#   'lepers.',
#   'dead.\r\nCast',
#   'house',
#   'dust',
#   'land',
#   'day',
#   'midst',
#   'councils.',
#   'time',
#   'Spirit',
#   'child.',
#   'end',
#   'cities',
#   'Son',
#   'disciple',
#   'servant',
#   'master\r\nof',
#   'house,',
#   'ear,',
#   'body',
#   'name',
#   'little\r\nones',
#   'name',
#   'works',
#   'poor',
#   'gospel',
#   'crowds',
#   'wilderness',
#   'way',
#   'Baptist',
#   'days',
#   'Baptist',
#   'violent',
#   'prophets',
#   'law',
#   'cities',
#   'mighty',
#   'day',
#   'mighty',
#   'day',
#   'wise',
#   'Son',
#   'Father',
#   'Son.',
#   'Son',
#   'Pharisees',
#   'sabbath',
#   'house',
#   'showbread.',
#   'bread',
#   'priests.',
#   'law',
#   'sabbath',
#   'priests',
#   'sabbath',
#   'temple.',
#   'guiltless',
#   'Son',
#   'sabbath',
#   'synagogue',
#   'Pharisees',
#   'sabbath',
#   'man',
#   'Pharisees',
#   'prophet:',
#   'Gentiles.',
#   'streets.',
#   'Gentiles',
#   'people',
#   'son',
#   'Pharisees',
#   'prince',
#   'devils.',
#   'kingdom',
#   'strong',
#   'Holy',
#   'Son',
#   'Holy',
#   'world',
#   'tree',
#   'tree',
#   'abundance',
#   'heart',
#   'mouth',
#   'heart,',
#   'evil',
#   'heart,',
#   'day',
#   'scribes',
#   'sign',
#   'Son',
#   'heart',
#   'earth.',
#   'preaching',
#   'south',
#   'judgment',
#   'uttermost',
#   'earth',
#   'wisdom',
#   'unclean',
#   'house',
#   'man',
#   'last',
#   'first.',
#   'people,',
#   'one',
#   'will',
#   'sea.',
#   'whole',
#   'wayside',
#   'birds',
#   'sun',
#   'seeds',
#   'mysteries',
#   'prophecy',
#   "people's",
#   'things',
#   'things\r\nwhich',
#   'sower.',
#   'word',
#   'kingdom',
#   'wayside.',
#   'seed\r\nin',
#   'stony',
#   'word',
#   'one',
#   'thorns\r\nhears',
#   'word',
#   'word',
#   'one',
#   'word,',
#   'night,',
#   'wheat',
#   'blades\r\nsprang',
#   'field?',
#   'tares',
#   'tares,\r\nye',
#   'wheat',
#   'reapers,',
#   'weeds',
#   'wheat',
#   'shelter.',
#   'largest',
#   'herbs.',
#   'birds',
#   'air',
#   'multitude.\r\nThus',
#   'prophet:',
#   'foundation',
#   'world.',
#   'multitude',
#   'parable',
#   'tares',
#   'field.\r\nJesus',
#   'good',
#   'Son',
#   'world.',
#   'children',
#   'kingdom.\r\nThe',
#   'children',
#   'wicked',
#   'devil.',
#   'end',
#   'world.',
#   'tares',
#   'fire;',
#   'end',
#   'righteous',
#   'sun',
#   'kingdom',
#   'kingdom',
#   'kingdom',
#   'sea',
#   'net',
#   'bad',
#   'end',
#   'world.',
#   'just',
#   'furnace',
#   'synagogue.',
#   "carpenter's",
#   'fame',
#   'Baptist.',
#   'dead',
#   'sake',
#   'multitude,',
#   "Baptist's",
#   "oath's",
#   'body,',
#   'people',
#   'multitude',
#   'villages',
#   'multitude',
#   'grass.',
#   'five',
#   'two',
#   'loaves',
#   'disciples',
#   'multitude.',
#   'other',
#   'multitude',
#   'boat',
#   'midst',
#   'sea',
#   'fourth',
#   'night,',
#   'disciples',
#   'sea.',
#   'boat',
#   'wind,',
#   'boat',
#   'wind',
#   'Son',
#   'land',
#   'people',
#   'country.',
#   'hem',
#   'tradition',
#   'elders?',
#   'commandment',
#   'father',
#   'commandment',
#   'commandments',
#   'multitude',
#   'mouth',
#   'Pharisees',
#   'blind.',
#   'blind,',
#   'ditch.',
#   'parable',
#   'mouth',
#   'belly',
#   'mouth',
#   'heart.',
#   'man',
#   'heart',
#   'things',
#   'coasts',
#   'lost',
#   'house\r\nof',
#   "children's",
#   'crumbs',
#   'sea',
#   'dumb',
#   'maimed',
#   'lame',
#   'blind',
#   'God',
#   'way.',
#   'wilderness',
#   'multitude',
#   'ground.',
#   'fish',
#   'disciples',
#   'multitude.',
#   'food',
#   'multitude',
#   'coasts',
#   'Sadducees',
#   'sky',
#   'morning,\r\nye',
#   'sky',
#   'face',
#   'sky',
#   'times!',
#   'sign',
#   'other',
#   'leaven',
#   'Pharisees',
#   'Sadducees.',
#   'five\r\nloaves',
#   'five',
#   'seven',
#   'four',
#   'leaven\r\nof',
#   'leaven',
#   'Pharisees',
#   'Sadducees?',
#   'leaven',
#   'doctrine\r\nand',
#   'Pharisees',
#   'Sadducees.',
#   'coast',
#   'Son',
#   'Baptist.',
#   'prophets.\n',
#   'Christ,',
#   'Son',
#   'living',
#   'keys',
#   'kingdom',
#   'Christ.',
#   'hands',
#   'third',
#   'things',
#   'whole',
#   'glory',
#   'Son',
#   'sun.',
#   'disciples',
#   'dead.',
#   'scribes',
#   'Son',
#   'disciples',
#   'Baptist.',
#   'multitude,',
#   'man',
#   'fire',
#   'water.',
#   'boy',
#   'devil,',
#   'child',
#   'boy',
#   'faith',
#   'hands',
#   'third',
#   'house,',
#   'kings',
#   'earth',
#   'children',
#   'sea,\r\ncast',
#   'first',
#   'same',
#   'disciples',
#   'kingdom',
#   'midst',
#   'kingdom',
#   'kingdom',
#   'deep',
#   'sea.',
#   'world',
#   'one',
#   'offence',
#   'face',
#   'ninety',
#   'mountains',
#   'one\r\ngone',
#   'ninety',
#   'will',
#   'mouth',
#   'church.',
#   'church,',
#   'midst',
#   'lord',
#   'debt.',
#   'throat',
#   'debt',
#   'rest',
#   "servant's",
#   'tormentors',
#   'coasts',
#   'beginning\r\nmade',
#   'hardness',
#   'beginning,',
#   'case',
#   'man',
#   'kingdom',
#   'disciples',
#   'commandments.',
#   'poor.',
#   'young',
#   'eye\r\nof',
#   'kingdom',
#   'regeneration,',
#   'Son',
#   'throne',
#   'twelve',
#   'last',
#   'sixth',
#   'ninth',
#   'same.\r\nAbout',
#   'eleventh',
#   'day',
#   'vineyard',
#   'lord',
#   'vineyard',
#   'last',
#   'eleventh',
#   'first',
#   'good',
#   'house',
#   'burden',
#   'day.',
#   'last',
#   'same',
#   'last',
#   'first',
#   'twelve\r\ndisciples',
#   'Son\r\nof',
#   'chief',
#   'Gentiles',
#   'third',
#   'sons',
#   'other',
#   'baptism',
#   'baptism',
#   'remaining',
#   'two',
#   'princes',
#   'Son',
#   'mount',
#   'village\r\nand',
#   'prophet',
#   'daughter',
#   'ass',
#   'colt\r\nand',
#   'way.',
#   'son',
#   'name',
#   'highest.',
#   'prophet',
#   'temple',
#   'tables',
#   'moneychangers',
#   'seats',
#   'lame',
#   'temple',
#   'chief',
#   'wonderful',
#   'children',
#   'temple,',
#   'son',
#   'morning',
#   'disciples',
#   'fig',
#   'temple.',
#   'elders',
#   'people',
#   'first',
#   'man',
#   'second\r\nson',
#   'same',
#   'will',
#   'harlots',
#   'way',
#   'publicans',
#   'harlots',
#   'time',
#   'husbandsmen',
#   'first\r\ntime.',
#   'same',
#   'husbandsmen',
#   'son,\r\nthey',
#   'heir.',
#   'vineyard,',
#   'lord',
#   'vineyard',
#   'fruits\r\nin',
#   'scriptures,',
#   'same',
#   'cornerstone;',
#   'chief',
#   'multitude',
#   'wedding',
#   "king's",
#   'king',
#   'murderers',
#   'highways,',
#   'marriage',
#   'wedding',
#   'king',
#   'guests.',
#   'wedding',
#   'wedding',
#   'king',
#   'Pharisees',
#   'herodians',
#   'tribute',
#   'things',
#   'things',
#   'Sadducees,',
#   'first,',
#   'second',
#   'third,',
#   'seventh',
#   'woman',
#   'resurrection,\r\nwhose',
#   'seven',
#   'scriptures',
#   'power',
#   'resurrection',
#   'angels',
#   'resurrection',
#   'God',
#   'God',
#   'God',
#   'God',
#   'dead,',
#   'multitude',
#   'Pharisees',
#   'Sadducees',
#   'great',
#   'law?',
#   'Lord',
#   'first',
#   'second',
#   'law',
#   'Pharisees',
#   'crowd',
#   'Pharisees',
#   'chief',
#   'synagogues.',
#   'markets',
#   'greater',
#   'child',
#   'temple,',
#   'gold',
#   'temple,',
#   'gold',
#   'temple',
#   'gold?',
#   'altar,',
#   'gift',
#   'gift,',
#   'altar',
#   'gift?',
#   'altar,',
#   'temple,\r\nswears',
#   'throne',
#   'weightier',
#   'outside',
#   'cup\r\nand',
#   'outside',
#   'outside,',
#   'tombs',
#   'sepulchres',
#   'righteous.',
#   'days',
#   'blood',
#   'prophets.',
#   'children',
#   'prophets',
#   'damnation\r\nof',
#   'blood',
#   'righteous',
#   'earth,',
#   'blood',
#   'blood',
#   'altar.',
#   'prophets,',
#   'name',
#   'buildings',
#   'disciples',
#   'sign',
#   'end',
#   'end',
#   'beginning',
#   'love',
#   'kingdom',
#   'world',
#   'end',
#   'prophet,',
#   'prophecy.',
#   'mountains.',
#   'housetop',
#   'field',
#   'winter',
#   'sabbath',
#   'beginning',
#   "elect's",
#   'very',
#   'desert,',
#   'secret\r\nchambers,',
#   'lightning',
#   'west,',
#   'coming',
#   'tribulation',
#   'sun',
#   'heavens',
#   'people',
#   'sign',
#   'Son',
#   'clouds',
#   'four',
#   'other.',
#   'fig',
#   'day',
#   'hour',
#   'Son',
#   'days',
#   'day',
#   'ark.',
#   'flood',
#   'Son',
#   'field.',
#   'mill.',
#   'other',
#   'good',
#   'house',
#   'household,',
#   'foods',
#   'servant',
#   'servant\r\ndoes',
#   'servant',
#   'hypocrites.',
#   'bridegroom.',
#   'bridegroom',
#   'virgins',
#   'wise\r\nanswered,',
#   'oil,',
#   'bridegroom',
#   'marriage',
#   'door',
#   'other',
#   'door\r\nto',
#   'day',
#   'hour',
#   'five',
#   'servant',
#   'earth',
#   'lord',
#   'joy',
#   'joy',
#   'servant',
#   'one',
#   'exchangers',
#   'talent',
#   'one',
#   'one',
#   'one',
#   'Son',
#   'sheep',
#   'goats',
#   'King',
#   'kingdom',
#   'beginning',
#   'righteous',
#   'least\r\nof',
#   'left,',
#   'devil',
#   'least',
#   'righteous',
#   'feast',
#   'passover.',
#   'same',
#   'chief',
#   'people\r\nheld',
#   'palace',
#   'high',
#   'feast',
#   'house',
#   'leper.',
#   'poor.',
#   'world',
#   'twelve,',
#   'chief',
#   'first',
#   'feast',
#   'disciples',
#   'passover?\r\nJesus',
#   'city',
#   'disciples',
#   'passover.',
#   'twelve.',
#   'same',
#   'dish',
#   'one',
#   'Son',
#   'bread',
#   'disciples',
#   'cup',
#   'new\r\ntestament',
#   'remission',
#   'vine',
#   'meal,\r\nthey',
#   'mount',
#   'disciples,',
#   'shepherd,',
#   'flock',
#   'disciples',
#   'two',
#   'three',
#   'spirit',
#   'flesh',
#   'three,',
#   'same',
#   'disciples',
#   'hour',
#   'hands',
#   'twelve,',
#   'chief\r\npriests',
#   'people.',
#   'high',
#   'sword',
#   'sword.',
#   'way',
#   'scriptures\r\nof',
#   'prophets',
#   'disciples',
#   'high',
#   'scribes',
#   'high',
#   'servants.',
#   'council',
#   'living',
#   'Christ,',
#   'Son',
#   'Son',
#   'right',
#   'clouds',
#   'high',
#   'palms',
#   'palace.',
#   'porch.',
#   'others\r\nstanding',
#   'man.',
#   'bystanders',
#   'man.',
#   'cock',
#   'cock',
#   'chief',
#   'governor.\n',
#   'chief',
#   'innocent.',
#   'pieces',
#   'temple.\r\nImmediately',
#   'same',
#   'chief',
#   'silver',
#   'treasury',
#   "potter's",
#   'thirty',
#   'price',
#   'children',
#   "potter's",
#   'Lord',
#   'governor.',
#   'Jews?',
#   'chief',
#   'things',
#   'governor',
#   ...],
#  'pages': ['of'],
#  'the\r\nGospel': ['of'],
#  'Matthew,': ['a'],
#  'a': ['rich',
#   'just',
#   'public\r\nexample,',
#   'dream',
#   'son',
#   'virgin',
#   'son,',
#   'Governor',
#   'dream',
#   'dream',
#   'dream,',
#   'city',
#   'leathern',
#   'dove',
#   'pinnacle',
#   'stone.',
#   'net',
#   'boat,',
#   'mountain',
#   'hill',
#   'bushel,',
#   'candlestick.',
#   'gift',
#   'woman',
#   'writing\r\nof',
#   'tooth',
#   'tooth.',
#   'trumpet',
#   'beam',
#   'stone?',
#   'fish,',
#   'wise',
#   'rock.',
#   'rock.',
#   'foolish\r\nman',
#   'leper',
#   'testimony.',
#   'centurion',
#   'man',
#   'fever.',
#   'boat',
#   'great',
#   'great',
#   'distance',
#   'herd',
#   'steep',
#   'boat',
#   'man',
#   'bed.',
#   'man',
#   'physician,',
#   'piece',
#   'certain',
#   'woman',
#   'house,',
#   'mute',
#   'devil',
#   'shepherd.',
#   'house,',
#   'testimony',
#   'brother',
#   'brother',
#   'farthing?',
#   'sword.',
#   'man',
#   'daughter-in-law',
#   'prophet',
#   'prophet',
#   "prophet's",
#   'righteous',
#   'righteous',
#   'cup',
#   'disciple,',
#   'prophet.\r\nThis',
#   'devil.',
#   'gluttonous\r\nman,',
#   'winebibber,',
#   'friend',
#   'sabbath',
#   'man',
#   'pit',
#   'sheep?',
#   'council',
#   'blind',
#   'devil,',
#   'strong',
#   'word',
#   'man',
#   'sign.',
#   'man,',
#   'boat',
#   'sower',
#   'hundredfold,',
#   'while.',
#   'hundredfold',
#   'man\r\nwho',
#   'grain',
#   'tree',
#   'furnace.',
#   'field.',
#   'net',
#   'householder',
#   'prophet',
#   'prophet.\n',
#   'charger.',
#   'charger,',
#   'desert',
#   'great',
#   'desert',
#   'boat',
#   'mountain',
#   'gift',
#   'man.',
#   'man.',
#   'man.',
#   'man.',
#   'devil.',
#   'word',
#   'multitude?',
#   'few',
#   'boat',
#   'sign',
#   'wicked',
#   'sign.',
#   'man',
#   'man',
#   'bright',
#   'voice',
#   'man',
#   'grain',
#   'hook,',
#   'coin.',
#   'little',
#   'little',
#   'millstone',
#   'hundred',
#   'heathen',
#   'king',
#   'man',
#   'man',
#   'writing',
#   'young',
#   'rich',
#   'camel',
#   'needle,',
#   'rich',
#   'hundredfold,',
#   'householder',
#   'coin',
#   'day,',
#   'coin.',
#   'coin.',
#   'coin?',
#   'ransom',
#   'great',
#   'man',
#   'colt,',
#   'house',
#   'den',
#   'fig',
#   'prophet.',
#   'householder',
#   'vineyard.\r\nHe',
#   'winepress',
#   'tower.',
#   'nation',
#   'prophet.',
#   'marriage',
#   'man',
#   'coin',
#   'man',
#   'lawyer,',
#   'word,',
#   'finger',
#   'pretence,',
#   'good',
#   'gnat',
#   'camel.',
#   'hen',
#   'great',
#   'trumpet.',
#   'parable',
#   'faithful',
#   'day',
#   'time',
#   'cry,\r\nBehold,',
#   'man',
#   'far',
#   'hole',
#   'long',
#   'few',
#   'few',
#   'hard',
#   'shepherd',
#   'stranger',
#   'stranger,',
#   'meeting',
#   'woman',
#   'good',
#   'certain',
#   'place',
#   'little',
#   'second',
#   'third',
#   'great\r\nmultitude.',
#   'sign',
#   'thief',
#   'word.',
#   'message\r\nto',
#   'dream',
#   'tumult',
#   'scarlet\r\nrobe',
#   'crown',
#   'reed',
#   'man',
#   'place',
#   'skull.\r\nThere',
#   'written',
#   'loud',
#   'sponge.',
#   'reed,',
#   'loud',
#   'rich',
#   'clean',
#   'watch.',
#   'large'],
#  'rich': ['source', 'man', 'man', 'man'],
#  'source': ['of'],
#  'information': ['detailing'],
#  'detailing': ['the'],
#  'Son': ["of\r\nGod's",
#   'in',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'comes.',
#   'but\r\nthe',
#   'will',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of\r\nGod.',
#   'of',
#   'of',
#   'of',
#   'of\r\nman',
#   'in',
#   'of',
#   'of',
#   'of\r\nman',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  "of\r\nGod's": ['instructions'],
#  'instructions': ['from'],
#  'from': ['Our',
#   'the',
#   'the',
#   'Galilee',
#   'heaven',
#   'there,',
#   'Galilee,\r\nand',
#   'Decapolis,',
#   'Jerusalem,',
#   'Judaea,',
#   'thee.',
#   'your',
#   'evil.',
#   'thine',
#   'thy',
#   'thorns,',
#   'thistles?',
#   'me,',
#   'the\r\nscribes.',
#   'the',
#   'the',
#   'them',
#   'their',
#   'them',
#   'the',
#   'your',
#   'the',
#   'me.',
#   'there.',
#   'thee.',
#   'the',
#   'which',
#   'him.',
#   'the',
#   'the',
#   'there',
#   'Jerusalem',
#   'me.',
#   'the',
#   'heaven.',
#   'thee,',
#   'the\r\nmountain,',
#   'the',
#   'that',
#   'thee.',
#   'thee.',
#   'the',
#   'their',
#   'my',
#   'the',
#   'Jericho',
#   'Nazareth',
#   'heaven',
#   'man?',
#   'you',
#   'that',
#   'your\r\ndrink',
#   'city',
#   'the',
#   'the',
#   'the',
#   'one',
#   'his',
#   'another',
#   'his\r\ngoats.',
#   'the',
#   'me',
#   'that',
#   'this',
#   'me.\r\nNevertheless,',
#   'me',
#   'the',
#   'the',
#   'the',
#   'top',
#   'the',
#   'heaven,',
#   'the',
#   'the'],
#  'Our': ['Father', 'Father'],
#  'Father': ['to',
#   'in',
#   'in',
#   'in',
#   'in',
#   'in',
#   'knows',
#   'who',
#   'will',
#   'forgive',
#   'shall',
#   'feeds',
#   'knows',
#   'in',
#   'in',
#   'knowing.',
#   'in',
#   'except',
#   'in\r\nheaven',
#   'shall',
#   'which',
#   'in',
#   'in',
#   'do',
#   'and'],
#  'to': ['us.',
#   '"this',
#   'hear',
#   'see.',
#   'make',
#   'put',
#   'him',
#   'take',
#   'Jerusalem.',
#   'know',
#   'enquire',
#   'Bethlehem',
#   'the',
#   'Herod,',
#   'Joseph',
#   'destroy',
#   'Joseph',
#   'go\r\nthere.',
#   'dwell',
#   'Jerusalem.',
#   'his\r\nbaptism,',
#   'them,',
#   'come?',
#   'you,',
#   'raise',
#   'Abraham',
#   'the',
#   'bear.',
#   'Jordan',
#   'be',
#   'me?',
#   'be',
#   'Him.',
#   'be',
#   'Him',
#   'Him.',
#   'them,',
#   'Him',
#   'be',
#   'be',
#   'all',
#   'destroy',
#   'destroy',
#   'fulfill.',
#   'do',
#   'you,\r\nWhoever',
#   'the',
#   'thy',
#   'the',
#   'the',
#   'commit',
#   'him',
#   'go\r\na',
#   'him',
#   'be',
#   'thy',
#   'others',
#   'fast.',
#   'fast.',
#   'the',
#   'his',
#   'thy',
#   'cast',
#   'dogs.',
#   'you.',
#   'give',
#   'your\r\nchildren,',
#   'them.',
#   'destruction.',
#   'life',
#   'you',
#   'me,',
#   'me,',
#   'them,',
#   'a',
#   'a',
#   'him,',
#   'him,',
#   'do',
#   'those',
#   'you,',
#   "Peter's",
#   'them.',
#   'Him',
#   'lay',
#   'Him',
#   'torment',
#   'Him,',
#   'go',
#   'those\r\npossessed',
#   'see',
#   'depart',
#   'His',
#   'Him',
#   'the\r\nsick',
#   'say,',
#   'forgive',
#   'the',
#   'thy',
#   'his',
#   'him,',
#   'His',
#   'call',
#   'call\r\nsinners',
#   'repentance.',
#   'Him',
#   'patch',
#   'cover',
#   'them,',
#   'scorn.',
#   'them,',
#   'do',
#   'Him,',
#   'make',
#   'Jesus.',
#   'all',
#   'His',
#   'the\r\nLord',
#   'His',
#   'cast\r\n\r\nout',
#   'heal',
#   'the\r\nlost',
#   'you.',
#   'death,',
#   'be',
#   'death.',
#   'the',
#   'another.',
#   'all',
#   'kill\r\nthe',
#   'destroy',
#   'earth',
#   'send',
#   'send',
#   'one',
#   'drink',
#   'them.\r\nBlessed',
#   'the',
#   'see?',
#   'see?',
#   'come.',
#   'hear,',
#   'you\r\nand',
#   'upbraid',
#   'you,',
#   'hell.',
#   'babes.',
#   'me',
#   'whomever',
#   'me,',
#   'pluck',
#   'Jesus,',
#   'do',
#   'eat,',
#   'heal',
#   'do',
#   'the',
#   'fulfill',
#   'the',
#   'such',
#   'desolation.',
#   'you,',
#   'come.',
#   'you,',
#   'see',
#   'hear',
#   'the',
#   'talk',
#   'the',
#   'speak',
#   'Him',
#   'speak',
#   'sow',
#   'hear,',
#   'them',
#   'know',
#   'them',
#   'them',
#   'change',
#   'see',
#   'hear',
#   'the\r\nparable',
#   'him',
#   'the',
#   'go',
#   'the',
#   'us',
#   'hear,',
#   'buy',
#   'buy',
#   'his',
#   'have',
#   'death',
#   'give',
#   'her,',
#   'her\r\nmother.',
#   'Jesus.',
#   'a',
#   'Him',
#   'eat.',
#   'sit',
#   'heaven,',
#   'His',
#   'women',
#   'get',
#   'the',
#   'pray.',
#   'sink.',
#   'Jesus',
#   'Jesus.',
#   'death',
#   'his',
#   'us.',
#   'Him',
#   'take',
#   'her,',
#   'rest.',
#   'Him.',
#   'sit',
#   'the',
#   'the',
#   'the',
#   'their',
#   'bring',
#   'the',
#   'thee,',
#   'tell',
#   'rebuke',
#   'His',
#   'his',
#   'be',
#   'tell',
#   'suffer',
#   'Jesus.',
#   'thy',
#   'me.',
#   'the',
#   'those',
#   'Jesus',
#   'Him,\r\nset',
#   'the',
#   'enter',
#   'be',
#   'enter',
#   'save',
#   'seek',
#   'hear',
#   'the',
#   'hear',
#   'Him',
#   'reckon,',
#   'him',
#   'pay,',
#   'be',
#   'be',
#   'their\r\nlord',
#   'the',
#   'you',
#   'pass,',
#   'test',
#   'his',
#   'put',
#   'put',
#   'you,',
#   'marry.',
#   'whom',
#   'receive\r\nit,',
#   'Him',
#   'come',
#   'me;',
#   'Him',
#   'him,',
#   'the',
#   'His',
#   'go',
#   'enter',
#   'hire',
#   'them,',
#   'his',
#   'those',
#   'the',
#   'thee.',
#   'Jerusalem,',
#   'Jerusalem',
#   'death.',
#   'the',
#   'mock,\r\nscourge,',
#   'drink',
#   'be',
#   'Him,',
#   'give.',
#   'them',
#   'Him',
#   'be',
#   'give',
#   'keep',
#   'them,',
#   'Jerusalem,',
#   'Bethphage',
#   'me.',
#   'you,',
#   'the',
#   'them,',
#   'Him',
#   'the',
#   'Him,',
#   'return',
#   'the\r\ncity.',
#   'it',
#   'the',
#   'this',
#   'Him',
#   'Jesus,',
#   'the',
#   'work',
#   'work.',
#   'the',
#   'you',
#   'husbandsmen',
#   'the',
#   'receive\r\nthe',
#   'them',
#   'these\r\nhusbandsmen?',
#   'Jesus,',
#   'others',
#   'a',
#   'call',
#   'the',
#   'say,',
#   'the\r\nmarriage.',
#   'his',
#   'his',
#   'his\r\nservants,',
#   'greet',
#   'him,\r\nFriend,',
#   'discuss',
#   'give',
#   'Caesar',
#   'Him.\r\nJesus',
#   'God',
#   'go',
#   'the',
#   'the',
#   'silence,\r\nthey',
#   'answer',
#   'the',
#   'His',
#   'be',
#   'other',
#   'be',
#   'attempt',
#   'enter',
#   'city.',
#   'thee,',
#   'show',
#   'pass',
#   'be\r\nafflicted.',
#   'all',
#   'take',
#   'get',
#   'you,',
#   'you,',
#   'the',
#   'be',
#   'meet',
#   'meet',
#   'the\r\nwise,',
#   'them',
#   'buy',
#   'the',
#   'every',
#   'his',
#   'me.',
#   'me\r\ntwo',
#   'have,',
#   'the',
#   'the',
#   'those',
#   'thee?',
#   'one',
#   'me.',
#   'those',
#   'one',
#   'everlasting',
#   'pass,',
#   'the',
#   'the',
#   'betray',
#   'eat',
#   'go',
#   'a',
#   'him',
#   'the',
#   'them\r\nsaying,',
#   'the',
#   'Him,',
#   'pray.',
#   'these',
#   'the',
#   'this',
#   'the',
#   'pray',
#   'all',
#   'him,\r\nFriend,',
#   'him,\r\nPut',
#   'the',
#   'my',
#   'this',
#   'take',
#   'Caiaphas',
#   'the',
#   'put',
#   'death.',
#   'destroy',
#   'Jesus,',
#   'Him,',
#   'him',
#   'the',
#   'Peter',
#   'curse',
#   'him:',
#   'put',
#   'death.',
#   'Pontius',
#   'the',
#   'us?',
#   'put',
#   'release',
#   'do',
#   'choose',
#   'it.',
#   'be',
#   'be',
#   'carry\r\nthe',
#   'a',
#   'drink',
#   'get',
#   'Jesus',
#   'drink.',
#   'save',
#   'bottom.',
#   'many.',
#   'Him\r\nwere',
#   'Pilate',
#   'them,',
#   'watch.',
#   'the',
#   'the',
#   'bring',
#   "Jesus'",
#   'Him,',
#   'them,',
#   'go',
#   'say',
#   "the\r\ngovernor's",
#   'Galilee,',
#   'the',
#   'them',
#   'me',
#   'observe'],
#  'us.': ['Here', 'We', 'When', 'Jesus\r\nreplied,', 'Jesus', 'He', 'But'],
#  'Here': ['we', 'Jesus'],
#  'we': ['learn,',
#   'must',
#   'have',
#   'have',
#   'forgive',
#   'eat?',
#   'be',
#   'not',
#   'not',
#   'not',
#   'to\r\ndo',
#   'and',
#   'look',
#   'want',
#   'go\r\nand',
#   'find',
#   'not',
#   'do',
#   'have',
#   'go',
#   'say,',
#   'say,',
#   'know',
#   'would',
#   'see',
#   'see',
#   'see\r\nthee',
#   'see',
#   'prepare',
#   'of',
#   'will'],
#  'learn,': ['through'],
#  'through': ["Jesus'\r\nteachings",
#   'the\r\nprince',
#   'you.',
#   'a\r\ncornfield.',
#   'dry',
#   'the'],
#  "Jesus'\r\nteachings": ['and'],
#  'and': ['actions,',
#   'has',
#   'the',
#   'eyes',
#   'paragraph',
#   'before',
#   'said,\r\nJoseph,',
#   'thou',
#   'shall\r\nbring',
#   'they',
#   'did',
#   'took\r\nunto',
#   'go\r\nto',
#   'scribes\r\ntogether',
#   'demanded',
#   'said,',
#   'search',
#   'worship',
#   'frankincense\r\nand',
#   'said,',
#   'take',
#   'His',
#   'His\r\nmother,',
#   'departed',
#   'was',
#   'under',
#   'great',
#   'would',
#   'take',
#   'His',
#   'His',
#   'started\r\ntoward',
#   'a',
#   'wild',
#   'all',
#   'confessed',
#   'Sadducees',
#   'cast',
#   'with',
#   'gather',
#   'the',
#   'light\r\nupon',
#   'forty',
#   'said,',
#   'sat\r\nHim',
#   'in',
#   'worship',
#   'Him',
#   'ministered',
#   'Nephthalim.',
#   'the',
#   'shadow',
#   'were',
#   'I',
#   'followed',
#   'John.',
#   'they',
#   'their',
#   'followed',
#   'healing',
#   'disease',
#   'those',
#   'those\r\nwho',
#   'from',
#   'from',
#   'from\r\nbeyond',
#   'sat.',
#   'He',
#   'thirst',
#   'persecute',
#   'say',
#   'be',
#   'walked',
#   'earth',
#   'teaches',
#   'teach',
#   'Pharisees,',
#   'whoever\r\nshall',
#   'then',
#   'offer',
#   'the',
#   'thou',
#   'cast',
#   'a',
#   'takes\r\naway',
#   'hate',
#   'persecute\r\nyou.',
#   'on',
#   'in',
#   'thy',
#   'in',
#   'the',
#   'the',
#   'look',
#   'wash',
#   'thy',
#   'rust\r\ncorrupts,',
#   'where',
#   'steal.',
#   'steal.',
#   'love',
#   'despise',
#   'mammon.',
#   'the',
#   'neither',
#   'how',
#   'tomorrow',
#   'turn',
#   'it',
#   'ye',
#   'it\r\nshall',
#   'the',
#   'broad',
#   'cast',
#   'does',
#   'the',
#   'the',
#   'beat',
#   'does',
#   'the\r\nfloods',
#   'the',
#   'beat',
#   'offer',
#   'grievously',
#   'heal',
#   'my',
#   'have',
#   'he',
#   'he',
#   'he',
#   'said',
#   'shall',
#   'Isaac,',
#   'Jacob',
#   'gnashing',
#   'the',
#   'ministered',
#   'He',
#   'bore',
#   'said,',
#   'the',
#   'said,',
#   'bury',
#   'let',
#   'started',
#   'said,',
#   'rebuked',
#   'the',
#   'the',
#   'perished',
#   'told',
#   'walk?',
#   'go',
#   'went',
#   'glorified',
#   'followed',
#   'sinners',
#   'sat',
#   'His\r\ndisciples.',
#   'sinners?',
#   'learn',
#   'not\r\nrevenge',
#   'asked,',
#   'the\r\nPharisees',
#   'then',
#   'the',
#   'the',
#   'both',
#   'said,',
#   'lay',
#   'she\r\nshall',
#   'followed',
#   'His',
#   'when',
#   'she',
#   'said,',
#   'said',
#   'villages,',
#   'disease',
#   'were\r\nscattered',
#   'gave',
#   'to',
#   'disease.',
#   'Judas\r\n\r\nIscariot,',
#   'commanded',
#   'Gomorrha',
#   'harmless',
#   'kings',
#   'the\r\nGentiles',
#   'a\r\nfather',
#   'the',
#   'body\r\nin',
#   'a\r\ndaughter',
#   'a',
#   'follow',
#   'he',
#   'preach',
#   'show',
#   'see.',
#   'he',
#   'the',
#   'the',
#   'calling',
#   'ye',
#   'they',
#   'drinking',
#   'they',
#   'sinners.',
#   'Sidon,',
#   'prudent',
#   'are',
#   'I',
#   'learn',
#   'lowly',
#   'my',
#   'His',
#   'began',
#   'those',
#   'are',
#   'lift',
#   'said,',
#   'it',
#   'like\r\nhis',
#   'held',
#   'He',
#   'smoking',
#   'mute',
#   'said,',
#   'said,',
#   'spoil',
#   'blasphemy\r\nagainst',
#   'not',
#   'its',
#   'its\r\nfruit',
#   'Pharisees',
#   'adulterous',
#   'three',
#   'three',
#   'shall\r\ncondemn',
#   'shall',
#   'finds',
#   'garnished.',
#   'dwell',
#   'His\r\nbrethren',
#   'requested',
#   'brethren',
#   'desire',
#   'who',
#   'said,',
#   'my',
#   'sister,',
#   'mother.',
#   'sit',
#   'the',
#   'devoured',
#   'choked',
#   'he',
#   'not',
#   'shall',
#   'shall',
#   'have',
#   'your',
#   'righteous',
#   'they',
#   'have',
#   'does',
#   'endures',
#   'the\r\ndeceitfulness',
#   'bears',
#   'brought',
#   'asked,',
#   'bind',
#   'went',
#   'said,',
#   'said,',
#   'burned',
#   'does\r\niniquity',
#   'cast',
#   'sells\r\nall',
#   'sells',
#   'sever\r\nthe',
#   'cast',
#   'gnashing',
#   'old.',
#   'said,',
#   'these',
#   'Joses,',
#   'Simon,',
#   'Judas?',
#   'in',
#   'mighty',
#   'those',
#   'she',
#   'He',
#   'said,',
#   'it',
#   'buy\r\nfood.',
#   'two',
#   'gave',
#   'the',
#   'were',
#   'children.',
#   'go\r\nahead',
#   'tossed',
#   'said,',
#   'said,',
#   'walked',
#   'said,',
#   'worshipped',
#   'Pharisees',
#   'mother.',
#   'honor',
#   'said,',
#   'understand.',
#   'said,',
#   'said,',
#   'is',
#   'blasphemies.',
#   'Sidon.',
#   'said,',
#   'said,',
#   'worshipped',
#   'cast',
#   'went',
#   'many',
#   'He',
#   'said,',
#   'have',
#   'a',
#   'the',
#   'gave',
#   'gave',
#   'the',
#   'were',
#   'children.\r\nThen',
#   'took',
#   'the',
#   'said,',
#   'adulterous',
#   'departed',
#   'beware',
#   'how',
#   'how\r\nmany',
#   'the',
#   'blood',
#   'upon',
#   'suffer',
#   'scribes.',
#   'said,\r\nFar',
#   'said,',
#   'follow',
#   'loses',
#   'shall',
#   'his',
#   'Elias',
#   'talked',
#   'one',
#   'were',
#   'said,',
#   'restores',
#   'into',
#   'perverse',
#   'the',
#   'asked,',
#   'it',
#   'fasting.',
#   'questioned',
#   'said,',
#   'take',
#   'give',
#   'thee.',
#   'asked,',
#   'said,',
#   'become',
#   'he',
#   'cast',
#   'cast',
#   'one',
#   'nine',
#   'go',
#   'nine',
#   'tell',
#   'him',
#   'a\r\npublican.',
#   'said,',
#   'I',
#   'children,',
#   'all\r\nthat',
#   'payment',
#   'I',
#   'forgave',
#   'met',
#   'took',
#   'besought\r\nhim',
#   'I',
#   'went',
#   'told',
#   'said,',
#   'delivered',
#   'came',
#   'He',
#   'female,',
#   'said,',
#   'mother',
#   'shall',
#   'shall',
#   'pray.',
#   'do',
#   'then',
#   'asked,',
#   'that',
#   'thy\r\nmother.',
#   'sell\r\nwhat',
#   'give',
#   'follow',
#   'said,',
#   'followed',
#   'shall',
#   'the',
#   'saw',
#   'whatever\r\nis',
#   'the',
#   'did',
#   'give',
#   'said,',
#   'thou',
#   'heat',
#   'said,',
#   'go',
#   'the',
#   'said,',
#   'scribes.',
#   'crucify',
#   'her',
#   'John,\r\napproached',
#   'the',
#   'to',
#   'be',
#   'said,',
#   'ambition',
#   'to',
#   'told',
#   'said',
#   'they\r\nfollowed',
#   'said,',
#   'bring\r\nthem',
#   'sitting',
#   'the',
#   'lined',
#   'cast',
#   'sold.\r\nHe',
#   'the',
#   'the',
#   'He',
#   'scribes',
#   'went',
#   'said,',
#   'doubt\r\nnot,',
#   'cast',
# ...
#   'risen',
#   'compassion',
#   'pity',
#   'finished',
#   'many',
#   'agreed',
#   'compassion',
#   'two',
#   'seen,',
#   'her?',
#   'known',
#   'finished',
#   'not',
#   'been',
#   'agreed',
#   'Jesus\r\nscourged',
#   'taken'],
#  'palsy.': ['He'],
#  'healed': ['them.',
#   'that',
#   'all',
#   'every',
#   'them',
#   'him,',
#   'their',
#   'them.',
#   'many',
#   'them.\r\nWhen'],
#  'them.': ['Great',
#   'So,',
#   'This',
#   'Now,',
#   'That',
#   'They',
#   'Some\r\nfell',
#   'Yet',
#   'They',
#   'So,',
#   'Let',
#   'The',
#   'When',
#   'His',
#   'From\r\nthe',
#   'Then',
#   'Then',
#   'But\r\nit',
#   'All',
#   'But',
#   'The\r\nwise',
#   'His',
#   'His\r\nlord',
#   'Peter',
#   'They'],
#  'Great': ['multitudes', 'multitudes'],
#  'multitudes': ['of', 'followed', 'gathering.', 'gathered.', 'came'],
#  'Galilee,\r\nand': ['from'],
#  'Decapolis,': ['and'],
#  'Jerusalem,': ['and', 'took', 'they', 'all\r\nthe', 'Jerusalem,', 'thou'],
#  'from\r\nbeyond': ['Jordan'],
#  'Him.\r\n5\r\nSeeing': ['the'],
#  'multitudes,': ['He'],
#  'mountain': ['and', 'to', 'appointed'],
#  'sat.': ['His\r\ndisciples'],
#  'His\r\ndisciples': ['came', 'said,', 'come'],
#  'taught': ['them:', 'as', 'them', 'in'],
#  'them:': ['Blessed', 'Go'],
#  'Blessed': ['are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'are',
#   'art',
#   'is',
#   'is',
#   'is'],
#  'poor': ['in', 'have', 'ye'],
#  'spirit': ['for\r\ntheirs', 'upon', 'has', 'says,', 'may'],
#  'for\r\ntheirs': ['is'],
#  'heaven.': ['Blessed',
#   'And,',
#   'Do',
#   'But',
#   'He',
#   'When',
#   'Give',
#   'Only',
#   'But',
#   'Whoever',
#   'Think',
#   'From',
#   'He',
#   'I',
#   'Whatsoever',
#   'Whatsoever',
#   'Then',
#   'Whosoever,',
#   'Whoever',
#   'Whatever',
#   'If',
#   'For',
#   'Jesus',
#   'It',
#   'Concerning',
#   'Neither',
#   'Then'],
#  'mourn': ['for', 'as'],
#  'they\r\nshall': ['be'],
#  'comforted.': ['Blessed'],
#  'meek': ['for', 'and'],
#  'inherit': ['the\r\nearth.', 'everlasting'],
#  'the\r\nearth.': ['Blessed'],
#  'hunger': ['and'],
#  'thirst': ['after'],
#  'righteousness': ['for\r\nthey', 'exceeds', 'of'],
#  'for\r\nthey': ['shall', 'shall'],
#  'filled.': ['Blessed'],
#  'merciful': ['for'],
#  'obtain': ['mercy.'],
#  'mercy.': ['Blessed'],
#  'the\r\npure': ['of'],
#  'heart': ['for', 'the', 'of', 'come'],
#  'peacemakers': ['for\r\nthey'],
#  'are\r\npersecuted': ['for'],
#  "righteousness'": ['sake'],
#  'sake': ['for', 'of', 'and'],
#  'theirs': ['is'],
#  'heaven.\r\nBlessed': ['are'],
#  'revile': ['and'],
#  'persecute': ['you,'],
#  'of\r\nevil': ['against'],
#  'falsely': ['for'],
#  'sake.': ['Rejoice', 'But', 'He', 'Many'],
#  'Rejoice': ['and'],
#  'glad.\r\nGreat': ['is'],
#  'your': ['reward',
#   'light',
#   'good',
#   'Father',
#   'righteousness',
#   'oaths',
#   'enemy.',
#   'Father',
#   'friends',
#   'Father',
#   'almsgiving',
#   'Father',
#   'heavenly',
#   'Father',
#   'trespasses.',
#   'treasure',
#   'heart.',
#   'body:\r\nwhat',
#   'heavenly',
#   'pearls\r\nbefore',
#   'Father',
#   'hearts?',
#   'master',
#   'faith',
#   'purses.',
#   'journey.',
#   'peace',
#   'peace',
#   'words,',
#   'feet.',
#   'Father\r\nwhich',
#   'Father',
#   'head',
#   'souls',
#   'children',
#   'judges.',
#   'eyes,',
#   'ears,',
#   'tradition?',
#   'unbelief.',
#   'master',
#   'hearts,\r\nsuffered',
#   'wives.',
#   'minister.',
#   'teacher,',
#   'father,',
#   'Master,',
#   'servant.',
#   'fathers.',
#   'synagogues',
#   'hands',
#   'house',
#   'flight',
#   'Lord',
#   'oil',
#   'way.'],
#  'reward': ['in', 'have', 'from', 'thee'],
#  'likewise,': ['they', 'when\r\nye'],
#  'persecuted': ['the\r\nprophets'],
#  'the\r\nprophets': ['who'],
#  'you.': ['Ye',
#   'Do',
#   'Pray',
#   'But',
#   'Take\r\nno',
#   'Ask',
#   'Seek',
#   'Who',
#   'Depart',
#   'Their',
#   'Whoever\r\nshall',
#   'Also',
#   'And',
#   'And,',
#   'He',
#   'Whoever',
#   'John',
#   'Many',
#   'Ye',
#   'Go',
#   'The'],
#  'Ye': ['are',
#   'are',
#   'have',
#   'have',
#   'have',
#   'have',
#   'cannot\r\nserve',
#   'shall',
#   'shall',
#   'shall',
#   'shall',
#   'hypocrites.',
#   'can',
#   'know',
#   'shall',
#   'err.',
#   'shut',
#   'devour',
#   'venture',
#   'pay',
#   'blind',
#   'make',
#   'are',
#   'build',
#   'say,',
#   'serpents,',
#   'shall',
#   'shall',
#   'shall',
#   'shall',
#   'have'],
#  'salt': ['of', 'loses'],
#  'earth.': ['If', 'The', 'They', 'Here,', 'Go'],
#  'loses': ['its', 'his', 'his', 'his'],
#  'its': ['savour',
#   'fruit',
#   'fruit.',
#   'branches.',
#   'fruits.',
#   'branch',
#   'place.'],
#  'savour': ['it'],
#  'good\r\nfor': ['nothing'],
#  'nothing': ['except', 'like', 'covered', 'to\r\neat.', 'to'],
#  'except': ['to', 'for\r\nreason', 'unto', 'the', 'the', 'in', 'the', 'it'],
#  'on.': ['Ye', 'Is', 'When', 'Among'],
#  'world.': ['A', 'Then', 'The', 'The', 'The', 'The', 'Amen.'],
#  'set': ['on', 'a', 'Jesus', 'the'],
#  'hill': ['cannot'],
#  'cannot': ['be',
#   'bring',
#   'bring',
#   'discern\r\nthe',
#   'receive',
#   'tell.',
#   'happen',
#   'pray',
#   'save'],
#  'hidden.': ['A'],
#  'candle': ['is\r\nnot'],
#  'is\r\nnot': ['lighted', 'good'],
#  'lighted': ['to'],
#  'bushel,': ['but'],
#  'candlestick.': ['This'],
#  'it\r\ngives': ['light'],
#  'house.': ['Let', 'When', 'He', 'He'],
#  'Let': ['your',
#   'your\r\nstatement',
#   'me',
#   'both',
#   'him',
#   'them',
#   'no',
#   'us',
#   'those',
#   'him',
#   'Him',
#   'Him',
#   'God',
#   'us'],
#  'shine': ['before', 'forth'],
#  'men\r\nthat': ['they'],
#  'good': ['works',
#   'gifts',
#   'things',
#   'tree\r\nbrings',
#   'fruit.',
#   'fruit',
#   'cheer;',
#   'comfort;',
#   'in',
#   'on',
#   'and',
#   'things?',
#   'man,',
#   'things.',
#   'ground.\r\nThese',
#   'seed',
#   'seed',
#   'seed',
#   'pearls.',
#   'they',
#   'cheer.',
#   'for',
#   'to',
#   'but',
#   'man',
#   'pledge!\r\nYe',
#   'man',
#   'work'],
#  'works': ['reflecting',
#   'of',
#   'were\r\ndone',
#   'which',
#   'which',
#   'there',
#   'because',
#   'they'],
#  'reflecting': ['only'],
#  'Do': ['not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'good\r\nto',
#   'this',
#   'not',
#   'not',
#   'men\r\ngather',
#   'ye',
#   'ye',
#   'ye',
#   'ye'],
#  'think': ['that', 'ye', 'ye?'],
#  'law': ['or', 'until', 'and', 'prophesied', 'how', 'and'],
#  'or': ['the',
#   'one',
#   'black.',
#   'he',
#   'figs',
#   'Arise',
#   'into',
#   'town',
#   'hear',
#   'mother',
#   'daughter',
#   'do',
#   'house',
#   'else',
#   'hear',
#   'persecution\r\narises',
#   'sixty',
#   'thirty.',
#   'mother.',
#   'mother,',
#   'remember',
#   'one',
#   'tribute',
#   'of',
#   'thy',
#   'maimed,',
#   'two',
#   'two\r\nmore,',
#   'three',
#   'three',
#   'brethren,',
#   'sisters,',
#   'father,\r\nor',
#   'wife,',
#   'children,',
#   'lands,',
#   'on',
#   'from',
#   'not?',
#   'the',
#   'the',
#   'on',
#   'there',
#   'in',
#   'a',
#   'naked,',
#   'sick,',
#   'in',
#   'Jesus,',
#   'the'],
#  'words': ['of', 'thou', 'thou', 'shall'],
#  'the\r\nprophets.': ['I', 'While'],
#  'fulfill.': ['For'],
#  'verily': ['I'],
#  'say,\r\nUntil': ['heaven'],
#  'earth': ['pass',
#   'because',
#   'as',
#   'to',
#   'to',
#   'to',
#   'take',
#   'as',
#   'your',
#   'shall',
#   'shall',
#   'and'],
#  'pass': ['away,', 'them.', 'but', 'away', 'away,', 'from', 'away'],
#  'away,': ['not', 'He\r\nwent', 'but', 'and\r\n\r\ndelivered', 'and'],
#  'jot': ['or'],
#  'tittle': ['shall'],
#  'pass\r\nfrom': ['the'],
#  'fulfilled.': ['Whoever', 'When'],
#  'Whoever': ['breaks',
#   'looks',
#   'puts',
#   'puts',
#   'strikes',
#   'compels',
#   'hears',
#   'hears',
#   'confesses',
#   'denies',
#   'speaks',
#   'shall',
#   'has',
#   'saves',
#   'loses',
#   'shall',
#   'shall',
#   'marries\r\nher',
#   'will',
#   'will',
#   'falls'],
#  'breaks': ['one'],
#  'least\r\ncommandments,': ['and'],
#  'teaches': ['others'],
#  'others': ['to',
#   'their',
#   'their',
#   'to',
#   'do',
#   'standing',
#   'standing',
#   'who',
#   'but'],
#  'likewise': ['shall'],
#  'the\r\nleast': ['in', 'of'],
#  'whoever': ['shall', 'shall', 'speaks', 'has\r\nunderstanding,', 'says'],
#  'least\r\ncommandments': ['and'],
#  'teach': ['them', 'the', 'all\r\nnations.'],
#  'of\r\nheaven.': ['Unless', 'Ye'],
#  'Unless': ['your', 'those'],
#  'exceeds': ['the'],
#  'the\r\nscribes': ['and'],
#  'Pharisees,': ['there'],
#  'enter': ['the',
#   'into',
#   'into',
#   'into',
#   'into',
#   'into',
#   'into\r\nlife,',
#   'into\r\nthe',
#   'into',
#   'the\r\nkingdom',
#   'not',
#   'in.'],
#  'time,': ['Thou', 'thy', 'I', 'two', 'the', 'Judas', 'the'],
#  'kill;': ['and'],
#  'whoever\r\nshall': ['kill'],
#  'kill': ['shall', 'the', 'Him', 'him', 'you.', 'Him.'],
#  'danger': ['of', 'of', 'of', 'of'],
#  'judgment.': ['But', 'By'],
#  'you,\r\nWhoever': ['is'],
#  'angry': ['with', 'and'],
#  'brother': ['shall',
#   'shall',
#   'is',
#   'first.',
#   'shall',
#   'to',
#   "Philip's\r\n\r\nwife.",
#   'trespasses',
#   'sin\r\nagainst',
#   'shall'],
#  'judgment.\r\nWhoever': ['shows'],
#  'shows': ['contempt'],
#  'contempt': ['toward'],
#  'toward': ['his', 'His', 'them', 'them', 'Jesus.'],
#  'the\r\ncouncil.': ['But'],
#  'whosoever': ['curses'],
#  'curses': ['his'],
#  'hell': ['fire.', 'shall', 'fire.', 'than'],
#  'So,': ['if',
#   'if',
#   'take',
#   'by',
#   'when',
#   'again,',
#   'it',
#   'the',
#   'if',
#   'likewise,'],
#  'gift': ['to', 'before', 'that', 'by', 'that'],
#  'altar': ['and', 'that\r\nsanctifies'],
#  'remember': ['that', 'the', 'the'],
#  'thy\r\nbrother': ['has'],
#  'something': ['against', 'of'],
#  'thee,': ['leave',
#   'Thou',
#   'pluck',
#   'cut',
#   'do',
#   'Jesus,',
#   'Chorazin!',
#   'O',
#   'but',
#   'Thou',
#   'Lord.',
#   'one',
#   'cut',
#   'pluck',
#   'go',
#   'thou',
#   'then',
#   'not',
#   'meek,',
#   'how',
#   'I\r\nwill',
#   'I',
#   'by'],
#  'leave': ['the', 'that'],
#  'altar.': ['Be\r\nreconciled', 'All'],
#  'Be\r\nreconciled': ['to'],
#  'first.': ['Then', 'This', '20\r\nThe', 'Pilate'],
#  'back': ['and', 'into', 'to', 'into', 'to', 'the'],
#  'offer': ['thy', 'the'],
#  'gift.\r\nAgree': ['with'],
#  'thine': ['adversary', 'eye', 'eye', 'eye', 'own', 'own', 'and'],
#  'adversary': ['quickly', 'deliver'],
#  'quickly': ['while', 'the\r\nfig', 'and', 'left'],
#  'art': ['with',
#   'in',
#   'the',
#   'John',
#   'the',
#   'thou,',
#   'Peter,',
#   'an',
#   'true',
#   'a',
#   'thou',
#   'one'],
#  'him;': ['lest,'],
#  'lest,': ['at\r\nany'],
#  'at\r\nany': ['time,'],
#  'deliver': ['thee', 'us', 'you', 'you', 'up', 'Him', 'you', 'Jesus', 'Him'],
#  'judge,': ['and', 'ye\r\nshall'],
#  'judge\r\ndeliver': ['thee'],
#  'officer,': ['and'],
#  'prison.': ['Verily', 'Then', 'Therefore,'],
#  'Verily': ['I', 'I', 'I', 'I', 'I', 'I', 'I', 'I'],
#  'say\r\nunto': ['thee,', 'thee,'],
#  'paid.': ['Ye', 'When'],
#  'old,': ['Thou', 'Thou'],
#  'commit': ['adultery.\r\nBut', 'adultery.', 'adultery.'],
#  'adultery.\r\nBut': ['I'],
#  'looks': ['on'],
#  'woman': ['in',
#   'who',
#   'was',
#   'there',
#   'took',
#   'of',
#   'died',
#   'carrying',
#   'has'],
#  'lust': ['has'],
#  'already': ['committed\r\nadultery', 'come.'],
#  'committed\r\nadultery': ['in'],
#  'heart.': ['If', 'The', 'This', 'They\r\ndefile'],
#  'right': ['eye',
#   'cheek,',
#   'does.\r\nGive',
#   'I',
#   'you',
#   'hand,',
#   'hand',
#   'hand',
#   'hand,',
#   'hand',
#   'hand.',
#   'hand'],
#  'eye': ['offend', 'for', 'and', 'be', 'be', 'when,', 'offend'],
#  'offend': ['thee,', 'thee,', 'them,', 'thee,', 'thee,'],
#  'pluck': ['it', 'ears', 'it'],
#  'and\r\ncast': ['it'],
#  'away.': ['It', 'Ye', 'Also,', 'When', 'When', 'But,', 'So', 'The'],
#  'more': ['profitable',
#   'than',
#   'than',
#   'than',
#   'than\r\nraiment?',
#   'shall',
#   'shall',
#   'value',
#   'than',
#   'than',
#   'than',
#   'tolerable',
#   'tolerable',
#   'is\r\na',
#   'shall',
#   'over',
#   'servants',
#   'parables.',
#   'questions.',
#   'talents',
#   'talents',
#   'shall',
#   'than'],
#  'profitable': ['for'],
#  'members\r\nshould': ['perish'],
#  'perish': ['rather', 'rather'],
#  'whole': ['body',
#   'body',
#   'body\r\nshall',
#   'herd',
#   'city',
#   'and',
#   'multitude',
#   'from\r\nthat',
#   'world',
#   'band\r\nof'],
#  'body': ['be', 'be', 'is', 'more', 'but', 'of'],
#  'hell.': ['And', 'It', 'Are', 'If'],
#  'thy\r\nright': ['hand'],
#  'hand': ['offend',
#   'know',
#   'and',
#   'upon',
#   'toward',
#   'or',
#   'and',
#   'till',
#   'in',
#   'of',
#   'and\r\nthe'],
#  'cut': ['it', 'them', 'down'],
#  'off': ['and', 'and', 'a', 'his'],
#  'thee.': ['It',
#   'From',
#   'Behold,',
#   'Verily',
#   'Then',
#   'But',
#   'But',
#   '18\r\nAt',
#   'It\r\nis',
#   'It',
#   'What',
#   'Is',
#   'The',
#   'Then'],
#  'more\r\nprofitable': ['for'],
#  'members': ['should'],
#  'than\r\nthy': ['whole'],
#  'puts': ['away', 'away', 'forth'],
#  'wife': ['shall', 'for', 'and', 'unto', 'shall', 'sent'],
#  'writing\r\nof': ['divorcement.'],
#  'divorcement.': ['But'],
#  'wife,': ['except', 'and', 'except', 'it', 'or'],
#  'for\r\nreason': ['of'],
#  'fornication,': ['causes'],
#  'causes': ['her'],
#  'adultery.': ['And', 'Also,', 'Whoever', 'His', 'Thou'],
#  'whoever\r\nmarries': ['her'],
#  'divorced': ['commits'],
#  'commits': ['adultery.', 'adultery.', 'adultery.'],
#  'Also,': ['ye', 'some', 'in', 'he'],
#  'forswear\r\nthyself': ['but'],
#  'perform': ['your'],
#  'oaths': ['unto'],
#  'unto': ['the',
#   'you,',
#   'you,',
#   'you,',
#   'thy',
#   'you,',
#   'you.',
#   'you,',
#   'you.',
#   'you,',
#   'you,',
#   'you,',
#   'you,',
#   'their',
#   'thee,',
#   'you,',
#   'you,\r\nHere',
#   'victory.',
#   'you.',
#   'you',
#   'thee',
#   'me\r\nwith',
#   'thee',
#   'thee,',
#   'you,',
#   'you,',
#   'the',
#   'you,',
#   'the\r\nfirst.',
#   'the',
#   'thee,',
#   'Caesar',
#   'his',
#   'his',
#   'my',
#   'you,',
#   'you,',
#   'you,',
#   'you,',
#   'you,',
#   'you,',
#   'you,',
#   'men,',
#   'you,',
#   'yourselves.\r\nYe',
#   'you',
#   'the',
#   'ten',
#   'you,',
#   'you,',
#   'thee?',
#   'you?',
#   'you,',
#   'the',
#   'you,',
#   'us,',
#   'the'],
#  'oaths\r\nat': ['all.'],
#  'all.': ['Do', 'He', 'But'],
#  'swear': ['by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by\r\nheaven,',
#   'and\r\nsaid,'],
#  'throne.': ['Do'],
#  'swear\r\nby': ['the'],
#  'footstool.': ['Do'],
#  'Jerusalem': ['for\r\nit', 'came', 'and', 'where'],
#  'for\r\nit': ['is'],
#  'King.': ['Do'],
#  'self': ['because'],
#  'you\r\nare': ['incapable'],
#  'incapable': ['of'],
#  'making': ['even', 'a'],
#  'even': ['one',
#   'the',
#   'the',
#   'before',
#   'more,',
#   'in',
#   'the',
#   'one',
#   'after',
#   'lay',
#   'Christ;',
#   'Christ.',
#   'unto'],
#  'white': ['or', 'as', 'as'],
#  'black.': ['Let'],
#  'your\r\nstatement': ['be'],
#  'Yea,': ['yes;', 'Lord.', 'I', 'Lord.\r\nThen'],
#  'yes;': ['Nay,'],
#  'Nay,': ['no:'],
#  'no:': ['for'],
#  'anything': ['more', 'that', 'to', 'out'],
#  'comes\r\nto': ['evil.'],
#  'evil.': ['Ye', 'Whoever', 'For\r\nThine'],
#  'An': ['eye', 'evil', 'evil', 'enemy', 'angel'],
#  'tooth': ['for'],
#  'tooth.': ['But'],
#  'I\r\nsay,': ['Do'],
#  'resist': ['evil.'],
#  'strikes': ['thee'],
#  'cheek,': ['turn\r\nthe'],
#  'turn\r\nthe': ['other'],
#  'any': ['one',
#   'city',
#   'man',
#   'man',
#   'one',
#   'man',
#   'man',
#   'more',
#   'man',
#   'talent'],
#  'lawfully': ['sues'],
#  'sues': ['thee'],
#  'takes\r\naway': ['thy'],
#  'coat,': ['let'],
#  'let': ['him',
#   'thy',
#   'me',
#   'the',
#   'your',
#   'your',
#   'him',
#   'him',
#   'him',
#   'him',
#   'no',
#   'him',
#   'him\r\nbe',
#   'him',
#   'he',
#   'this',
#   'Him'],
#  'cloak': ['also.'],
#  'compels': ['thee'],
#  'go\r\na': ['mile,'],
#  'mile,': ['go'],
#  'two.': ['Give', 'But'],
#  'Give': ['to', 'us\r\nthis', 'them', 'us'],
#  'asks': ['of', 'for\r\nbread,', 'for'],
#  'From': ['him', 'the', 'that', 'heaven;', 'man;\r\nwe', 'the'],
#  'who\r\nwould': ['borrow'],
#  'borrow': ['of'],
#  'turn': ['away.', 'around\r\nand'],
#  'love': ['thy',
#   'only',
#   'you,',
#   'to\r\npray',
#   'the\r\nother,',
#   'thy',
#   'the',
#   'thy',
#   'the\r\nuppermost',
#   'of'],
#  'neighbour': ['and'],
#  'hate': ['thine\r\nenemy.', 'you.', 'the', 'one\r\nanother.'],
#  'thine\r\nenemy.': ['But'],
#  'Love': ['your'],
#  'enemy.': ['Bless'],
#  'Bless': ['those'],
#  'curse': ['you.', 'and'],
#  'good\r\nto': ['those'],
#  'Pray': ['for', 'like', 'to', 'that'],
#  'spitefully': ['use'],
#  'use': ['and', 'vain'],
#  'persecute\r\nyou.': ['Do'],
#  'may': ['be',
#   'be',
#   'but',
#   'go',
#   'be\r\nestablished.',
#   'have',
#   'sit,\r\none',
#   'be',
#   'be',
#   'be\r\nwilling,'],
#  'makes\r\nHis': ['sun'],
#  'sun': ['rise', 'was', 'in\r\nthe', 'will'],
#  'rise': ['on', 'up', 'in', 'again.', 'up'],
#  'evil': ['and',
#   'fruit.',
#   'fruit.',
#   'in',
#   'man,',
#   'of',
#   'things.',
#   'and',
#   'thoughts,',
#   'in',
#   'servant',
#   'has'],
#  'good.': ['He'],
#  'sends': ['rain'],
#  'rain': ['on', 'descended,', 'descended,'],
#  'and\r\non': ['the'],
#  'unjust.': ['If'],
#  'ye?\r\nDo': ['not'],
#  'publicans': ['do', 'do', 'and', 'and', 'and', 'and', 'and'],
#  'this?': ['And', 'They\r\nsaid', 'The', 'They'],
#  'greet': ['your', 'the'],
#  'friends': ['only,\r\nwhat'],
#  ...}

# %%
generate_sentence(matthew_dict)
# Out:
# 'Next morning all His mother and the blind, dumb, maimed, and sells\r\nall that the way.'

# %%
mark_text = data.transcripts.loc['Mark']
# Create the dictionary for Matthew's gospel, take a look at it
mark_dict = markov_chain(mark_text)
mark_dict
# Out:
# {'Title:': ['The'],
#  'The': ['Gospel',
#   'beginning',
#   'voice',
#   'spirit',
#   'time',
#   'kingdom',
#   'people',
#   'next',
#   'people',
#   'disciples',
#   'Pharisees',
#   'sabbath',
#   'Pharisees',
#   'sons',
#   'multitude',
#   'fowls',
#   'thorns',
#   'sower',
#   'wind',
#   'man\r\nhad',
#   'man\r\ncried',
#   'man',
#   'unclean',
#   'herd',
#   'swine',
#   'people',
#   'people',
#   'woman,',
#   'disciples',
#   'daughter',
#   'king\r\nsaid',
#   'head',
#   'king',
#   'king',
#   'apostles',
#   'devil',
#   'number',
#   'disciples\r\nreasoned',
#   'man',
#   'man',
#   'boy',
#   'Son',
#   'Pharisees',
#   'two',
#   'people',
#   'young',
#   'disciples\r\nwere',
#   'disciples',
#   'blind',
#   'next',
#   'disciples',
#   'scribes',
#   'man',
#   'husbandmen',
#   'man',
#   'stone',
#   'chief',
#   'second',
#   'third',
#   'seven',
#   'first',
#   'second',
#   'scribe',
#   'Lord',
#   'common',
#   'gospel',
#   'feast',
#   'chief',
#   'two',
#   'spirit',
#   'third',
#   'Son',
#   'one',
#   'chief',
#   'chief',
#   'multitude',
#   'soldiers\r\nled',
#   'superscription',
#   'King',
#   'scripture',
#   'chief',
#   'veil',
#   'Gospel'],
#  'Gospel': ['of', 'of', 'of'],
#  'of': ['Mark',
#   'Mark\r\n\r\n______________________________________________________________________\n',
#   'the',
#   'Jesus',
#   'God;\r\nAs',
#   'one',
#   'the',
#   'repentance\r\nfor',
#   'sins.',
#   'Judaea',
#   'whose',
#   'Jordan.',
#   'the',
#   'the',
#   'God',
#   'God',
#   'Galilee,',
#   'men.',
#   'Nazareth?\r\nArt',
#   'God.\r\nAnd',
#   'him.\r\nAnd',
#   'him.',
#   'Simon',
#   'the',
#   'the',
#   'man',
#   'Alphaeus,',
#   'custom,',
#   'a',
#   'John',
#   'the',
#   'John',
#   'the',
#   'new',
#   'corn',
#   'God',
#   'man',
#   'the\r\nsabbath',
#   'Him.',
#   'Zebedee,',
#   'James',
#   'thunder);',
#   'Alphaeus;',
#   'Him\r\nand',
#   'the',
#   'men,\r\nand',
#   'God,',
#   'seeds.',
#   'the',
#   'the',
#   'God.\r\nBut,',
#   'the',
#   'this\r\nworld,',
#   'riches,',
#   'other',
#   'set',
#   'God',
#   'God?',
#   'mustard',
#   'the',
#   'it.',
#   'water.',
#   'the',
#   'man',
#   'the',
#   'the',
#   'his',
#   'the',
#   'the',
#   'swine',
#   'the',
#   'the\r\nsynagogue,',
#   'death.',
#   'blood',
#   'Jesus',
#   'her',
#   'Him,\r\nturned',
#   'thy',
#   'the',
#   'James.',
#   'the',
#   'the',
#   'the\r\ndamsel',
#   'Jesus',
#   'Mary,',
#   'this,',
#   'the',
#   'judgment',
#   'them.',
#   'Him',
#   'the',
#   'John.',
#   'Galilee.',
#   'Herodias',
#   'me',
#   'him,',
#   'his',
#   'John',
#   'those',
#   'this,',
#   'bread',
#   'the',
#   'bread',
#   'the',
#   'the',
#   'the',
#   'good',
#   'the',
#   'Gennesaret.',
#   'the',
#   'the',
#   'cups,',
#   'tables.',
#   'the',
#   'you',
#   'men.',
#   'God,',
#   'men,',
#   'pots',
#   'God',
#   'God',
#   'the',
#   'men,',
#   'Tyre',
#   'Him.',
#   'Tyre',
#   'the',
#   'Decapolis.',
#   'them',
#   'those',
#   'Him',
#   'the',
#   'Herod.',
#   'fragments',
#   'fragments',
#   'the',
#   'Caesarea',
#   'the',
#   'Him.',
#   'man\r\nmust',
#   'God,',
#   'men.',
#   'me',
#   'my',
#   'man',
#   'His',
#   'death',
#   'God',
#   'snow,',
#   'the',
#   'man',
#   'man',
#   'the',
#   'the\r\nchild',
#   'him.',
#   'him.',
#   'man',
#   'men.',
#   'all',
#   'all.',
#   'them.',
#   'such',
#   'me.',
#   'water',
#   'these',
#   'God',
#   'Judaea',
#   'Jordan.',
#   'a',
#   'divorcement',
#   'the\r\nhardness',
#   'your',
#   'the',
#   'such',
#   'God.',
#   'God',
#   'God!',
#   'a',
#   'God.',
#   'man\r\nshall',
#   'Zebedee,',
#   'the',
#   'the',
#   'man',
#   'Timaeus,',
#   'the',
#   'David,',
#   'good',
#   'Olives,',
#   'His',
#   'him;',
#   'the',
#   'our',
#   'the',
#   'thee',
#   'those',
#   'prayer',
#   'thieves.',
#   'the',
#   'men?',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Jesus,',
#   'the',
#   'men,',
#   'all',
#   'Isaac,',
#   'Jacob?',
#   'the',
#   'the',
#   'all?',
#   'all',
#   'the',
#   'the',
#   'their',
#   'the',
#   'His',
#   'Olives',
#   'wars',
#   'wars,',
#   'sorrows.',
#   'desolation,',
#   'by',
#   'the',
#   "God's",
#   'man',
#   'the',
#   'heaven.',
#   'these',
#   'the',
#   'Man',
#   'the',
#   'dawn,',
#   'the',
#   'unleavened',
#   'Simon',
#   'very',
#   'spikenard.',
#   'the',
#   'the',
#   'the',
#   'his',
#   'unleavened',
#   'His',
#   'water.\r\nFollow',
#   'the',
#   'you',
#   'the',
#   'man',
#   'Him:',
#   'man',
#   'the',
#   'the',
#   'the',
#   'God.',
#   'Olives.\r\nJesus',
#   'me',
#   'man',
#   'the',
#   'them',
#   'the',
#   'the',
#   'the',
#   'man',
#   'power,',
#   'heaven.',
#   'any',
#   'death.',
#   'their',
#   'the',
#   'the',
#   'Nazareth.',
#   'them.',
#   'them.',
#   'whom',
#   'the',
#   'many',
#   'the',
#   'thorns,',
#   'the',
#   'Alexander',
#   'the',
#   'a',
#   'the',
#   'Israel',
#   'those\r\nwho',
#   'vinegar,',
#   'the',
#   'God.',
#   'James',
#   'Arimathaea,',
#   'God,',
#   'rock,',
#   'Joses',
#   'the',
#   'James,',
#   'the',
#   'the\r\nsepulchre',
#   'Nazareth,',
#   'whom',
#   'them',
#   'heart',
#   'God.',
#   'Project',
#   'Mark'],
#  'Mark': ['for', 'for'],
#  'for': ['Readers',
#   'forty',
#   'they',
#   'He',
#   'thee.',
#   'therefore',
#   'thy\r\ncleansing',
#   'a',
#   'the',
#   'man,\r\nand',
#   'the',
#   'the',
#   'thee.',
#   'a',
#   'the',
#   'we',
#   'thee,',
#   'him.',
#   'twelve',
#   'their',
#   'Sodom',
#   'Herodias,',
#   'him',
#   'his',
#   'his',
#   'the\r\nsake',
#   'they',
#   'the',
#   'their',
#   'the',
#   'doctrines\r\nthe',
#   'his',
#   'a',
#   'my',
#   'his',
#   'us',
#   'thee,',
#   'Moses,',
#   'Elias.',
#   'He\r\ntaught',
#   'him',
#   'thee',
#   'thee',
#   'thee',
#   'a\r\nman',
#   'of',
#   'those',
#   'a',
#   'my',
#   'whom',
#   'many.',
#   'thee?',
#   'figs.',
#   'the',
#   'there',
#   'a',
#   'such\r\nthings',
#   'my',
#   'a',
#   'it',
#   "my\r\nname's",
#   'the',
#   'ye',
#   'a',
#   'burying.',
#   'us',
#   'that',
#   'many.',
#   'it\r\nis',
#   'witness',
#   'Pilate\r\nto',
#   'the',
#   'us?',
#   'they',
#   'their',
#   'Readers,'],
#  'Readers': ['Editor:'],
#  'Editor:': ['Lightheart'],
#  'Lightheart': ['Release'],
#  'Release': ['date:'],
#  'date:': ['September'],
#  'September': ['1,'],
#  '1,': ['2004'],
#  '2004': ['[eBook'],
#  '[eBook': ['#6530]\r\n'],
#  '#6530]\r\n': [''],
#  '': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Most',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'The',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'After',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Then',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Later,',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'They',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'And',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Pharisees',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Jesus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'After',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'From',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'They',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'He',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'As',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'The',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'First',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'When',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'edited',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'www.PracticeGodsPresence.com'],
#  'Most': ['recently'],
#  'recently': ['updated:'],
#  'updated:': ['August'],
#  'August': ['21,'],
#  '21,': ['2012'],
#  '2012': ['Language:'],
#  'Language:': ['English'],
#  'English': ['Copyright'],
#  'Copyright': ['(C)'],
#  '(C)': ['2002'],
#  '2002': ['by'],
#  'by': ['Lightheart.',
#   'him',
#   'John',
#   'Satan',
#   'the',
#   'the',
#   'four',
#   'the',
#   'the',
#   'parables.',
#   'the',
#   'the',
#   'saying,',
#   'the',
#   'a',
#   'God',
#   'boat',
#   'name.',
#   'the',
#   'His',
#   'His\r\nhands?',
#   'boat.',
#   'hundreds',
#   'fifties.\r\nThen,',
#   'them.',
#   'whatsoever',
#   'nation;',
#   'the',
#   'boat',
#   'the',
#   'the',
#   'the',
#   'prayer',
#   'way',
#   'a',
#   'the',
#   'all',
#   'what',
#   'what\r\nauthority',
#   'parables.',
#   'all',
#   'Daniel',
#   'craft',
#   'one,\r\nask',
#   'whom',
#   'said',
#   'thy',
#   'on',
#   'railed',
#   'Lightheart\r\n',
#   'Lightheart'],
#  'Lightheart.': ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0www.PracticeGodsPresence.com\r\n\r\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0The'],
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0www.PracticeGodsPresence.com\r\n\r\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0The': ['Gospel'],
#  'Mark\r\n\r\n______________________________________________________________________\n': ['1.'],
#  '1.': [''],
#  'beginning': ['of', 'of', 'of'],
#  'the': ['gospel',
#   'Son',
#   'prophets,',
#   'way',
#   'way',
#   'Lord,',
#   'wilderness,',
#   'baptism',
#   'remission',
#   'river',
#   'latchet',
#   'Holy',
#   'river',
#   'water,',
#   'heavens',
#   'wilderness.',
#   'angels',
#   'gospel',
#   'kingdom',
#   'gospel.',
#   'sea',
#   'sea',
#   'son',
#   'boat\r\nwith',
#   'hired',
#   'sabbath',
#   'synagogue\r\nand',
#   'scribes.',
#   'Holy',
#   'unclean',
#   'unclean',
#   'region',
#   'synagogue,',
#   'house',
#   'hand.',
#   'fever',
#   'city\r\ngathered',
#   'door.',
#   'devils\r\nto',
#   'next',
#   'synagogues',
#   'leprosy',
#   'man',
#   'priest',
#   'matter.',
#   'city',
#   'house.\r\nAnd,',
#   'door.',
#   'crowd,',
#   'roof',
#   'bed',
#   'sick',
#   'sick',
#   'scribes',
#   'Son',
#   'sick',
#   'bed,',
#   'seaside',
#   'multitude',
#   'son',
#   'receipt',
#   'scribes\r\nand',
#   'righteous,',
#   'Pharisees',
#   'disciples',
#   'Pharisees',
#   'children',
#   'bridechamber\r\nfast',
#   'bridegroom',
#   'day',
#   'new',
#   'old',
#   'rent',
#   'new',
#   'wine',
#   'bottles',
#   'corn',
#   'ears',
#   'sabbath',
#   'house',
#   'days',
#   'high',
#   'showbread?',
#   'priests',
#   'sabbath;',
#   'Son',
#   'synagogue',
#   'man',
#   'sabbath',
#   'hardness',
#   'man,',
#   'man\r\nstretched',
#   'Herodians\r\nabout',
#   'sea.',
#   'things',
#   'Son',
#   'brother',
#   'son',
#   'Canaanite;',
#   'multitude',
#   'scribes',
#   'prince',
#   'devils,',
#   'strong',
#   'sons',
#   'Holy',
#   'will',
#   'same',
#   'seaside,',
#   'large\r\ncrowd',
#   'wayside.',
#   'air',
#   'sunlight',
#   'twelve',
#   'parable',
#   'people',
#   'mystery',
#   'kingdom',
#   'teachings',
#   'people',
#   'wayside,',
#   'word',
#   'word\r\nthat',
#   'word,',
#   "word's",
#   'seed',
#   'thorns',
#   'cares',
#   'deceitfulness',
#   'lusts',
#   'word,',
#   'word,\r\nthey',
#   'kingdom',
#   'ground.',
#   'seed',
#   'earth',
#   'blade,',
#   'ear,',
#   'full',
#   'fruit',
#   'sickle',
#   'harvest',
#   'kingdom',
#   'earth,',
#   'seeds',
#   'fowls',
#   'air',
#   'multitude,',
#   'boat.',
#   'boat',
#   'back',
#   'boat,',
#   'wind,',
#   'sea,\r\nPeace,',
#   'wind',
#   'other',
#   'sea,',
#   'country\r\nof',
#   'Gadarenes.',
#   'boat,',
#   'tombs.',
#   'chains',
#   'mountains',
#   'tombs,',
#   'most',
#   'man',
#   'man,',
#   'country.',
#   'mountains,',
#   'swine.',
#   'sea',
#   'city',
#   'country.',
#   'man',
#   'devil',
#   'legion,\r\nsitting,',
#   'others',
#   'man',
#   'swine.',
#   'boat,',
#   'man',
#   'great',
#   'Lord',
#   'great',
#   'other',
#   'rulers',
#   'point',
#   'people',
#   'crowd',
#   'crowd,',
#   'fountain',
#   'multitude',
#   'truth.',
#   'ruler',
#   "synagogue's\r\nhouse",
#   'Master',
#   'message,',
#   'ruler',
#   'brother',
#   'house',
#   'ruler',
#   'synagogue,',
#   'house',
#   'father',
#   'hand',
#   'damsel,',
#   'sabbath',
#   'synagogue.',
#   'sayings',
#   'carpenter,',
#   'son',
#   'brother',
#   'sick',
#   'villages',
#   'area.',
#   'twelve',
#   'dust',
#   'day',
#   'Baptist',
#   'dead',
#   'prophets.',
#   'dead.',
#   'damsel,',
#   'Baptist.',
#   'king',
#   'head',
#   'Baptist',
#   'prison.',
#   'damsel.',
#   'damsel',
#   'people',
#   'multitude',
#   'day',
#   'country',
#   'villages',
#   'people',
#   'five',
#   'two',
#   'loaves',
#   'two',
#   'fragments',
#   'loaves\r\nwere',
#   'boat',
#   'other',
#   'people',
#   'boat',
#   'sea.',
#   'land.',
#   'wind\r\nwas',
#   'fourth',
#   'night',
#   'sea,',
#   'sea,',
#   'boat.',
#   'wind\r\nceased',
#   'miracle',
#   'loaves',
#   'other',
#   'land',
#   'boat,',
#   'people',
#   'area',
#   'region,\r\nmany',
#   'sick',
#   'sick',
#   'border',
#   'Pharisees,',
#   'Jews,',
#   'tradition',
#   'elders',
#   'tradition',
#   'elders,',
#   'commandment',
#   'tradition',
#   'washing',
#   'word',
#   'people',
#   'things',
#   'man.',
#   'house,',
#   'man',
#   'draught,',
#   'man',
#   'man.',
#   'borders',
#   'devil',
#   'children',
#   "child's",
#   'dogs.',
#   'dogs',
#   'table',
#   "child's",
#   'devils',
#   'coasts',
#   'sea',
#   'midst',
#   'coasts',
#   'man',
#   "man's",
#   "man's",
#   'more',
#   'deaf',
#   'dumb',
#   'multitude',
#   'way.',
#   'people',
#   'ground.',
#   'loaves',
#   'people.',
#   'disciples',
#   'people.',
#   'disciples',
#   'broken',
#   'multitude',
#   'Pharisees\r\ncame',
#   'other',
#   'disciples',
#   'boat',
#   'leaven',
#   'Pharisees',
#   'leaven',
#   'five',
#   'seven',
#   'man.',
#   'blind',
#   'hand',
#   'town.',
#   "man's",
#   'man',
#   'town,',
#   'town.',
#   'towns',
#   'way',
#   'Baptist,',
#   'prophets.',
#   'Christ.',
#   'Son',
#   'elders,',
#   'things',
#   'things',
#   'people',
#   "gospel's,",
#   'Son',
#   'glory',
#   'holy\r\nangels.',
#   'kingdom',
#   'white',
#   'cloud\r\nsaying,',
#   'mountain',
#   'Son',
#   'dead.',
#   'rising',
#   'Son',
#   'disciples,',
#   'people',
#   'scribes,',
#   'multitude\r\nanswered,',
#   'mouth,',
#   'spirit',
#   'ground',
#   'father',
#   'son.',
#   'fire',
#   'water',
#   'man,',
#   'father',
#   'foul',
#   'hand,\r\nlifted',
#   'third',
#   'house',
#   'way?',
#   'way',
#   'greatest.',
#   'same\r\nshall',
#   'midst',
#   'child',
#   'sea.',
#   'fire',
#   'worm',
#   'fire',
#   'kingdom',
#   'salt',
#   'coasts',
#   'writing',
#   'beginning',
#   'creation,',
#   'house,',
#   'people',
#   'disciples,',
#   'little',
#   'kingdom',
#   'kingdom',
#   'road,',
#   'commandments,',
#   'proceeds',
#   'young',
#   'kingdom',
#   'kingdom',
#   'eye',
#   'kingdom',
#   'last',
#   'way,',
#   'Son',
#   'chief',
#   'Gentiles.',
#   'sons',
#   'cup',
#   'baptism',
#   'cup',
#   'baptism',
#   'other',
#   'Gentiles',
#   'Son',
#   'son',
#   'side',
#   'highway.',
#   'blind',
#   'Lord',
#   'village',
#   'colt',
#   'door',
#   'colt?',
#   'colt,',
#   'way.',
#   'trees,',
#   'way.',
#   'Lord.',
#   'kingdom',
#   'name',
#   'Lord.',
#   'highest.',
#   'temple.',
#   'evening.',
#   'twelve.',
#   'time',
#   'fruit',
#   'temple.',
#   'temple.',
#   'tables',
#   'seats',
#   'temple.',
#   'people',
#   'city.',
#   'fig',
#   'roots.',
#   'fig',
#   'sea;',
#   'temple,',
#   'scribes,',
#   'elders.',
#   'baptism',
#   'people',
#   'winevat',
#   'end',
#   'season',
#   'husbandmen\r\nto',
#   'fruit',
#   'vineyard.',
#   'servant.',
#   'head.',
#   'man',
#   'heir;',
#   'son,',
#   'vineyard.',
#   'lord',
#   'vineyard',
#   'husbandmen',
#   'vineyard',
#   'builders',
#   'cornerstone',
#   'whole',
#   'people.',
#   'Pharisees',
#   'person',
#   'way',
#   'things',
#   'things\r\nthat',
#   'Sadducees,',
#   'resurrection.',
#   'seven',
#   'scriptures',
#   'power\r\nof',
#   'dead,',
#   'angels',
#   'dead',
#   'book\r\nof',
#   'bush',
#   'God',
#   'God',
#   'God',
#   'God\r\nof',
#   'dead,',
#   'God',
#   'living.',
#   'scribes',
#   'commandments',
#   'Lord',
#   'first',
#   'truth,',
#   'understanding,',
#   'soul,',
#   'strength,',
#   'burnt',
#   'kingdom\r\nof',
#   'scribes',
#   'son\r\nof',
#   'scribes,',
#   'marketplace,',
#   'best',
#   'synagogues,\r\nand',
#   'uppermost',
#   'treasury',
#   'people',
#   'rest\r\nhave',
#   'treasury.',
#   'temple,',
#   'mount',
#   'temple.',
#   'end',
#   'Holy',
#   'end',
#   'abomination',
#   'mountains.',
#   'housetop',
#   'house',
#   'field',
#   'winter.',
#   'Lord',
#   'sake',
#   'elect,',
#   'days.',
#   'beginning',
#   'days',
#   'sun',
#   'stars',
#   'powers',
#   'Son',
#   'four',
#   'earth',
#   'uttermost',
#   'fig',
#   'same',
#   'door.',
#   'hour,',
#   'angels',
#   'Father',
#   'time',
#   'Son',
#   'porter',
#   'master',
#   'house',
#   'break',
#   'passover',
#   'scribes',
#   'feast\r\nday,',
#   'people.',
#   'house',
#   'leper.',
#   'container',
#   'oil.',
#   'others',
#   'table',
#   'ointment',
#   'money',
#   'poor.',
#   'poor',
#   'world,',
#   'twelve,',
#   'chief',
#   'first',
#   'passover\r\nlamb,',
#   'passover?',
#   'city.\r\nHe',
#   'good',
#   'house,\r\nThe',
#   'guestchamber',
#   'city',
#   'passover.',
#   'evening',
#   'twelve',
#   'dish.\r\nThe',
#   'Son',
#   'cup\r\nand,',
#   'new',
#   'fruit',
#   'vine',
#   'kingdom',
#   'mount',
#   'shepherd,',
#   'sheep',
#   'cock',
#   'more',
#   'same.',
#   'hour',
#   'same',
#   'hands',
#   'twelve,',
#   'chief',
#   'high',
#   'temple,',
#   'scriptures',
#   'linen',
#   'high',
#   'chief',
#   'scribes',
#   'palace',
#   'high',
#   'servants\r\nwho',
#   'council',
#   'high',
#   'high',
#   'Son',
#   'Blessed?',
#   'right',
#   'high',
#   'blasphemy.',
#   'servants',
#   'palms',
#   'maids',
#   'high',
#   'cock',
#   'word',
#   'cock',
#   'next',
#   'chief',
#   'elders',
#   'whole',
#   'King',
#   'Jews?',
#   'people\r\nchose.',
#   'multitude,',
#   'King',
#   'Jews?',
#   'chief',
#   'King\r\nof',
#   'Jews?',
#   'more,',
#   'people,',
#   'hall,',
#   'whole',
#   'Jews!',
#   'head',
#   'purple',
#   'father',
#   'country,',
#   'place',
#   'place',
#   'third',
#   'Jews.\r\nAlong',
#   'transgressors.',
#   'cross.',
#   'scribes',
#   'cross',
#   'whole',
#   'ninth',
#   'temple',
#   'top',
#   'centurion',
#   'Son',
#   'mother',
#   'less',
#   'preparation',
#   'kingdom',
#   'body',
#   'centurion,',
#   'body.',
#   'linen.',
#   'mother',
#   'sabbath',
#   'morning',
#   'week,',
#   'mother',
#   'sepulchre',
#   'rising',
#   'sun.',
#   'stone',
#   'door',
#   'large\r\nstone',
#   'sepulchre,',
#   'right\r\nside,',
#   'place',
#   'sepulchre;',
#   'rest,',
#   'eleven',
#   'world',
#   'gospel',
#   'sick,',
#   'Lord',
#   'right',
#   'Lord'],
#  'gospel': ['of', 'of', 'must', 'shall', 'to\r\nevery'],
#  'Jesus': ['Christ,',
#   'came',
#   'came',
#   'said',
#   'of',
#   'rebuked',
#   'about',
#   'healed',
#   'said',
#   'preached',
#   'was',
#   'directly',
#   'could',
#   'entered',
#   'preached',
#   'because',
#   'stood.',
#   'saw\r\ntheir',
#   'realized',
#   'went',
#   'sat',
#   'and',
#   'heard',
#   'and',
#   'said',
#   'responded,',
#   'said',
#   'entered',
#   'would',
#   'said',
#   'said',
#   'looked',
#   'withdrew',
#   'told',
#   'directly',
#   'went',
#   'called',
#   'answered,',
#   'was',
#   'began,\r\nHearken.',
#   'finished',
#   'said',
#   'said',
#   'said,',
#   'said,',
#   'spoke',
#   'told',
#   'was',
#   'arose,',
#   'said',
#   'got',
#   'from',
#   'asked,',
#   'that',
#   'gave',
#   'suffered',
#   'crossed',
#   'went',
#   'and,\r\npressing',
#   'heard',
#   'allowed',
#   'saw',
#   'said',
#   'took',
#   'charged',
#   'and',
#   'said,',
#   'went',
#   'called',
#   'said\r\nto',
#   'saw',
#   'answered,',
#   'commanded',
#   'was',
#   'talked',
#   'answered,',
#   'replied,',
#   'said',
#   'then\r\nsaid',
#   'took',
#   'charged',
#   'called',
#   'asked',
#   'told',
#   'blessed',
#   'sent',
#   'sighed',
#   'uttered,',
#   'realized',
#   'said,',
#   'asked',
#   'put',
#   'sent',
#   'and',
#   'said',
#   'charged',
#   'said',
#   'turned',
#   'took',
#   'instructed',
#   'answered',
#   'asked',
#   'stepped',
#   'looked',
#   'asked',
#   'said',
#   'rebuked',
#   'took',
#   'went',
#   'asked',
#   'then',
#   'said,',
#   'went',
#   'asked,',
#   'answered,',
#   'was',
#   'took',
#   'turned',
#   'and',
#   'led',
#   'said',
#   'answered,',
#   'said,',
#   'called',
#   'passed',
#   'stood',
#   'said',
#   'commanded\r\nand',
#   'sat',
#   'came',
#   'said',
#   'went',
#   'said',
#   'answered,',
#   'answered,',
#   'then',
#   'in',
#   'replied,',
#   'answered,',
#   'had',
#   'answered,',
#   'saw',
#   'said,',
#   'sat',
#   'called',
#   'answered,\r\nSee',
#   'sat',
#   'cautioned',
#   'was',
#   'said,',
#   'to',
#   'had',
#   'came',
#   'said,',
#   'answered,',
#   'took',
#   'said',
#   'said',
#   'went',
#   'said',
#   'went',
#   'said,',
#   'to',
#   'held',
#   'said,',
#   'of',
#   'still',
#   'scourged,',
#   'cried',
#   'cried',
#   'of',
#   'appeared'],
#  'Christ,': ['the', 'shall'],
#  'Son': ['of',
#   'in',
#   'of',
#   'of',
#   'of\r\nGod.',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'God;\r\nAs': ['it'],
#  'it': ['is',
#   'came',
#   'is',
#   'came',
#   'that',
#   'up',
#   'came',
#   'to',
#   'lawful\r\nto',
#   'out,',
#   'had',
#   'was\r\nscorched',
#   'is',
#   'with',
#   'becomes',
#   'and',
#   'shall',
#   'is',
#   'is',
#   'grows',
#   'that',
#   'in',
#   'told',
#   'befell',
#   'was',
#   'to',
#   'to',
#   'in',
#   'is',
#   'to',
#   'was',
#   'enters',
#   'to',
#   'saying,',
#   'be',
#   'to',
#   'profit',
#   'is',
#   'was',
#   'is',
#   'has\r\ncast',
#   'that',
#   'off.',
#   'off.',
#   'lawful',
#   'shall',
#   'for',
#   'is',
#   'drew',
#   'was',
#   'a',
#   'out',
#   'is',
#   'lawful',
#   'is',
#   'ought',
#   'be',
#   'is',
#   'I?',
#   'I?',
#   'is',
#   'for',
#   'and',
#   'to',
#   'anew',
#   'means',
#   'were',
#   'that',
#   'again.',
#   'around',
#   'not.',
#   'up',
#   'on',
#   'was',
#   'from',
#   'to',
#   'shall'],
#  'is': ['written',
#   'fulfilled.',
#   'at',
#   'this?',
#   'this?',
#   'easier',
#   'it',
#   'with',
#   'made',
#   'spilled,',
#   'not',
#   'Lord',
#   'too',
#   'in',
#   'my',
#   'given',
#   'sown.\r\nWhen',
#   'nothing\r\nkept',
#   'the',
#   'ripe,',
#   'come.',
#   'like',
#   'sown',
#   'less',
#   'sown,',
#   'it',
#   'this',
#   'thy',
#   'at',
#   'dead.',
#   'not',
#   'this\r\nthat',
#   'given',
#   'Elias.',
#   'risen',
#   'a',
#   'very',
#   'far\r\nfrom',
#   'Corban,',
#   'nothing',
#   'what',
#   'from',
#   'not',
#   'gone',
#   'because',
#   'good',
#   'my',
#   'also',
#   'indeed\r\ncome',
#   'dead.',
#   'delivered',
#   'killed,',
#   'no',
#   'not',
#   'on',
#   'better',
#   'never',
#   'better',
#   'never',
#   'better',
#   'good.',
#   'the',
#   'none',
#   'it',
#   'easier',
#   'not',
#   'prepared.',
#   'He',
#   'written:',
#   'withered',
#   'in',
#   'in',
#   'the',
#   'marvellous',
#   'on',
#   'no',
#   'not',
#   'the\r\nfirst',
#   'one',
#   'the',
#   'no',
#   'no',
#   'worth',
#   'the',
#   'he,',
#   'not',
#   'in',
#   'Christ;',
#   'yet',
#   'near.',
#   'near,',
#   'like',
#   'where',
#   'furnished',
#   'one',
#   'written',
#   'betrayed!',
#   'my',
#   'my',
#   'exceedingly',
#   'ready,',
#   'weak.',
#   'enough.\r\nThe',
#   'now',
#   'at',
#   'made',
#   'it',
#   'one',
#   'not',
#   'baptized'],
#  'written': ['in', 'that', 'of', 'and'],
#  'in': ['the',
#   'the\r\nwilderness,',
#   'the',
#   'the',
#   'those',
#   'the',
#   'whom',
#   'prison',
#   'a',
#   'the',
#   'their\r\nsynagogue',
#   'the',
#   'your',
#   "Levi's",
#   'the',
#   'danger\r\nof',
#   'parables:',
#   'their',
#   'the',
#   'parables.',
#   'the',
#   'the',
#   'the',
#   'pieces.',
#   'the',
#   'the',
#   'one',
#   'the',
#   'the',
#   'his',
#   'Decapolis',
#   'Himself',
#   'fear',
#   'her,',
#   'peace,',
#   'the',
#   'his',
#   'his',
#   'the',
#   'their',
#   'the',
#   'him.',
#   'the',
#   'a',
#   'groups',
#   'ranks,',
#   'the\r\nmidst',
#   'the',
#   'beds',
#   'the\r\nstreets',
#   'vain',
#   'order',
#   'the\r\nwilderness?',
#   'His',
#   'the',
#   'the',
#   'this\r\nadulterous',
#   'the',
#   'foam.',
#   'the',
#   'His',
#   'my',
#   'thy',
#   'my\r\nname,',
#   'me,',
#   'yourselves,',
#   'the',
#   'His',
#   'heaven.',
#   'riches',
#   'eternal',
#   'thy',
#   'a\r\nplace',
#   'the',
#   'the',
#   'the\r\nname',
#   'the',
#   'the',
#   'the',
#   'his',
#   'heaven',
#   'heaven',
#   'the',
#   'the',
#   'our',
#   'His',
#   'marriage.',
#   'heaven.',
#   'the',
#   'the',
#   'His',
#   'flowing',
#   'the',
#   'the',
#   'large',
#   'two',
#   'than',
#   'what',
#   'my',
#   'divers',
#   'that',
#   'Judaea',
#   'the',
#   'the',
#   'those',
#   'the\r\nclouds',
#   'glory.',
#   'heaven',
#   'daylight.',
#   'His',
#   'two\r\ndays.',
#   'Bethany',
#   'the',
#   'the',
#   'any',
#   'to',
#   'the',
#   'the\r\nclouds',
#   'insurrection',
#   'the\r\ninsurrection.',
#   'three',
#   'two',
#   'Galilee,',
#   'the',
#   'the',
#   'a',
#   'another'],
#  'prophets,': ['Behold,'],
#  'Behold,': ['I', 'why', 'thy', 'my', 'there', 'He'],
#  'I': ['send',
#   'am',
#   'have',
#   'am',
#   'will',
#   'know',
#   'may',
#   'will.\r\nBe',
#   'say',
#   'came',
#   'say',
#   'to',
#   'adjure',
#   'may',
#   'shall',
#   'say\r\nto',
#   'say',
#   'beheaded.',
#   'will',
#   'ask?',
#   'will\r\nthat',
#   'have',
#   'send',
#   'say',
#   'broke',
#   'see',
#   'am?',
#   'am?',
#   'say',
#   'say',
#   'have',
#   'spoke',
#   'be',
#   'suffer',
#   'believe.',
#   'charge',
#   'say',
#   'do',
#   'have',
#   'do\r\nfor',
#   'drink',
#   'am',
#   'drink',
#   'am',
#   'call\r\nthee.',
#   'do',
#   'might\r\nreceive',
#   'will',
#   'do',
#   'tell',
#   'do',
#   'am',
#   'make',
#   'am',
#   'have',
#   'say',
#   'will',
#   'drink',
#   'will',
#   'am',
#   'will',
#   'will',
#   'will',
#   'should',
#   'go',
#   'will,',
#   'shall',
#   'was',
#   'will',
#   'will',
#   'am:',
#   'do',
#   'do',
#   'release'],
#  'send': ['my', 'forth', 'them', 'him.', 'His'],
#  'my': ['messenger',
#   'beloved',
#   'brethren?',
#   'mother',
#   'brethren!',
#   'brother,',
#   'sister,',
#   'clothes?',
#   'sake',
#   'words',
#   'beloved',
#   'son',
#   'unbelief.',
#   'name,\r\nreceives',
#   'name',
#   'sake',
#   'left',
#   'sight.',
#   'son.',
#   'Lord,',
#   'name',
#   'sake,',
#   'words',
#   'body',
#   'body.',
#   'blood',
#   'God,',
#   'name'],
#  'messenger': ['who\r\nshall'],
#  'who\r\nshall': ['prepare'],
#  'prepare': ['the', 'that\r\nthou'],
#  'way': ['before',
#   'of',
#   'to',
#   'He',
#   'back,',
#   'of\r\nthe',
#   'of\r\nGod.',
#   'out'],
#  'before': ['thee.',
#   'dawn,',
#   'them',
#   'Him',
#   'them',
#   'the',
#   'the',
#   'them.',
#   'Him',
#   'rulers',
#   'you',
#   'the',
#   'the\r\nsabbath,',
#   'you'],
#  'thee.': ['The', 'And', 'There', 'Jesus', 'Then', 'Jesus\r\nanswered,'],
#  'voice': ['of', 'from\r\nheaven', 'came', 'and\r\ntook'],
#  'one': ['crying',
#   'mightier',
#   'with',
#   'sick',
#   'to',
#   'could',
#   'voice,',
#   'of',
#   'to\r\nfollow',
#   'of',
#   'loaf',
#   'of',
#   'for',
#   'for',
#   'of',
#   'of',
#   'casting',
#   'of',
#   'with\r\nanother.',
#   'flesh:',
#   'flesh.',
#   'on',
#   'Lord.',
#   'of',
#   'stone',
#   'that',
#   'of',
#   'by',
#   'of',
#   'hour',
#   'who',
#   'of',
#   'of',
#   'of',
#   'of',
#   'prisoner,',
#   'named',
#   'on',
#   'because'],
#  'crying': ['in'],
#  'the\r\nwilderness,': ['Prepare'],
#  'Prepare': ['the'],
#  'Lord,': ['make', 'I', 'that', 'Sit'],
#  'make': ['His',
#   'you',
#   'me',
#   'Him',
#   'this',
#   'all',
#   'the',
#   'three',
#   'thine',
#   'long'],
#  'His': ['paths',
#   'coming',
#   'doctrine',
#   'fame',
#   'hand,',
#   'arrival\r\nwas',
#   'disciples',
#   'disciples',
#   'friends',
#   'brethren',
#   'mother',
#   'disciples',
#   'disciples',
#   'feet',
#   'clothes,',
#   'disciples',
#   'disciples,',
#   'own',
#   'sisters',
#   'hands',
#   'name',
#   'disciples\r\ncame',
#   'disciples',
#   'disciples',
#   'disciples',
#   'feet.',
#   'hand',
#   'fingers',
#   'tongue',
#   'disciples',
#   'disciples\r\nanswered',
#   'disciples',
#   'disciples',
#   'spirit',
#   'hands\r\nupon',
#   'hands\r\nagain',
#   'disciples',
#   'disciples,',
#   'disciples.',
#   'disciples,',
#   'Father',
#   'raiment\r\nbecame',
#   'disciples\r\nasked',
#   'disciples',
#   'arms,',
#   'disciples',
#   'arms,\r\nput',
#   'hands',
#   'disciples',
#   'words.',
#   'life',
#   'disciples',
#   'words.',
#   'teaching,\r\nBeware',
#   'disciples\r\nto',
#   'disciples',
#   'angels,',
#   'elect',
#   'coming',
#   'disciples',
#   'disciples',
#   'disciples.',
#   'disciples,\r\nSit',
#   'peace',
#   'face,',
#   'head.',
#   'own\r\nclothes',
#   'cross.',
#   'garments,',
#   'right',
#   'left.',
#   'last',
#   'disciples'],
#  'paths': ['straight.'],
#  'straight.': ['John\r\ndid'],
#  'John\r\ndid': ['baptize'],
#  'baptize': ['in'],
#  'wilderness,': ['and'],
#  'and': ['preach',
#   'from',
#   'wore',
#   'he',
#   'wild',
#   'unloose.',
#   'was',
#   'the\r\nSpirit,',
#   'Jesus',
#   'Andrew,',
#   'I',
#   'followed',
#   'John,',
#   'went',
#   'not',
#   'said,',
#   'come',
#   'cried',
#   'they',
#   'presently\r\nthey',
#   'took',
#   'some',
#   'did',
#   'those',
#   'cast',
#   'beseeching',
#   'said,',
#   'the',
#   'offer',
#   'began',
#   'His',
#   'said,)',
#   'go',
#   'went',
#   'the',
#   'said',
#   'sinners',
#   'His\r\ndisciples.',
#   'sinners,',
#   'drinks',
#   'of',
#   'asked,\r\nWhy',
#   'the',
#   'then',
#   'the',
#   'the',
#   'His',
#   'they',
#   'were',
#   'ate',
#   'was',
#   'immediately',
#   'from',
#   'those',
#   'many',
#   'cried,',
#   'that',
#   'to',
#   'Judas',
#   'said,',
#   'be',
#   'is\r\nfinished.',
#   'spoil',
#   'His',
#   'seek',
#   'said,',
#   'my',
#   'my',
#   'mother.',
#   'began',
#   'withered',
#   'choked',
#   'it\r\nyielded',
#   'increased;',
#   'brought',
#   'some',
#   'why',
#   'not',
#   'hearing',
#   'their\r\nsins',
#   'takes',
#   'endure',
#   'the',
#   'it',
#   'bring',
#   'days,',
#   'the',
#   'becomes',
#   'waves',
#   'it\r\nwas',
#   'said,',
#   'said',
#   'there',
#   'no',
#   'chains,',
#   'broke\r\nthe',
#   'night',
#   'day',
#   'cutting',
#   'worshipped',
#   'entered',
#   'drowned',
#   'told',
#   'in',
#   'had',
#   'in',
#   'also',
#   'tell',
#   'began',
#   'lay',
#   'the',
#   'thronged\r\nHim.',
#   'nothing\r\nwas',
#   'touched',
#   'she',
#   'said,',
#   'ask',
#   'fell',
#   'spoke',
#   'be',
#   'announced,',
#   'John,',
#   'many',
#   'wailing.',
#   'weep?\r\nThe',
#   'mother',
#   'those',
#   'entered',
#   'said,',
#   'walked.\r\nThey',
#   'Jesus',
#   'were',
#   'the',
#   'Simon?',
#   'in',
#   'heal\r\na',
#   'teach',
#   'two.',
#   'not',
#   'Gomorrha',
#   'preached',
#   'said',
#   'laid',
#   'knew',
#   'holy',
#   'heard',
#   'heard',
#   'chief',
#   'those',
#   'I',
#   'said,',
#   'said,',
#   'for',
#   'commanded',
#   'beheaded',
#   'gave',
#   'took',
#   'laid',
#   'told',
#   'what',
#   'rest',
#   'going',
#   'had',
#   'came',
#   'was',
#   'said,',
#   'it',
#   'into',
#   'give',
#   'see.',
#   'two',
#   'by',
#   'the',
#   'blessed',
#   'gave',
#   'were',
#   'fish.',
#   'He\r\ndeparted',
#   'saw',
#   'would',
#   'were',
#   'said,',
#   'they',
#   'did',
#   'came',
#   'got',
#   'besought',
#   'some',
#   'all',
#   'pots,',
#   'of',
#   'scribes',
#   'cups',
#   'many\r\nother',
#   'thy',
#   'make',
#   'said,',
#   'goes',
#   'defile',
#   'went',
#   'Sidon.',
#   'would',
#   'came',
#   'fell',
#   'she',
#   'cast',
#   'the',
#   'Sidon,',
#   'had',
#   'put',
#   'said,',
#   'he\r\nspoke',
#   'the',
#   'said,',
#   'they\r\nhave',
#   'gave',
#   'gave',
#   'told',
#   'were',
#   'filled',
#   'came',
#   'began',
#   'testing',
#   'the',
#   'said,',
#   'how',
#   'how\r\nmany',
#   'told',
#   'besought\r\nHim',
#   'led',
#   'put',
#   'saw\r\nevery',
#   'His',
#   'others\r\nsay',
#   'scribes;',
#   'that',
#   'began',
#   'rebuked',
#   'take',
#   'follow',
#   'the',
#   'lose',
#   'of',
#   'sinful',
#   'John',
#   'there',
#   'Moses.',
#   'a',
#   'restores',
#   'be',
#   'they',
#   'wastes',
#   'they',
#   'cried,',
#   'into',
#   'help',
#   'said,',
#   'deaf\r\nspirit,',
#   'then',
#   'he',
#   'fasting.',
#   'passed',
#   'said,',
#   'said',
#   'servant',
#   'set\r\nhim',
#   'he\r\nwere',
#   'go',
#   'the',
#   'every',
#   'have',
#   'He',
#   'female.',
#   'cleave',
#   'marry',
#   'be\r\nmarried',
#   'said',
#   'blessed',
#   'said',
#   'sell',
#   'give',
#   'follow',
#   'went\r\naway',
#   'said,',
#   'said',
#   'have',
#   "the\r\ngospel's,",
#   'in',
#   'the',
#   'scribes.',
#   'shall',
#   'scourge',
#   'John,',
#   'said,',
#   'on',
#   'John.',
#   'said,',
#   'their',
#   'to',
#   'said,',
#   'went',
#   'followed',
#   'Bethany.',
#   'said,',
#   'bring',
#   'found',
#   'Jesus',
#   'strewed',
#   'went',
#   'upon',
#   'Jesus',
#   'bought',
#   'the',
#   'chief',
#   'considered',
#   'be\r\nthou',
#   'shall',
#   'the',
#   'said',
#   'went',
#   'beat',
#   'wounded',
#   'sent',
#   'they',
#   'killing',
#   'the\r\ninheritance',
#   'cast',
#   'destroy',
#   'let',
#   'it',
#   'elders',
#   'Herodians\r\nto',
#   'regard',
#   'to',
#   'leaves',
#   'leaves',
#   'this',
#   'left',
#   'that',
#   'said,',
#   'the',
#   'the',
#   'having',
#   'with',
#   'there',
#   'with',
#   'with',
#   'with\r\nall',
#   'to',
#   'sacrifices.',
#   'love\r\nsalutations',
#   'the',
#   'watched',
#   'put',
#   'said,',
#   'what',
#   'not',
#   'Andrew',
#   'asked,',
#   'said,',
#   'shall\r\ndeceive',
#   'rumors',
#   'kingdom',
#   'famines',
#   'crises.',
#   'deliver',
#   'children',
#   'the',
#   'in',
#   'from',
#   'false',
#   'wonders',
#   'the',
#   'pray.',
#   'gave',
#   'of',
#   'the',
#   'put',
#   'anointed',
#   'said,',
#   'the',
#   'prepared.',
#   'found',
#   'ate,',
#   'blessed',
#   'gave',
#   'eat.',
#   'the',
#   'I',
#   'James',
#   'John',
#   'heavy',
#   'watch.',
#   'fell',
#   'found',
#   'pray\r\nso',
#   'prayed',
#   'staves,',
#   'elders.',
#   'lead',
#   'took',
#   'cut',
#   'staves',
#   'ye\r\ndid',
#   'fled.',
#   'laid',
#   'fled',
#   'the\r\nelders',
#   'the',
#   'sat',
#   'all',
#   'within',
#   'said',
#   'ye',
#   'coming',
#   'to',
#   'to',
#   'said,',
#   'said,',
#   'the',
#   'began',
#   'swear',
#   'said,',
#   'scribes',
#   'the',
#   'carried',
#   'delivered',
#   'Pilate',
#   'who',
#   'they',
#   'put',
#   'put',
#   'led',
#   'the',
#   'Rufus,',
#   'hung',
#   'builds',
#   'come\r\ndown',
#   'filled',
#   'Mary',
#   'Joses,',
#   'Salome\r\n\r\n(who',
#   'ministered',
#   'many',
#   'wrapped',
#   'rolled',
#   'Mary',
#   'Peter',
#   'fled',
#   'were\r\namazed.',
#   'told',
#   'had',
#   'told',
#   'hardness',
#   'preach',
#   'is',
#   'they',
#   'sat',
#   'confirming'],
#  'preach': ['the', 'there', 'the'],
#  'baptism': ['of', 'that', 'with', 'of\r\nJohn'],
#  'repentance\r\nfor': ['the'],
#  'remission': ['of'],
#  'sins.': ['After'],
#  'After': ['confessing',
#   'they',
#   'some',
#   'this,',
#   'Jesus',
#   'they',
#   'He',
#   'Jesus',
#   'they',
#   'that',
#   'six',
#   'Jesus',
#   'He',
#   'this',
#   'they',
#   'they'],
#  'confessing': ['their'],
#  'their': ['sins',
#   'nets',
#   'nets.',
#   'father,',
#   'hearts.',
#   'coasts.',
#   'unbelief\r\nand,',
#   'journey',
#   'purse.',
#   'hearts',
#   'hands,',
#   'lips',
#   'heart',
#   'own',
#   'way,',
#   'misunderstanding,',
#   'great',
#   'garments',
#   'garments',
#   'hypocrisy,',
#   'abundance;',
#   'parents\r\nand',
#   'eyes',
#   'hands',
#   'witness',
#   'hands.',
#   'desire',
#   'knees,',
#   'unbelief'],
#  'sins': ['many', 'are', 'but', 'are', 'shall'],
#  'many': ['from',
#   'people',
#   'that',
#   'devils',
#   'gathered,',
#   'who',
#   'and',
#   'who\r\nhad',
#   'things',
#   'people\r\ngathered',
#   'physicians,',
#   'weeping',
#   'devils,',
#   'sick',
#   'of',
#   'times',
#   'loaves',
#   'as',
#   'loaves',
#   'baskets',
#   'things;',
#   'said,',
#   'possessions.',
#   'others;\r\nbeating',
#   'things,',
#   'other'],
#  'from': ['the\r\nland',
#   'Jerusalem',
#   'Nazareth',
#   'every',
#   'them,',
#   'the',
#   'Galilee,',
#   'beyond',
#   'afar,',
#   'the',
#   'that',
#   'your\r\nfeet',
#   'the',
#   'the',
#   'Jerusalem',
#   'outside',
#   'without',
#   'inside,',
#   'within',
#   'her',
#   'thy\r\ndaughter.',
#   'the\r\nmultitude',
#   'afar.',
#   'the',
#   'the',
#   'the',
#   'my\r\nyouth.',
#   'Bethany,\r\nJesus',
#   'heaven',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the\r\nuttermost',
#   'me.',
#   'them',
#   'the',
#   'the',
#   'the',
#   'afar;',
#   'the',
#   'the',
#   'the'],
#  'the\r\nland': ['of'],
#  'Judaea': ['and', 'by', 'flee'],
#  'Jerusalem': ['were', 'observed', 'and,', 'the', 'and', 'and'],
#  'were': ['baptized',
#   'fishermen.',
#   'astonished',
#   'amazed,',
#   'brought',
#   'possessed',
#   'sick',
#   'with',
#   'certain',
#   'many',
#   'with',
#   'hungry?',
#   'alone',
#   'alone.',
#   'also',
#   'about',
#   'with',
#   'astonished',
#   'astonished.',
#   'offended',
#   'pleased.',
#   'as',
#   'filled.',
#   'troubled.',
#   'amazed',
#   'sick.',
#   'opened.',
#   'filled.',
#   'afraid.',
#   'scribes',
#   'greatly',
#   'afraid',
#   'silent',
#   'hung',
#   'astonished',
#   'astonished',
#   'seven',
#   'rich',
#   'glad',
#   'it',
#   'possible,',
#   'armed',
#   'assembled',
#   'crucified',
#   'also',
#   'frightened.',
#   'afraid.'],
#  'baptized': ['by', 'you', 'by', 'with?', 'with', 'shall'],
#  'him': ['in',
#   'and',
#   'followed.',
#   'to',
#   'on',
#   'hear.',
#   'hear.',
#   'shall',
#   'and',
#   'stay',
#   'not',
#   'and',
#   'bound\r\nand',
#   'to\r\nhave',
#   'killed.',
#   'were',
#   'all\r\nthings,',
#   'die.',
#   'to',
#   'because',
#   'look',
#   'away',
#   'deny',
#   'exactly',
#   'he',
#   'out.',
#   'into',
#   'no',
#   'by',
#   'up',
#   'out?',
#   'because',
#   'not.',
#   'that',
#   'and',
#   'to',
#   'and',
#   'here.',
#   'what',
#   'away\r\nempty.',
#   'and',
#   'away.\r\nThe',
#   'as',
#   'and',
#   'in',
#   'who',
#   'that\r\nis',
#   'that',
#   'money.',
#   'and',
#   'again,',
#   'and',
#   'to'],
#  'river': ['of\r\nJordan.', 'of'],
#  'of\r\nJordan.': ['John'],
#  'John': ['was',
#   'in',
#   'saw',
#   'was',
#   'and',
#   'and',
#   'told',
#   'and',
#   'many',
#   'the',
#   'in',
#   'the',
#   'up',
#   'said,',
#   'a',
#   'with\r\nHim.'],
#  'was': ['clothed',
#   'baptized',
#   'put',
#   'a',
#   'moved\r\nwith',
#   'no',
#   'carried',
#   'only\r\nlawful',
#   'made',
#   'a',
#   'grieved',
#   'restored',
#   'again',
#   'no',
#   'sown',
#   'in',
#   'in',
#   'a',
#   'immediately\r\nmet',
#   'a',
#   'done.',
#   'possessed',
#   'a',
#   'dried',
#   'healed.',
#   'done',
#   'lying.\r\nThen',
#   'twelve',
#   'spread',
#   'risen',
#   'not',
#   'a\r\njust',
#   'exceedingly',
#   'moved',
#   'far',
#   'in',
#   'alone',
#   'a',
#   'a',
#   'deaf',
#   'loosed',
#   'about',
#   'restored',
#   'transfigured',
#   'not',
#   'written.',
#   'met',
#   'greatly\r\ndispleased',
#   'sad',
#   'going',
#   'hungry.',
#   'not',
#   'walking',
#   "the\r\nLord's",
#   'not',
#   'in',
#   'in',
#   'with',
#   'outside,',
#   'with',
#   'one',
#   'the',
#   'written',
#   'fulfilled:',
#   'darkness',
#   'rent',
#   'the',
#   'Mary\r\n\r\nMagdalene,',
#   'in',
#   'the',
#   'already',
#   'past,',
#   'rolled',
#   'crucified.',
#   'alive',
#   'risen.',
#   'received'],
#  'clothed': ['with', 'Him', 'in'],
#  'with': ["camel's",
#   'water',
#   'the',
#   'authority',
#   'an',
#   'thee,',
#   'a',
#   'authority',
#   'a',
#   'devils.',
#   'him',
#   'palsy',
#   'Jesus',
#   'publicans',
#   'publicans',
#   'them?',
#   'them,',
#   'him,',
#   'him?',
#   'anger',
#   'the',
#   'His\r\ndisciples',
#   'Him,',
#   'Jesus,',
#   'gladness.',
#   'fetters',
#   'a',
#   'thee,',
#   'the',
#   'Him.',
#   'him',
#   'Him',
#   'only',
#   'oil,\r\nand',
#   'him',
#   'him,',
#   'great',
#   'them',
#   'unwashed',
#   'unwashed\r\nhands?',
#   'their',
#   'me',
#   'bread',
#   'His',
#   'them.',
#   'His',
#   'the',
#   'Jesus.',
#   'you?',
#   'tears',
#   'one\r\neye',
#   'fire,',
#   'what\r\nwill',
#   'God.',
#   'the',
#   'the',
#   'which',
#   'James',
#   'His\r\ndisciples,',
#   'the',
#   'all',
#   'all',
#   'all',
#   'all',
#   'all',
#   'all',
#   'child.',
#   'great',
#   'the',
#   'you',
#   'His',
#   'me',
#   'me?',
#   'the',
#   'a',
#   'swords',
#   'swords',
#   'you',
#   'the',
#   'hands,',
#   'the',
#   'Jesus',
#   'the',
#   'those\r\ninvolved',
#   'him',
#   'purple,',
#   'a',
#   'myrrh',
#   'Him',
#   'the',
#   'the',
#   'Him',
#   'a',
#   'a',
#   'Him',
#   'Him',
#   'new',
#   'them',
#   'these'],
#  "camel's": ['hair'],
#  'hair': ['and'],
#  'wore': ['animal'],
#  'animal': ['hides'],
#  'hides': ['around'],
#  'around': ['his\r\nloins',
#   'Galilee.',
#   'sunset,',
#   'Him,\r\nand',
#   'Tyre',
#   'Him',
#   'on',
#   'the',
#   'the',
#   'his',
#   'it.',
#   'His'],
#  'his\r\nloins': ['and'],
#  'he': ['ate',
#   'went',
#   'arose',
#   'went',
#   'cannot',
#   'first',
#   'can',
#   'that',
#   'that',
#   'has.',
#   'knows',
#   'puts',
#   'had',
#   'plucked',
#   'was\r\nin',
#   'saw',
#   'ran',
#   'besought',
#   'not',
#   'saw',
#   'fell',
#   'said,',
#   'was',
#   'would\r\ngive',
#   'would',
#   'shall',
#   'saw',
#   'was',
#   'shall',
#   'takes',
#   'tears',
#   'arose.',
#   'does',
#   'had',
#   'began',
#   'cried',
#   'rose',
#   'received',
#   'will',
#   'let',
#   'says',
#   'shall\r\nhave',
#   'says.',
#   'sent',
#   'loved',
#   'that',
#   'might\r\nconveniently',
#   'shall',
#   'left',
#   'denied',
#   'wept.',
#   'released',
#   'had',
#   'delivered',
#   'said,',
#   'released'],
#  'ate': ['locusts', 'the', 'and', 'of', 'bread'],
#  'locusts': ['and'],
#  'wild': ['honey.', 'beasts,'],
#  'honey.': ['He'],
#  'He': ['preached,',
#   'shall\r\nbaptize',
#   'began',
#   'walked',
#   'saw',
#   'had',
#   'saw',
#   'entered',
#   'taught\r\nthem',
#   'cried',
#   'even\r\ncommands',
#   'came',
#   'cast',
#   'went',
#   'put',
#   'had',
#   'said',
#   'returned',
#   'said',
#   'said',
#   'taught',
#   'saw',
#   'eats',
#   'said',
#   'went',
#   'said',
#   'did.',
#   'needed',
#   'had',
#   'called',
#   'would',
#   'ordained',
#   'took',
#   'has',
#   'said',
#   'has',
#   'looked',
#   'entered',
#   'taught',
#   'that\r\nhas',
#   'told',
#   'said',
#   'that',
#   'passes',
#   'said,',
#   'explained\r\nall',
#   'was',
#   'was',
#   'returned',
#   'has',
#   'said',
#   'yet',
#   'said',
#   'had',
#   'took',
#   'said',
#   'went,',
#   'began',
#   'marvelled',
#   'gave',
#   'told',
#   'instructed',
#   'said',
#   'is',
#   'had',
#   'swore',
#   'brought',
#   'had',
#   'looked',
#   'broke',
#   'divided',
#   'instructed',
#   'sent',
#   'looked',
#   'came\r\nto',
#   'went',
#   'made',
#   'said',
#   'called',
#   'went',
#   'arose',
#   'could',
#   'came',
#   'sighed',
#   'charged',
#   'has\r\ndone',
#   'makes',
#   'took',
#   'broke',
#   'immediately',
#   'left',
#   'said',
#   'took',
#   'had',
#   'asked',
#   'began',
#   'must',
#   'must',
#   'called',
#   'comes',
#   'was',
#   'approached',
#   'saw',
#   'saw',
#   'foams',
#   'is',
#   'said',
#   'is',
#   'shall',
#   'took',
#   'took',
#   'said',
#   'that',
#   'was',
#   'taught',
#   'should',
#   'said,',
#   'shall',
#   'said',
#   'beckoned',
#   'that',
#   'had',
#   'went',
#   'spotted',
#   'got',
#   'found',
#   'cast',
#   'overthrew',
#   'would',
#   'went',
#   'was',
#   'will',
#   'began',
#   'set',
#   'dug',
#   'reasoned,',
#   'had',
#   'is',
#   'said',
#   'taught',
#   'said',
#   'went',
#   'has\r\nchosen,',
#   'has',
#   'shall',
#   'is\r\nthere;',
#   'find',
#   'sat',
#   'sent',
#   'shall',
#   'broke',
#   'said,',
#   'took',
#   'had',
#   'gave',
#   'said',
#   'took',
#   'said',
#   'prayed',
#   'said,',
#   'came',
#   'returned,',
#   'found',
#   'returned',
#   'yet',
#   'that',
#   'went',
#   'answered,',
#   'answered\r\nnothing.',
#   'done?',
#   'received',
#   'was\r\nnumbered',
#   'saved',
#   'cannot',
#   'calls',
#   'was',
#   'was',
#   'called',
#   'had',
#   'laid',
#   'is',
#   'goes',
#   'told',
#   'had',
#   'was',
#   'appeared,',
#   'appeared',
#   'was',
#   'said',
#   'that',
#   'was'],
#  'preached,': ['saying,'],
#  'saying,': ['There\r\ncomes',
#   'Thou',
#   'What',
#   'We',
#   'He',
#   'Come',
#   'My',
#   'He',
#   'Neither',
#   'Get',
#   'I',
#   'Whomsoever'],
#  'There\r\ncomes': ['one'],
#  'mightier': ['than'],
#  'than': ['I,', 'all', 'all.', 'for\r\nthat', 'to', 'to', 'all'],
#  'I,': ['the'],
#  'latchet': ['of'],
#  'whose': ['shoes', 'young', 'wife\r\nshall'],
#  'shoes': ['I'],
#  'am': ['not', 'well', 'baptized', 'baptized.', 'the', 'Christ;', 'risen'],
#  'not': ['worthy\r\nto',
#   'as',
#   'allow',
#   'so',
#   'get',
#   'to\r\ncall',
#   'lawful',
#   'man',
#   'make',
#   'eat',
#   'perceive;',
#   'this',
#   'be',
#   'be',
#   'how.',
#   'that',
#   'send\r\nthem',
#   'but\r\nsaid,',
#   'afraid,',
#   'dead,',
#   'the',
#   'right',
#   'put',
#   'receive\r\nyou,',
#   'lawful',
#   'reject',
#   'afraid.',
#   'eat',
#   'walk\r\naccording',
#   'into',
#   'fit\r\nto',
#   'or',
#   'remember',
#   'remember',
#   'know',
#   'so',
#   'cast',
#   'understand',
#   'me,',
#   'follow',
#   'follow',
#   'against\r\nus',
#   'lose',
#   'die',
#   'die\r\nand',
#   'for',
#   'receive',
#   'enter',
#   'commit',
#   'kill,',
#   'bear',
#   'with',
#   'mine',
#   'be',
#   'to',
#   'yet',
#   'doubt',
#   'forgive,',
#   'believe\r\nhim?',
#   'read',
#   'the',
#   'give?',
#   'the',
#   'read',
#   'the',
#   'far',
#   'be',
#   'one',
#   'be',
#   'be',
#   'be',
#   'ye',
#   '(let',
#   'go',
#   'turn',
#   'in',
#   'seen',
#   'give',
#   'believe',
#   'pass',
#   'pass',
#   'the',
#   'always.',
#   'what',
#   'watch',
#   'give',
#   'know',
#   'take',
#   'agree.',
#   'agree',
#   'know',
#   'know',
#   'afraid.',
#   'here.',
#   'believe',
#   'believe',
#   'believe',
#   'hurt'],
#  'worthy\r\nto': ['stoop'],
#  'stoop': ['down'],
#  'down': ['and',
#   'and',
#   'the',
#   'before',
#   'from\r\nJerusalem',
#   'a\r\nsteep',
#   'before\r\nHim',
#   'in',
#   'in',
#   'on',
#   'into'],
#  'unloose.': ['I'],
#  'have': ['baptized',
#   'we',
#   'the\r\nbridegroom',
#   'forgiveness,',
#   'heard,',
#   'no\r\nroot',
#   'no',
#   'I',
#   'nothing',
#   'ye?',
#   'passed',
#   'no',
#   'compassion\r\non',
#   'been',
#   'ye?',
#   'no',
#   'no',
#   'seen',
#   'done',
#   'brought',
#   'compassion',
#   'two',
#   'two',
#   'two',
#   'peace',
#   'observed',
#   'treasure',
#   'riches',
#   'left',
#   'followed',
#   'mercy',
#   'mercy',
#   'made',
#   'them.',
#   'ye',
#   'warned',
#   'been',
#   'the',
#   'not',
#   'heard'],
#  'you': ['with',
#   'with',
#   'fishers',
#   'it',
#   'that',
#   'hypocrites.',
#   'say\r\nthat',
#   'about.',
#   'your',
#   'a',
#   'answer',
#   'by',
#   'by',
#   'up',
#   'away',
#   'up,',
#   'of',
#   'sleeping.',
#   'always,',
#   'shall',
#   'a',
#   'who',
#   'into\r\nGalilee.',
#   'in',
#   'sleep?',
#   'not',
#   'do',
#   'daily,',
#   'say.',
#   'behold',
#   'the',
#   'want',
#   'into\r\nGalilee.'],
#  'water': ['but', 'to', 'in'],
#  'but': ['He',
#   'had',
#   'God',
#   'to',
#   'thy',
#   'is',
#   'touch',
#   'knowing',
#   'sleeps.',
#   'lay',
#   'the',
#   'eat',
#   'their',
#   'the',
#   'into',
#   'some',
#   'the',
#   'were',
#   'Him\r\nthat',
#   'one',
#   'His\r\ndisciples',
#   'one,',
#   'not',
#   'to\r\nminister',
#   'he',
#   'leaves\r\nfor',
#   'ye',
#   'shall\r\nbelieve',
#   'they\r\nfeared',
#   'teach',
#   'the',
#   'Him.',
#   'she\r\ncast',
#   'the',
#   'my',
#   'the',
#   'me',
#   'what',
#   'they',
#   'their',
#   'He',
#   'He',
#   'they'],
#  'shall\r\nbaptize': ['you'],
#  'Holy': ['Ghost.', 'One', 'Ghost', 'Ghost.'],
#  'Ghost.': ['And', 'In'],
#  'And': ['it',
#   'there',
#   'Jesus',
#   'they',
#   'in',
#   'she,',
#   'all',
#   'Jesus',
#   'Jesus',
#   'they',
#   'he',
#   'it',
#   'when',
#   'Jesus',
#   'it',
#   'Jesus',
#   'how',
#   'Jesus',
#   'the',
#   'if\r\nSatan',
#   'Jesus',
#   'Jesus',
#   'these',
#   'these',
#   'these',
#   'He',
#   'to',
#   'He',
#   'when',
#   'he',
#   'He',
#   'Jesus',
#   'whosoever',
#   'others',
#   'when',
#   'they',
#   'He',
#   'immediately',
#   'He',
#   'wheresoever',
#   'as',
#   'He',
#   'having\r\nears,',
#   'do',
#   'there',
#   'it',
#   'He',
#   'one',
#   'whosoever',
#   'if',
#   'if',
#   'if',
#   'they',
#   'when',
#   'woe',
#   'pray',
#   'they',
#   'He',
#   'some',
#   'he',
#   'Peter',
#   'there',
#   'they',
#   'so',
#   'He',
#   'these',
#   'they'],
#  'came': ['to',
#   'from',
#   'a',
#   'into\r\nGalilee.',
#   'out',
#   'and',
#   'I\r\nforth.',
#   'to',
#   'to',
#   'to',
#   'to',
#   'not',
#   'to',
#   'to',
#   'to',
#   'to',
#   'again',
#   'down',
#   'and,',
#   'to',
#   'and\r\ndevoured',
#   'out',
#   'one',
#   'up',
#   'and',
#   'from',
#   'and',
#   'together',
#   'back',
#   'into',
#   'and',
#   'to',
#   'from',
#   'into',
#   'out',
#   'upon',
#   'out',
#   'to',
#   'to',
#   'not',
#   'to',
#   'near',
#   'into',
#   'to',
#   'to',
#   'the',
#   'to',
#   'with\r\nthe',
#   'to',
#   'back',
#   'up'],
#  'to': ['pass',
#   'do',
#   'destroy',
#   'the',
#   'them.',
#   'Him',
#   'a',
#   'them,',
#   'Him',
#   'say',
#   'any',
#   'the',
#   'them.',
#   'broadcast',
#   'stay',
#   'Him',
#   'the',
#   'them.',
#   'Him',
#   'the',
#   'them,',
#   'say',
#   'the\r\nsick',
#   'forgive\r\nsins,',
#   'the',
#   'thee,',
#   'thine',
#   'the',
#   'him,',
#   'pass,',
#   'them,',
#   'call',
#   'repentance.',
#   'Jesus',
#   'them,',
#   'pass,',
#   'pluck',
#   'Him,',
#   'eat?',
#   'those',
#   'them,',
#   'see',
#   'the',
#   'them,',
#   'do',
#   'the',
#   'the',
#   'Him',
#   'get',
#   'touch',
#   'whom',
#   'Him.',
#   'be',
#   'preach,',
#   'heal',
#   'cast',
#   'Him',
#   'you,',
#   'the',
#   'address',
#   'pass,',
#   'hear,',
#   'know',
#   'those',
#   'them,',
#   'be',
#   'them,',
#   'you.',
#   'you',
#   'him',
#   'it\r\nbecause',
#   'His',
#   'the',
#   'them,',
#   'another,',
#   'do',
#   'the',
#   'those',
#   'see',
#   'the',
#   'let',
#   'thy',
#   'tell',
#   'the',
#   'Him.',
#   'many',
#   'her,',
#   'the',
#   'the',
#   'them,',
#   'scorn.',
#   'eat.',
#   'teach',
#   'Him',
#   'do',
#   'Him',
#   'begin',
#   'go',
#   'be\r\nshod',
#   'them,',
#   'you,',
#   'the',
#   'her',
#   'half',
#   'her',
#   'the',
#   'be',
#   'the',
#   'her\r\nmother.',
#   'Jesus,',
#   'eat.',
#   'Him.',
#   'teach',
#   'Him',
#   'buy\r\nthemselves',
#   'eat.',
#   'eat.',
#   'them',
#   'eat?',
#   'make',
#   'His\r\ndisciples',
#   'set',
#   'get',
#   'the',
#   'Bethsaida',
#   'pray.',
#   'them.',
#   'them',
#   'all',
#   'allow',
#   'touch',
#   'the',
#   'them,',
#   'keep',
#   'his',
#   'do',
#   'Him',
#   'me',
#   'hear,',
#   'her,',
#   'the',
#   'her,',
#   'the',
#   'put',
#   'tell',
#   'hear,',
#   'Him',
#   'eat.',
#   'their',
#   'sit',
#   'His\r\ndisciples.',
#   'set\r\nthem',
#   'question',
#   'you,\r\nThere',
#   'this',
#   'the',
#   'bring',
#   'them,',
#   'Jesus,',
#   'touch',
#   'his',
#   'any',
#   'them,',
#   'teach',
#   'His',
#   'rebuke',
#   'Him',
#   'you,',
#   'be\r\nhere.',
#   'say',
#   'tell',
#   'you,',
#   'him',
#   'salute',
#   'thy',
#   'destroy',
#   'the',
#   'them,\r\nThis',
#   'ask',
#   'them,',
#   'be',
#   'drink',
#   'Christ,',
#   'enter\r\ninto',
#   'have',
#   'enter',
#   'have',
#   'be',
#   'enter',
#   'have',
#   'be',
#   'hear\r\nHim',
#   'Him,',
#   'put',
#   'put\r\nher',
#   'his',
#   'another',
#   'the',
#   'me.',
#   'you,',
#   'Jesus,',
#   'inherit',
#   'him,',
#   'the\r\npoor.',
#   'His',
#   'enter',
#   'them,',
#   'enter',
#   'go',
#   'enter',
#   'Jerusalem',
#   'tell',
#   'Him.',
#   'the',
#   'death,',
#   'the',
#   'Him',
#   'tell',
#   'them,',
#   'Him,\r\nWe',
#   'sit',
#   'give.',
#   'them',
#   'rule',
#   'be',
#   'give',
#   'Jericho.',
#   'cry',
#   'be',
#   'Him',
#   'Jesus.',
#   'the\r\nman,',
#   'him,',
#   'Bethphage',
#   'two',
#   'the',
#   'them,',
#   'him',
#   'the',
#   'the',
#   'eat.',
#   'it,',
#   'it,',
#   'Jerusalem',
#   'carry',
#   'Jesus,',
#   'this',
#   'pass;',
#   'Him',
#   'do',
#   'Jesus,\r\nWe',
#   'speak',
#   'them',
#   'husbandmen',
#   'the',
#   'lay',
#   'catch',
#   'give',
#   'Caesar,',
#   'Caesar',
#   'God',
#   'us,',
#   'his',
#   'him',
#   'love',
#   'him,',
#   'my',
#   'them',
#   'go',
#   'live',
#   'Him',
#   'councils.',
#   'say',
#   'be',
#   'death.',
#   'the',
#   'the',
#   'take',
#   'get',
#   'those',
#   'the',
#   'you,',
#   'seduce,',
#   'pass,',
#   'his',
#   'watch.',
#   'you,\r\nI',
#   'all,',
#   'death.',
#   'Him',
#   'the',
#   'anoint',
#   'the',
#   'betray',
#   'them.',
#   'hear',
#   'give',
#   'Jesus,',
#   'prepare',
#   'the',
#   'know',
#   'be',
#   'that\r\nman',
#   'them.',
#   'them,',
#   'a',
#   'His',
#   'pray.',
#   'them,',
#   'thee;',
#   'Peter,',
#   'temptation.',
#   'say',
#   'Him.',
#   'them,',
#   'Him\r\nand',
#   'them,',
#   'take',
#   'the',
#   'the',
#   'death;',
#   'Jesus,',
#   'be',
#   'spit',
#   'cover',
#   'buffet',
#   'say',
#   'Him,',
#   'say\r\nto',
#   'Peter,',
#   'mind',
#   'him:',
#   'Pilate.',
#   'Him,',
#   'them',
#   'cry',
#   'the',
#   'you',
#   'them.',
#   'do',
#   'Him',
#   'them,\r\nWhy,',
#   'content',
#   'them.',
#   'be',
#   'be',
#   'bear',
#   'the',
#   'drink',
#   'drink.',
#   'take',
# ...
#   'your',
#   'the',
#   'Galilee',
#   'the',
#   'Jericho',
#   'the',
#   'all\r\nseven'],
#  'corn': ['fields', 'as'],
#  'fields': ['on'],
#  'the\r\nsabbath': ['day;', 'also.', 'day'],
#  'day;': ['and'],
#  'pluck': ['the', 'it\r\nout.'],
#  'ears': ['of', 'to', 'to\r\nhear,', 'to', 'were'],
#  'they\r\nwent': ['along.'],
#  'along.': ['The'],
#  'Him,': ['Behold,',
#   'fell',
#   'and',
#   'Five,',
#   'He',
#   'Why',
#   'How',
#   'seeking',
#   'Jesus',
#   'all',
#   'and,',
#   'asked,',
#   'Is',
#   'and',
#   'but',
#   'Art',
#   'and',
#   'Prophesy;\r\nand',
#   'Art',
#   'Answer',
#   'Hail,\r\nKing',
#   'they',
#   'and',
#   'they',
#   'just'],
#  'why': ['do', 'He', 'ye', 'has'],
#  'that\r\nwhich': ['is'],
#  'lawful': ['on', 'for', 'for', 'to'],
#  'day?': ['And'],
#  'responded,': ['Have'],
#  'Have': ['ye\r\nnever', 'salt', 'faith', 'ye', 'ye'],
#  'ye\r\nnever': ['read'],
#  'read': ['what', 'this', 'in'],
#  'what': ['David,',
#   'ye',
#   'measure',
#   'was',
#   'was',
#   'place',
#   'they',
#   'they',
#   'defiles',
#   'shall',
#   'shall',
#   'else',
#   'the',
#   'the\r\nscribes',
#   'was',
#   'shall',
#   'Jesus',
#   'authority',
#   'authority',
#   'she',
#   'buildings',
#   'ye',
#   'she',
#   'I',
#   'thou\r\nwilt.',
#   'to',
#   'you',
#   'evil'],
#  'David,': ['and', 'have', 'that\r\ncomes'],
#  'had\r\nneed': ['and'],
#  'hungry?': ['How'],
#  'of\r\nAbiathar,': ['the'],
#  'high': ['priest,',
#   'God?',
#   'priest,',
#   'priest.',
#   'priest',
#   'priest',
#   'priest',
#   'priest',
#   'priest'],
#  'priest,': ['and', 'and'],
#  'showbread?': ['How'],
#  'only\r\nlawful': ['for'],
#  'priests': ['to',
#   'and',
#   'heard',
#   'and',
#   'and',
#   'to\r\narrange',
#   'and',
#   'and',
#   'held',
#   'accused',
#   'told\r\nthe',
#   'along'],
#  'eat?': ['And', 'He\r\nasked'],
#  'how': ['David',
#   'they',
#   'it',
#   'many',
#   'can',
#   'they',
#   'God',
#   'is',
#   'the',
#   'they',
#   'he',
#   'long'],
#  'David': ['also', 'himself', 'calls\r\nhim'],
#  'gave': ['it',
#   'them',
#   'them',
#   'it',
#   'it',
#   'them',
#   'thanks.',
#   'them',
#   'thee',
#   'out',
#   'authority',
#   'it\r\nto',
#   'it',
#   'it\r\nto'],
#  'who\r\nwere': ['with'],
#  'him?': ['Then'],
#  'man,\r\nand': ['not'],
#  'sabbath;': ['therefore,'],
#  'therefore,': ['the', 'mighty', 'held', 'shall', 'God', 'do'],
#  'Lord': ['of',
#   'has\r\ndone',
#   'has',
#   'our',
#   'thy',
#   'said',
#   'shortened',
#   'had',
#   'working'],
#  'also.': ['3', 'In'],
#  '3': [''],
#  'synagogue': ['again.'],
#  'again.': ['Inside', 'Jesus', 'The', 'James', 'The', 'Then,'],
#  'Inside': ['was', 'the'],
#  'with\r\na': ['withered'],
#  'withered': ['hand.', 'hand,', 'away.', 'away.'],
#  'watched': ['to', 'how', 'where'],
#  'see': ['if',
#   'what',
#   'ye',
#   'men',
#   'these',
#   'the',
#   'these',
#   'the\r\nSon',
#   'and\r\nbelieve.',
#   'whether',
#   'Him,'],
#  'if': ['Jesus',
#   'there',
#   'he',
#   'he',
#   'it',
#   'thou\r\ncan',
#   'thy',
#   'thine',
#   'the',
#   'a',
#   'ye',
#   'we',
#   'any',
#   'it',
#   'it',
#   'it',
#   'they\r\ndrink'],
#  'would': ['heal',
#   'and\r\nthey',
#   'not',
#   'have',
#   'have',
#   'happen',
#   'not\r\nallow',
#   'be',
#   'rather'],
#  'heal': ['him', 'sickness,'],
#  'might': ['accuse',
#   'get',
#   'be',
#   'take\r\nHim',
#   'have',
#   'pass\r\nfrom',
#   'anoint'],
#  'accuse': ['Him.'],
#  'with\r\nthe': ['withered', 'washing', 'disciples.', 'rest.'],
#  'Step': ['Forward.'],
#  'Forward.': ['Then'],
#  'Is': ['it', 'a', 'this', 'it', 'it', 'it', 'it'],
#  'lawful\r\nto': ['do'],
#  'good': ['on',
#   'ground.',
#   'ground.',
#   'cheer.',
#   'for',
#   'but',
#   'comfort.',
#   'man'],
#  'days,': ['or', 'and', 'rise', 'no\r\nflesh', 'I', 'save'],
#  'or': ['to',
#   'to\r\nkill?',
#   'my',
#   'persecution\r\narises',
#   'in',
#   'cities',
#   'country,',
#   'understand?\r\nHave',
#   'brethren,',
#   'sisters,',
#   'mother,',
#   'wife,',
#   'children,',
#   'lands,',
#   'of',
#   'not?',
#   'the',
#   'plan\r\nbeforehand',
#   'at\r\nmidnight,',
#   'at',
#   'in'],
#  'evil?': ['To'],
#  'To': ['save', 'you', 'those', 'this', 'love'],
#  'save': ['life,', 'his', 'it.', 'thyself'],
#  'life,': ['or'],
#  'to\r\nkill?': ['But'],
#  'remained': ['silent.'],
#  'silent.': ['Jesus'],
#  'looked': ['at',
#   'around',
#   'up\r\nto',
#   'out',
#   'up\r\nand',
#   'at',
#   'around,',
#   'at'],
#  'anger': ['and'],
#  'grieved': ['for'],
#  'hardness': ['of\r\ntheir', 'of'],
#  'of\r\ntheir': ['hearts.'],
#  'hearts.': ['He', 'And'],
#  'Stretch': ['forth'],
#  'man\r\nstretched': ['it'],
#  'out,': ['his', 'He', 'Lord,', 'and', 'Jesus,', 'What', 'Crucify'],
#  'hand': ['was', 'and', 'upon', 'and', 'offend', 'and', 'is', 'of', 'of'],
#  'restored': ['as', 'and'],
#  'whole': ['as', 'of', 'world,', 'foundation.', 'council,', 'troop.', 'land'],
#  'other': ['hand.',
#   'things.',
#   'side.',
#   'little',
#   'side',
#   'side,',
#   'side',
#   'shore',
#   'things',
#   'side.',
#   'on',
#   'ten',
#   'commandment',
#   'but',
#   'on',
#   'women'],
#  'counsel': ['with'],
#  'Herodians\r\nabout': ['how'],
#  'rid': ['of'],
#  'withdrew': ['with'],
#  'His\r\ndisciples': ['to', 'to', 'rebuked'],
#  'sea.': ['A', 'Jesus', 'If'],
#  'A': ['great', 'prophet', 'man', 'maid'],
#  'great': ['multitude',
#   'that',
#   'storm.',
#   'calm.',
#   'herd',
#   'things',
#   'things',
#   'difficulty',
#   'multitude',
#   'ones',
#   'among',
#   'buildings?',
#   'power',
#   'multitude'],
#  'Judaea,\r\nJerusalem,': ['Idumaea,'],
#  'Idumaea,': ['and'],
#  'beyond': ['Jordan,', 'measure.', 'measure,'],
#  'Jordan,': ['and'],
#  'Tyre': ['and\r\nSidon', 'and', 'and'],
#  'and\r\nSidon': ['came'],
#  'did.': ['Jesus'],
#  'needed': ['to'],
#  'small': ['boat', 'fish', 'coins.'],
#  'lest\r\nthe': ['multitude'],
#  'should': ['throng',
#   'not',
#   'be',
#   'be',
#   'cross',
#   'be',
#   'take',
#   'ask',
#   'be',
#   'touch',
#   'I',
#   'take',
#   'die.',
#   'take.'],
#  'throng': ['Him.'],
#  'For': ['He',
#   'he',
#   'the',
#   'saying',
#   'whosoever',
#   'what',
#   'every',
#   'this',
#   'in',
#   'the'],
#  'who\r\nhad': ['plagues'],
#  'plagues': ['now'],
#  'pressed': ['upon'],
#  'just': ['to', 'as'],
#  'touch': ['Him.', 'His', 'but', 'the', 'them'],
#  'Unclean': ['spirits,\r\nwhen'],
#  'spirits,\r\nwhen': ['they'],
#  'fell': ['down',
#   'by',
#   'on',
#   'among',
#   'on',
#   'at',
#   'down',
#   'at',
#   'on',
#   'on\r\nthe'],
#  'cried,': ['Thou', 'O', 'lashed', 'Hosanna.'],
#  'of\r\nGod.': ['Jesus', 'Is'],
#  'known.': ['Then'],
#  'mountain.': ['He'],
#  'called': ['to',
#   'them',
#   'to',
#   'all',
#   'His',
#   'the',
#   'the\r\ntwelve,',
#   'them',
#   'to',
#   'His',
#   'out,',
#   'to',
#   'Praetorium;',
#   'Golgotha,',
#   'the\r\ncenturion'],
#  'and\r\nthey': ['came'],
#  'Here': ['He', 'they\r\nbrought', 'the'],
#  'ordained': ['twelve'],
#  'twelve': ['to',
#   'into',
#   'were',
#   'years.\r\nShe',
#   'years',
#   'to',
#   'baskets\r\nfull',
#   'that'],
#  'He\r\nmight': ['send'],
#  'preach,': ['to'],
#  'sickness,': ['and'],
#  'devils.\r\nThen': ['He'],
#  'house:': ['Simon'],
#  'surnamed': ['Peter;'],
#  'Peter;': ['James,\r\nthe'],
#  'James,\r\nthe': ['son'],
#  'brother': ['of',
#   'of',
#   'of\r\nJames,',
#   "Philip's",
#   'dies',
#   'should',
#   'likewise',
#   'shall',
#   'even'],
#  'James': ['(He', 'and', 'and', 'and', 'the'],
#  '(He': ['named'],
#  'named': ['them\r\nBoanerges,', 'Gethsemane.', 'Barabbas,'],
#  'them\r\nBoanerges,': ['which'],
#  'is,': ['The', 'God.', 'Hear,', 'Thou'],
#  'sons': ['of', 'of', 'of'],
#  'thunder);': ['Andrew;'],
#  'Andrew;': ['Philip;\r\nBartholomew;'],
#  'Philip;\r\nBartholomew;': ['Matthew;'],
#  'Matthew;': ['Thomas;'],
#  'Thomas;': ['James,'],
#  'Alphaeus;': ['Thaddaeus;\r\nSimon'],
#  'Thaddaeus;\r\nSimon': ['the'],
#  'Canaanite;': ['and'],
#  'Judas': ['Iscariot,', 'Iscariot,', 'schemed', 'immediately'],
#  'Iscariot,': ['who', 'one'],
#  'betrayed': ['Him.', 'into', 'Jesus\r\nhad'],
#  'eat': ['bread\r\nundisturbed.',
#   'unless\r\nthey',
#   'bread',
#   'the',
#   'and',
#   'the'],
#  'bread\r\nundisturbed.': ['When'],
#  'friends': ['heard'],
#  'hold': ['of', 'of', 'of'],
#  'Him\r\nand': ['said,', 'said,'],
#  'This': ['is',
#   'did',
#   'is',
#   'people',
#   'is',
#   'is',
#   'was',
#   'is',
#   'poor',
#   'generation',
#   'man',
#   'is',
#   'is',
#   'day,',
#   'is'],
#  'too': ['much.'],
#  'much.': ['And', 'He'],
#  'from\r\nJerusalem': ['said,'],
#  'Beelzebub,': ['and,'],
#  'prince': ['of'],
#  'devils,': ['He\r\ncasts', 'anointed'],
#  'He\r\ncasts': ['out'],
#  'Satan?': ['And\r\nif'],
#  'And\r\nif': ['a', 'a'],
#  'divided': ['against', 'against', 'the'],
#  'against': ['itself,',
#   'itself,',
#   'himself,',
#   'them.',
#   'John\r\nand',
#   'her.',
#   'anyone,',
#   'the',
#   'the',
#   'nation,',
#   'kingdom.',
#   'them.',
#   'their',
#   'her.\r\nBut',
#   'Jesus\r\nto',
#   'thee?',
#   'thee?'],
#  'itself,': ['that', 'that'],
#  'stand.': ['And\r\nif', 'And'],
#  'if\r\nSatan': ['rise'],
#  'rise': ['up', 'again.', 'again.', 'from', 'against', 'up'],
#  'himself,': ['and'],
#  'divided,': ['he'],
#  'stand': ['and', 'here', 'praying,'],
#  'is\r\nfinished.': ['Nor'],
#  'Nor': ['can'],
#  'strong': ["man's", 'man'],
#  "man's": ['house', 'ears.', 'ears', 'eyes', 'brother'],
#  'spoil': ['his\r\ngoods', 'his\r\nhouse.'],
#  'his\r\ngoods': ['unless'],
#  'unless': ['he'],
#  'first': ['binds', 'the', 'be', 'and', 'shall', 'of', 'commandment.', 'day'],
#  'binds': ['up'],
#  'his\r\nhouse.': ['Verily'],
#  'Verily': ['I', 'I', 'I', 'I', 'I'],
#  'you,': ['All', 'when', 'It', 'There', 'Elias', 'Whosoever', 'Lo,'],
#  'men,\r\nand': ['blasphemies'],
#  'blasphemies': ['also,'],
#  'also,': ['however', 'when'],
#  'however': ['they'],
#  'blaspheme.': ['But'],
#  'blasphemes\r\nagainst': ['the'],
#  'Ghost': ['will'],
#  'forgiveness,': ['but'],
#  'danger\r\nof': ['eternal'],
#  'eternal': ['damnation.', 'life?', 'life.'],
#  'damnation.': ['He'],
#  'an\r\nunclean': ['spirit.'],
#  'brethren': ['and', 'are'],
#  'standing': ['outside,', 'where'],
#  'outside,': ['they', 'one'],
#  'called\r\nfor': ['Him.'],
#  'mother\r\nand': ['thy'],
#  'answered,': ['Who',
#   'My',
#   'Give',
#   'Well',
#   'Yes,\r\nLord.',
#   'Thou',
#   'As',
#   'Moses',
#   'Ye',
#   'Have',
#   'I',
#   'Why',
#   'Ye',
#   'The',
#   'It',
#   'Thou'],
#  'is\r\nmy': ['mother,'],
#  'mother,': ['or', 'let', 'and', 'or'],
#  'brethren?': ['Then'],
#  'sat\r\nabout': ['Him'],
#  'brethren!': ['Whosoever'],
#  'Whosoever': ['shall\r\ndo',
#   'will',
#   'shall',
#   'shall',
#   'shall',
#   'shall',
#   'shall',
#   'will',
#   'will',
#   'shall'],
#  'shall\r\ndo': ['the'],
#  'same': ['is', 'devour', 'way,\r\nwhen', 'words.\r\nWhen', 'is\r\nHe.'],
#  'sister,': ['and'],
#  'mother.': ['4'],
#  '4': [''],
#  'seaside,': ['there'],
#  'a\r\ngreat': ['multitude.'],
#  'multitude.': ['He'],
#  'address': ['the'],
#  'large\r\ncrowd': ['on'],
#  'shore.': ['He'],
#  'parables.': ['Jesus', 'He', 'A'],
#  'began,\r\nHearken.': ['Behold,'],
#  'sower': ['of', 'sows'],
#  'seeds.': ['It'],
#  'It': ['came',
#   'sprang',
#   'is',
#   'shoots\r\nout',
#   'shall',
#   'is',
#   'is\r\nJohn',
#   'is\r\nI.',
#   'is\r\nwritten,',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'shall',
#   'is',
#   'is',
#   'might',
#   'is',
#   'is',
#   'was'],
#  'as\r\nhe': ['sowed,'],
#  'sowed,': ['some'],
#  'seed': ['fell', 'fell', 'fell', 'fell', 'sown', 'springs', 'to'],
#  'wayside.': ['The'],
#  'fowls': ['of', 'of'],
#  'air': ['came', 'may'],
#  'and\r\ndevoured': ['it.'],
#  'it.': ['Some', 'To', 'He', 'But', 'For', 'He', 'Many', 'He', 'Then'],
#  'Some': ['seed', 'seed', 'say', 'of', 'of'],
#  'stony': ['ground', 'ground.'],
#  'ground': ['where', 'wallowing'],
#  'good\r\nsoil.': ['It'],
#  'sprang': ['up', 'up'],
#  'quickly.': ['But,'],
#  'But,': ['because', 'from', 'take', 'of\r\nthe', 'after'],
#  'roots,': ['it'],
#  'was\r\nscorched': ['by'],
#  'sunlight': ['and'],
#  'away.': ['Some', 'I', 'Jesus', 'Jesus', 'But,', 'Entering'],
#  'thorns.': ['The'],
#  'thorns': ['grew', 'of', 'enter'],
#  'grew': ['up', 'worse.'],
#  'choked': ['it,'],
#  'it,': ['and', 'ye', 'He', 'No'],
#  'it\r\nyielded': ['no'],
#  'fruit.': ['Other'],
#  'Other': ['seed'],
#  'ground.': ['This', 'When', 'In', 'He', 'He', 'He'],
#  'yield': ['fruit\r\nthat'],
#  'fruit\r\nthat': ['sprang'],
#  'increased;': ['and'],
#  'thirty,': ['some\r\nsixty,'],
#  'some\r\nsixty,': ['and'],
#  'hundredfold.': ['And', 'Then'],
#  'finished': ['by'],
#  'that\r\nhas': ['ears'],
#  'hear,': ['let', 'and\r\nnot', 'more', 'let\r\nhim', 'and'],
#  'let': ['him',
#   'him',
#   'him',
#   'him',
#   'him',
#   'no',
#   'them',
#   'it',
#   'us',
#   'out',
#   'those',
#   'us'],
#  'hear.': ['After', 'And', 'With', 'After'],
#  'alone': ['with', 'on'],
#  'Jesus,': ['they',
#   'thou',
#   'they\r\nsaw',
#   'he',
#   'knowing',
#   'and',
#   'and',
#   'knelt',
#   'beholding',
#   'looking',
#   'thou',
#   'Master,',
#   'but',
#   'knowing',
#   'Where',
#   'Answer',
#   'and'],
#  'asked': ['Him\r\nabout',
#   'Him,',
#   'Him',
#   'them,',
#   'the',
#   'His',
#   'Him',
#   'the',
#   'the',
#   'them,',
#   'Him',
#   'Him,',
#   'Him,'],
#  'Him\r\nabout': ['the'],
#  'parable': ['and', 'about\r\nthem.', 'of'],
#  'parable.': ['Jesus'],
#  'given': ['to', 'something', 'to', 'to', 'to', 'thanks,', 'them'],
#  'mystery': ['of'],
#  'God.\r\nBut,': ['to'],
#  'without,': ['the', 'Jesus'],
#  'teachings': ['are'],
#  'parables:': ['That\r\nseeing'],
#  'That\r\nseeing': ['they'],
#  'see,': ['and', 'if'],
#  'perceive;': ['and'],
#  'hearing': ['they', 'the', 'this'],
#  'and\r\nnot': ['understand;'],
#  'understand;': ['lest'],
#  'lest': ['at', 'any', 'there'],
#  'converted,': ['and'],
#  'their\r\nsins': ['should'],
#  'Know': ['ye'],
#  'parable?': ['The'],
#  'sows': ['the\r\nword.'],
#  'the\r\nword.': ['And'],
#  'wayside,': ['where'],
#  'word': ['is', 'of', 'that\r\nJesus'],
#  'sown.\r\nWhen': ['they'],
#  'heard,': ['Satan'],
#  'comes': ['immediately', 'in', 'first', 'in'],
#  'word\r\nthat': ['was'],
#  'sown': ['in', 'on', 'among', 'on', 'in'],
#  'likewise': ['those', 'and'],
#  'they\r\nhave': ['heard', 'nothing'],
#  'word,': ['they', 'and'],
#  'receive': ['it',
#   'it',
#   'one',
#   'me,',
#   'the',
#   'a',
#   'them,\r\nand',
#   'greater\r\ndamnation.'],
#  'gladness.': ['But'],
#  'no\r\nroot': ['and'],
#  'endure': ['only', 'to'],
#  'while.': ['When', 'They'],
#  'affliction': ['or'],
#  'persecution\r\narises': ['for'],
#  "word's": ['sake,'],
#  'sake,': ['they', 'and', 'for'],
#  'offended.': ['And'],
#  'cares': ['of'],
#  'this\r\nworld,': ['the'],
#  'deceitfulness': ['of'],
#  'riches,': ['and'],
#  'lusts': ['of'],
#  'things.': ['All\r\nthese', 'Was', '12', 'Now'],
#  'All\r\nthese': ['thorns'],
#  'in,': ['choke', 'say'],
#  'choke': ['the'],
#  'becomes': ['unfruitful.', 'greater'],
#  'unfruitful.': ['And,\r\nfinally,'],
#  'And,\r\nfinally,': ['are'],
#  'In': ['hearing',
#   'the',
#   'a',
#   'what',
#   'laying',
#   'return,',
#   'Jerusalem',
#   'Jerusalem,',
#   'the',
#   'the\r\nsynagogues',
#   'that',
#   'the',
#   'the',
#   'the',
#   'my'],
#  'word,\r\nthey': ['receive'],
#  'bring': ['forth', 'any', 'him'],
#  'fruit,': ['some'],
#  'thirtyfold,': ['some'],
#  'sixty,\r\nand': ['some'],
#  'candle': ['lighted'],
#  'lighted': ['to'],
#  'under': ['a', 'the\r\nshadow', 'the'],
#  'bushel,': ['or\r\nunder'],
#  'or\r\nunder': ['a'],
#  'instead': ['of'],
#  'set': ['on', 'before', 'them', 'at', 'a'],
#  'candlestick?': ['You'],
#  'You': ['see,', 'lack\r\none'],
#  'is\r\nnothing': ['hidden'],
#  'hidden': ['which'],
#  'manifested,': ['then'],
#  'nothing\r\nkept': ['secret,'],
#  'secret,': ['which'],
#  'uncovered.': ['If'],
#  'to\r\nhear,': ['let'],
#  'heed': ['what', 'lest'],
#  'With': ['what', 'what\r\nshall', 'men', 'God', 'them'],
#  'measure': ['ye\r\nmete,'],
#  'ye\r\nmete,': ['it'],
#  'measured': ['to'],
#  'you.': ['And', 'Understand', 'Whosoever', 'Many', 'They'],
#  'be\r\ngiven.': ['For'],
#  'has,': ['to'],
#  'given.': ['He'],
#  'not,': ['from\r\nhim', 'Honor'],
#  'from\r\nhim': ['shall'],
#  'even': ['that',
#   'the',
#   'such',
#   'up',
#   'to',
#   'unto',
#   'the\r\nelect.',
#   'this',
#   'if'],
#  'has.': ['Then'],
#  'Such': ['is'],
#  'casts': ['seed\r\ninto'],
#  'seed\r\ninto': ['the'],
#  'passes': ['nights'],
#  'nights': ['and'],
#  'springs': ['up\r\nand'],
#  'up\r\nand': ['grows,', 'said,'],
#  'grows,': ['he'],
#  'knows': ['not'],
#  'how.': ['For'],
#  'brings': ['forth'],
#  'fruit': ['of\r\nherself;', 'is', 'of', 'of', 'of'],
#  'of\r\nherself;': ['first'],
#  'blade,': ['then'],
#  'ear,': ['and,'],
#  'full': ['ear\r\nof', 'of', 'of', 'of', 'of'],
#  'ear\r\nof': ['corn.'],
#  'corn.': ['When'],
#  'ripe,': ['immediately'],
#  'sickle': ['to'],
#  'it\r\nbecause': ['the'],
#  'harvest': ['is'],
#  'come.': ['And', 'The'],
#  'Whereto': ['shall'],
#  'liken': ['the'],
#  'God?': ['With', 'I'],
#  'what\r\nshall': ['we'],
#  'compare': ['it?'],
#  'it?': ['It', 'Have'],
#  'grain': ['of'],
#  'mustard': ['seed,'],
#  ...}

# %%
generate_sentence(mark_dict)
# Out:
# 'Scourged, he arose. After Jesus because it I? Is this thing. The man\r\ncried with you.'

# %%
# ok that one starts off ok but then goes off the rails
luke_text = data.transcripts.loc['Luke']
# Create the dictionary for Matthew's gospel, take a look at it
luke_dict = markov_chain(luke_text)
luke_dict
# Out:
# {'Title:': ['The'],
#  'The': ['Gospel',
#   'multitude',
#   'angel',
#   'people',
#   'angel',
#   'Lord',
#   'Lord',
#   'Holy',
#   'child',
#   'shepherds',
#   'shepherds\r\nreturned,',
#   'Holy',
#   'word',
#   'voice',
#   'people',
#   'publicans',
#   'soldiers,',
#   'devil',
#   'devil,',
#   'devil',
#   'devil',
#   'Spirit',
#   'eyes',
#   'people\r\nwere',
#   'people\r\nlooked',
#   'fishermen',
#   'scribes',
#   'scribes',
#   'days\r\nwill',
#   'old',
#   'Son',
#   'scribes',
#   'man',
#   'whole',
#   'disciple',
#   'next',
#   'young',
#   'Lord',
#   'Son',
#   'seed',
#   'seed',
#   'seed',
#   'ship',
#   'storm',
#   'devils',
#   'man',
#   'Christ',
#   'Son',
#   'next',
#   'Son',
#   'Son',
#   'seventy',
#   'lawyer',
#   'lawyer',
#   'door',
#   'crowd',
#   'queen',
#   'men',
#   'light',
#   'wisdom',
#   'blood',
#   'Holy',
#   'ground',
#   'Lord',
#   'father',
#   'ruler',
#   'Lord',
#   'kingdom',
#   'host',
#   'first',
#   'servant',
#   'servant',
#   'lord',
#   'younger',
#   'father',
#   'son',
#   'elder',
#   'servant',
#   'elder',
#   'father',
#   'master',
#   'steward',
#   'first',
#   'other',
#   'children',
#   'one',
#   'one',
#   'Pharisees,',
#   'law',
#   'rich',
#   'rich',
#   'Lord',
#   'kingdom',
#   'days',
#   'Lord',
#   'Pharisee',
#   'publican,',
#   'man\r\nsaid,',
#   'people,',
#   'Son',
#   'second',
#   'Lord',
#   'chief',
#   'first\r\ntook',
#   'second',
#   'third',
#   'children',
#   'Lord',
#   'rich',
#   'feast',
#   'chief',
#   'Master',
#   'kings',
#   'Lord',
#   'things',
#   'men',
#   'whole',
#   'chief',
#   'days',
#   'people',
#   'sun',
#   'women\r\nwho',
#   'women',
#   'Lord',
#   'Gospel'],
#  'Gospel': ['of', 'of', 'of'],
#  'of': ['Luke',
#   'Luke\r\n\r\n______________________________________________________________________\n',
#   'the',
#   'those',
#   'these',
#   'the',
#   'Herod,',
#   'Judaea,',
#   'the',
#   'Abia.',
#   'the',
#   'the\r\n\r\nLord.',
#   'the',
#   'the',
#   'incense.',
#   'the',
#   'incense.',
#   'the',
#   'the',
#   'Israel',
#   'Elias',
#   'the\r\nfathers',
#   'the\r\njust;',
#   'God;',
#   'his',
#   'the',
#   'David.',
#   'the',
#   'His\r\nfather',
#   'Jacob',
#   'God.',
#   'the',
#   'Juda',
#   'Zacharias,',
#   'Mary,',
#   'my',
#   'thy',
#   'those',
#   'His',
#   'their',
#   'low',
#   'His',
#   'his',
#   'thy\r\nkindred',
#   'Judaea.',
#   'child',
#   'the',
#   'Israel;',
#   'salvation',
#   'His',
#   'all',
#   'the',
#   'our',
#   'our',
#   'the',
#   'the',
#   'salvation',
#   'their',
#   'our',
#   'death,',
#   'peace.',
#   'his',
#   'David,',
#   'Bethlehem',
#   'the',
#   'the',
#   'David.',
#   'the',
#   'the',
#   'Moses',
#   'the',
#   'turtledoves,\r\nor',
#   'Israel.',
#   'all',
#   'Him.\r\nSimeon',
#   'many',
#   'many',
#   'Him.',
#   'Phanuel,\r\nof',
#   'Aser.',
#   'Him',
#   'Nazareth',
#   'God.',
#   'the',
#   'the',
#   'it.',
#   'the',
#   'the',
#   'the',
#   'Tiberius',
#   'Judaea;',
#   'Galilee;\r\nand',
#   'Ituraea',
#   'Abilene.',
#   'God',
#   'Zacharias',
#   'repentance',
#   'sins.',
#   'Esaias',
#   'one\r\ncrying',
#   'the',
#   'vipers,',
#   'repentance.',
#   'the',
#   'whose',
#   'Herodias,\r\nhis',
#   'age,',
#   'Joseph,',
#   'Heli,',
#   'Matthat,',
#   'Levi,',
#   'Melchi,',
#   'Janna,',
#   'Joseph,',
#   'Amos,',
#   'Naum,',
#   'Nagge,',
#   'Maath,',
#   'Semei,',
#   'Joseph,',
#   'Juda.',
#   'Joanna,',
#   'Rhesa,',
#   'Zorobabel,',
#   'Salathiel,',
#   'Melchi,',
#   'Addi,',
#   'Cosam,',
#   'Er,',
#   'Jose,',
#   'Eliezer,\r\nwhich',
#   'Jorim,',
#   'Matthat,',
#   'Levi.',
#   'Simeon,',
#   'Juda,',
#   'Joseph,',
#   'Jonan,',
#   'Melea,',
#   'Menan,',
#   'Mattatha,',
#   'Nathan,',
#   'Jesse,',
#   'Obed,',
#   'Booz,',
#   'Salmon.',
#   'Naasson,',
#   'Aminadab,',
#   'Esrom,',
#   'Phares,',
#   'Juda,',
#   'Jacob,',
#   'Isaac.',
#   'Abraham,',
#   'Thara,',
#   'Nachor,',
#   'Saruch,',
#   'Ragau,',
#   'Phalec,',
#   'Heber,',
#   'Sala,',
#   'Cainan,',
#   'Sem,',
#   'Noah.',
#   'Lamech,',
#   'Mathusala,',
#   'Enoch,',
#   'Jared,',
#   'Maleleel,',
#   'Enos,',
#   'Seth,',
#   'Adam,',
#   'God.',
#   'God,',
#   'God.',
#   'the',
#   'time.',
#   'all',
#   'the\r\ntemple',
#   'God,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'all',
#   'Elias,',
#   'them',
#   'Sidon,',
#   'Eliseus',
#   'them',
#   'the',
#   'the',
#   'an',
#   'Nazareth?',
#   'God.',
#   'him.',
#   'him.',
#   'that',
#   'the',
#   'them',
#   'many,',
#   'God.',
#   'Galilee.',
#   'God,',
#   'Gennesaret.',
#   'them',
#   'the',
#   'fish.',
#   'their',
#   'the',
#   'every',
#   'the',
#   'the',
#   'where',
#   'man',
#   'custom.',
#   'publicans',
#   'John',
#   'the',
#   'a',
#   'the',
#   'the',
#   'man',
#   'the',
#   'them,',
#   'James;',
#   'His',
#   'people',
#   'all\r\nJudaea',
#   'Tyre',
#   'their',
#   'Him',
#   'God.',
#   "man's",
#   'you,',
#   'the\r\nHighest',
#   'a',
#   'the',
#   'his',
#   'the',
#   'his',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'a',
#   'the',
#   'Him',
#   'John',
#   'these',
#   'their',
#   'evil',
#   'whom',
#   'women',
#   'God',
#   'John,',
#   'God',
#   'this',
#   'man',
#   'publicans',
#   'all',
#   'the',
#   'ointment',
#   'woman\r\nthis',
#   'them',
#   'her',
#   'the',
#   'God,',
#   'evil',
#   'whom',
#   "Herod's",
#   'the',
#   'the',
#   'the',
#   'the',
#   'God.',
#   'God.',
#   'their',
#   'temptation\r\nthey',
#   'the',
#   'the',
#   'the',
#   'the',
#   'God',
#   'swine',
#   'the',
#   'whom',
#   'Jesus,',
#   'the',
#   'the',
#   'blood',
#   'His',
#   'blood',
#   'me.',
#   'good',
#   "the\r\nsynagogue's",
#   'the',
#   'God,',
#   'the',
#   'old\r\nwas',
#   'Bethsaida.',
#   'the',
#   'God',
#   'healing.',
#   'fifty.',
#   'old',
#   'God.',
#   'this.',
#   'man',
#   'me',
#   'my',
#   'man',
#   'him',
#   'the',
#   'death',
#   'His',
#   'the',
#   'those',
#   'God.',
#   'man\r\nshall',
#   'men.',
#   'them',
#   'their',
#   'the',
#   'spirit',
#   'man',
#   'the',
#   'man',
#   'God.',
#   'God.',
#   'peace',
#   'his',
#   'God',
#   'the',
#   'your\r\ncity,',
#   'God',
#   'the',
#   'heaven',
#   'him.',
#   'him.',
#   'these',
#   'the',
#   'His\r\ndisciples',
#   'you',
#   'mine',
#   'your',
#   'a',
#   'them',
#   'Beelzebub,',
#   'the',
#   'God,',
#   'God',
#   'which',
#   'that',
#   'God',
#   'man',
#   'the',
#   'the',
#   'Solomon;',
#   'Nineve',
#   'Jonas;',
#   'the',
#   'light.',
#   'darkness.',
#   'light,',
#   'light,',
#   'a',
#   'the',
#   'poison',
#   'what\r\nyou',
#   'God.',
#   'the',
#   'your',
#   'God',
#   'all',
#   'the',
#   'this',
#   'Abel',
#   'this',
#   'knowledge.',
#   'many',
#   'the',
#   'the',
#   'those',
#   'them',
#   'your',
#   'more',
#   'man',
#   'God.',
#   'God.',
#   'man,',
#   'the',
#   'covetousness.',
#   'the',
#   'things',
#   'a',
#   'thee;\r\nthen',
#   'you,',
#   'these.',
#   'little',
#   'a',
#   'the',
#   'these',
#   'God',
#   'the',
#   'man',
#   'meat',
#   'that',
#   'stripes,',
#   'him',
#   'him',
#   'the\r\nwest,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'you',
#   'Abraham,\r\nwhom',
#   'the',
#   'God',
#   'mustard',
#   'the',
#   'God',
#   'meal',
#   'the',
#   'iniquity.',
#   'teeth',
#   'God,',
#   'God.',
#   'the',
#   'the',
#   'one',
#   'the\r\nchief',
#   'you',
#   'the\r\nother',
#   'the',
#   'them',
#   'God.\r\nThen',
#   'the',
#   'the',
#   'those',
#   'my',
#   'you,',
#   'you',
#   'you,',
#   'silver,',
#   'the\r\nangels',
#   'God',
#   'them',
#   'my',
#   'my',
#   'thy',
#   'the',
#   'wasting',
#   'thee?',
#   'your\r\nstewardship;',
#   'this',
#   'his',
#   'oil.',
#   'wheat.',
#   'this',
#   'light.',
#   'God.',
#   'God',
#   'the',
#   'purple',
#   'torment.',
#   'these',
#   'mustard\r\nseed,',
#   'you,',
#   'Samaria',
#   'them,',
#   'God',
#   'God',
#   'the',
#   'the',
#   'man,',
#   'man',
#   'Noah,',
#   'man.',
#   'Lot.',
#   'man',
#   'my',
#   'man',
#   'all',
#   'such',
#   'God.',
#   'God',
#   'God!',
#   'God.',
#   "God's",
#   'man',
#   'David,',
#   'David,',
#   'the',
#   'stature',
#   'the',
#   'a',
#   'my',
#   'Abraham.',
#   'man',
#   'God\r\nshould',
#   'what',
#   'thine',
#   'His',
#   'him.',
#   'him.',
#   'the',
#   'Olives,',
#   'the',
#   'the',
#   'the',
#   'thy',
#   'thieves.',
#   'the',
#   'John,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'His',
#   'the',
#   'God.',
#   'the',
#   'all',
#   'the',
#   'this',
#   'obtaining',
#   'God,',
#   'the',
#   'Abraham,\r\nand',
#   'Isaac,',
#   'Jacob.',
#   'the\r\ndead,',
#   'the',
#   'the',
#   'Psalms,',
#   'the\r\nscribes',
#   'their',
#   'you',
#   'it',
#   'vengeance,',
#   'the\r\n\r\nGentiles',
#   'man',
#   'God',
#   'this',
#   'the',
#   'man.',
#   'the\r\ncity',
#   'Olives.',
#   'unleavened',
#   'the',
#   'unleavened',
#   'the',
#   'God',
#   'the',
#   'the',
#   'God',
#   'me.',
#   'him',
#   'man',
#   'them\r\nit',
#   'them',
#   'the',
#   'Israel.',
#   'Olives;',
#   'the',
#   'man\r\nwith',
#   'them',
#   'the',
#   'this.',
#   'the',
#   'darkness.',
#   'them.\r\nPeter',
#   'man',
#   'the',
#   'God.',
#   'God?',
#   'any',
#   'the',
#   'Galilee,',
#   'which',
#   'necessity',
#   'the',
#   'the',
#   'Jerusalem,',
#   'God.',
#   'the',
#   'Greek,',
#   'the',
#   'the',
#   'the',
#   'God.',
#   'Jesus.',
#   'preparation',
#   'the',
#   'the',
#   'man',
#   'sinful',
#   'James;',
#   'them',
#   'them,',
#   'Nazareth,',
#   'the',
#   'our\r\ngroup',
#   'angels',
#   'those',
#   'heart',
#   'the',
#   'them',
#   'broiled',
#   'a\r\nhoneycomb.',
#   'Moses',
#   'sins',
#   'my\r\nFather',
#   'Jerusalem',
#   'Project',
#   'Luke'],
#  'Luke': ['for', 'for'],
#  'for': ['Readers',
#   'the',
#   'Zacharias,',
#   'he',
#   'five',
#   'me\r\nthat',
#   'thou',
#   'joy.',
#   'there\r\nshall',
#   'a',
#   'He',
#   'us',
#   'thou\r\nshall',
#   'her',
#   'them',
#   'all',
#   'the',
#   'the',
#   'the',
#   'a',
#   'fourscore',
#   'the',
#   'I',
#   'all',
#   'His',
#   'Him.',
#   'I',
#   'thy',
#   'a',
#   'the',
#   'yours',
#   'you',
#   'you\r\nshall',
#   'the\r\nSon',
#   'joy!',
#   'those',
#   'them',
#   'He',
#   'it',
#   'he',
#   'my',
#   'she',
#   'and',
#   'whoever',
#   'a',
#   'thee.\r\nThe',
#   'Him.',
#   'twelve',
#   'I',
#   'your',
#   'all\r\nthese',
#   'my',
#   'us',
#   'thee,',
#   'Moses,',
#   'Elias.',
#   'he',
#   'he',
#   'us.',
#   'the',
#   'the',
#   'Sodom,',
#   'that',
#   'Tyre',
#   'you.',
#   'another,',
#   'bread,',
#   'she',
#   'they',
#   'two',
#   'himself',
#   'your',
#   'the',
#   'the',
#   'it',
#   'their',
#   'him',
#   'three',
#   'eighteen',
#   'eighteen',
#   'all',
#   'Herod\r\nwill',
#   'it',
#   'the',
#   'the\r\ndunghill;',
#   'my',
#   'him.',
#   'us',
#   'you',
#   'heaven',
#   'one',
#   'them.',
#   'of',
#   'those',
#   'a',
#   'a',
#   'men',
#   'God.',
#   'the',
#   'you?',
#   'an',
#   'I',
#   'all',
#   'they',
#   'a',
#   'ways',
#   'us',
#   'Him.',
#   'a',
#   'these',
#   'many',
#   'these',
#   'my',
#   'my',
#   'the',
#   'your',
#   'they',
#   'I',
#   'I',
#   'you.',
#   'you.',
#   'he',
#   'you,',
#   'he',
#   'a',
#   'he',
#   'sedition',
#   'me,',
#   'they',
#   'you',
#   'our',
#   'the',
#   'a',
#   'Readers,'],
#  'Readers': ['Editor:'],
#  'Editor:': ['Lightheart'],
#  'Lightheart': ['Release'],
#  'Release': ['date:'],
#  'date:': ['September'],
#  'September': ['1,'],
#  '1,': ['2004'],
#  '2004': ['[eBook'],
#  '[eBook': ['#6529]\r\n'],
#  '#6529]\r\n': [''],
#  '': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Most',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Forasmuch',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'A',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'It',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Filled',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'As',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'It',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Jesus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Afterward,',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Then',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'After',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'After',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Later,',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Among',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'It',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Seeing',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Jesus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Then',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Jesus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'In',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'One',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Jesus',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'The',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'The',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'On',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'edited',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'www.PracticeGodsPresence.com'],
#  'Most': ['recently'],
#  'recently': ['updated:'],
#  'updated:': ['August'],
#  'August': ['21,'],
#  '21,': ['2012'],
#  '2012': ['Language:'],
#  'Language:': ['English'],
#  'English': ['Copyright'],
#  'Copyright': ['(C)'],
#  '(C)': ['2002'],
#  '2002': ['by'],
#  'by': ['Lightheart.',
#   'his',
#   'the\r\nLord.',
#   'this',
#   'the',
#   'the',
#   'night.',
#   'the',
#   'the',
#   'him,',
#   'saying',
#   'John',
#   'the',
#   'every',
#   'all.',
#   'the',
#   'the\r\nlake.',
#   'Him.',
#   'its',
#   'him.',
#   'the\r\nwayside',
#   'the',
#   'the\r\ndevils',
#   'the',
#   'the\r\nelders,',
#   'two,',
#   'my',
#   'and',
#   'on',
#   'day,',
#   'the\r\npower',
#   'Beelzebub,\r\ncast',
#   'whom',
#   'them.\r\nHowever,',
#   'God?',
#   'thinking',
#   'Him.',
#   'publicans',
#   'the',
#   'one',
#   'the',
#   'observation.',
#   'this\r\ngeneration.',
#   'the\r\nprophets',
#   'false',
#   'what',
#   'what',
#   'parents,',
#   'the',
#   'whom\r\nHe',
#   'me',
#   'Him.',
#   'casting',
#   'them',
#   'themselves',
#   'the',
#   'Lightheart\r\n',
#   'Lightheart'],
#  'Lightheart.': ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0www.PracticeGodsPresence.com\r\n\r\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0The'],
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0www.PracticeGodsPresence.com\r\n\r\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0The': ['Gospel'],
#  'Luke\r\n\r\n______________________________________________________________________\n': ['1.'],
#  '1.': [''],
#  'Forasmuch': ['as'],
#  'as': ['many',
#   'soon',
#   'the',
#   'the',
#   'He',
#   'He',
#   'it',
#   'it',
#   'the\r\nother.',
#   'evil',
#   'you',
#   'much',
#   'your',
#   'his',
#   'it',
#   'a',
#   'Jesus',
#   'they\r\ndeparted',
#   'Elias',
#   'lambs',
#   'they',
#   'are',
#   'thyself.',
#   'John',
#   'you',
#   'empty',
#   'graves',
#   'lay',
#   'He',
#   'a',
#   'you',
#   'soon\r\nas',
#   'small',
#   'a',
#   'Jesus',
#   'lightning',
#   'lift',
#   'a',
#   'He',
#   'He',
#   'He',
#   'He',
#   'Jesus',
#   'a',
#   'a',
#   'the',
#   'captives',
#   'the\r\nsea',
#   'a',
#   'He',
#   'it',
#   'the',
#   'he',
#   'He',
#   'my',
#   'wheat.',
#   'against',
#   'it',
#   'he',
#   'they',
#   'you',
#   'the',
#   'though\r\nHe',
#   'they',
#   'you',
#   'far',
#   'Bethany,'],
#  'many': ['eyewitnesses',
#   'of',
#   'in',
#   'hearts',
#   'widows',
#   'who',
#   'of',
#   'that',
#   'others\r\nprovided',
#   'towns',
#   'devils',
#   'things;',
#   'people',
#   'things.',
#   'things.',
#   'sparrows.',
#   'stripes.',
#   'cities\r\nand',
#   'people.',
#   'of',
#   'years',
#   'things,',
#   'possessions.',
#   'thought',
#   'shall',
#   'other',
#   'things'],
#  'eyewitnesses': ['and'],
#  'and': ['ministers',
#   'delivered',
#   'her',
#   'ordinances',
#   'gladness',
#   'many\r\nwill',
#   'he',
#   'power',
#   'the',
#   'am',
#   'to\r\nshow',
#   'unable',
#   'marvelled',
#   'remained',
#   'hid\r\nherself',
#   'bring',
#   'shall',
#   'the',
#   'went',
#   'saluted',
#   'blessed',
#   'my',
#   'exalted',
#   'the',
#   'to',
#   'she',
#   'her',
#   'they',
#   'wrote,',
#   'he',
#   'praised',
#   'prophesied,\r\nBlessed',
#   'redeemed\r\nHis',
#   'from',
#   'to',
#   'righteousness,',
#   'in\r\nthe',
#   'became',
#   'lineage',
#   'laid',
#   'the\r\nglory',
#   'good',
#   'see',
#   'Joseph,',
#   'the',
#   'pondered',
#   'praising',
#   'seen,',
#   'devout\r\nman,',
#   'revealed',
#   'said,\r\nLord,',
#   'the',
#   'Mary',
#   'said',
#   'rising',
#   'for',
#   'served',
#   'day.',
#   'spoke',
#   'was',
#   'His',
#   'asking',
#   'answers.',
#   'I',
#   'was',
#   'in',
#   'man.',
#   'the',
#   'Lysanias',
#   'Caiaphas\r\nwere',
#   'every',
#   'hill\r\nshall',
#   'the',
#   'the\r\nrough',
#   'all',
#   'cast',
#   'wondered',
#   'with',
#   'for',
#   'was\r\nled',
#   'showed',
#   'glory',
#   'to\r\nwhomever',
#   'Him',
#   'said,',
#   'stood',
#   'to',
#   'sat',
#   'wondered',
#   'six',
#   'none',
#   'pushed',
#   'taught',
#   'come',
#   'said,',
#   'power\r\nHe',
#   'they',
#   'entered',
#   'they',
#   'it',
#   'ministered',
#   'healed\r\nthem.',
#   'saying,',
#   'silenced',
#   'went',
#   'were',
#   'requested',
#   'taught',
#   'have',
#   'his',
#   'their',
#   'help',
#   'filled',
#   'said,',
#   'John,',
#   'all',
#   'followed',
#   'said,',
#   'said,',
#   'be',
#   'the',
#   'Judaea,',
#   'Jerusalem.',
#   'doctors',
#   'lay',
#   'lowered',
#   'the',
#   'walk?',
#   'go',
#   'departed',
#   'glorified',
#   'were\r\nfilled',
#   'saw',
#   'followed',
#   'others',
#   'Pharisees',
#   'drink',
#   'sinners?',
#   'likewise',
#   'drink?',
#   'the',
#   'the',
#   'both',
#   'His',
#   'also',
#   'is',
#   'said',
#   'stood\r\nforth.',
#   'discussed',
#   'John;\r\n\r\nPhilip',
#   'Bartholomew;',
#   'Thomas;',
#   'Simon',
#   'stood',
#   'Jerusalem,',
#   'from',
#   'Sidon,',
#   'to',
#   'unclean\r\nspirits.',
#   'healed',
#   'said,',
#   'denounce',
#   'leap',
#   'weep.',
#   'treat\r\nyou',
#   'lend,',
#   'to',
#   'ye',
#   'ye',
#   'ye',
#   'it',
#   'running\r\nover',
#   'only',
#   'a',
#   'not',
#   'does',
#   'does',
#   'the',
#   'ready',
#   'heal',
#   'had',
#   'my',
#   'he',
#   'to',
#   'he',
#   'he',
#   'said',
#   'many\r\npeople',
#   'said',
#   'touched\r\nthe',
#   'began',
#   'Jesus\r\ndelivered',
#   'they\r\nglorified',
#   'all',
#   'of',
#   'to',
#   'tell',
#   'heard;',
#   'to',
#   'live',
#   'much\r\nmore',
#   'were',
#   'ye',
#   'ye',
#   'ye',
#   'ye',
#   'a',
#   'sinners!',
#   'sat',
#   'stood',
#   'began',
#   'wipe',
#   'anointed',
#   'what',
#   'said,\r\nSimon,',
#   'the',
#   'said,',
#   'said',
#   'wiped',
#   'village,\r\npreaching',
#   'showing',
#   'the\r\ntwelve',
#   'out',
#   'Joanna,\r\nthe',
#   'Susanna;',
#   'many',
#   'ministered',
#   'the',
#   'choked',
#   'bore',
#   'takes',
#   'be',
#   'riches',
#   'pleasures\r\nof',
#   'they',
#   'good',
#   'bring',
#   'nothing',
#   'come',
#   'whoever',
#   'His',
#   'my',
#   'do',
#   'they',
#   'woke',
#   'said,',
#   'the',
#   'there',
#   'water',
#   'they',
#   'had',
#   'in',
#   'was',
#   'fell',
#   'entered',
#   'were',
#   'found',
#   'in',
#   'show',
#   'told',
#   'the',
#   'besought\r\nHim',
#   'who',
#   'touched',
#   'those',
#   'you',
#   'how',
#   'the',
#   'the',
#   'said,',
#   'she',
#   'gave',
#   'authority',
#   'to',
#   'to',
#   'depart',
#   'went',
#   'healing',
#   'some\r\nsaid',
#   'went',
#   'followed',
#   'healed',
#   'said',
#   'country',
#   'get',
#   'two',
#   'buy',
#   'two',
#   'gave',
#   'were',
#   'others',
#   'be',
#   'scribes;',
#   'be',
#   'be',
#   'follow',
#   'lose\r\nhimself,',
#   'of',
#   'in',
#   'of',
#   'James\r\nand',
#   'glistering.',
#   'Elias,',
#   'those',
#   'the',
#   'one',
#   'one',
#   'they',
#   'told',
#   'bruises',
#   'hardly',
#   'perverse',
#   'suffer',
#   'tore',
#   'delivered',
#   'they\r\nfeared',
#   'set',
#   'they',
#   'John,',
#   'consume\r\nthem',
#   'rebuked',
#   'birds',
#   'bury',
#   'looking',
#   'salute',
#   'drinking\r\nsuch',
#   'say',
#   'say,',
#   'Sidon,',
#   'ashes.',
#   'Sidon',
#   'he',
#   'scorpions,',
#   'all',
#   'said,',
#   'earth,',
#   'prudent,',
#   'revealed',
#   'who',
#   'He',
#   'said',
#   'kings',
#   'have',
#   'to',
#   'have',
#   'tested',
#   'with',
#   'with',
#   'with',
#   'thy',
#   'you',
#   'fell',
#   'left',
#   'looked',
#   'wine,',
#   'set\r\nhim',
#   'took',
#   'said,',
#   'do',
#   'troubled',
#   'Mary',
#   'go',
#   'say,',
#   'I',
#   'my',
#   'I',
#   'give',
#   'because',
#   'give',
#   'it',
#   'you',
#   'to',
#   'the',
#   'wanted',
#   'a',
#   'his',
#   'one\r\nwho',
#   'garnished.',
#   'gathers',
#   'dwell',
#   'the',
#   'the',
#   'keep',
#   'shall',
#   'the',
#   'wickedness.',
#   'rue',
#   'all',
#   'ignore',
#   'the',
#   'Pharisees,\r\nhypocrites!',
#   'do\r\nnot',
#   'you',
#   'your',
#   'you',
#   'apostles.',
#   'persecute',
#   'the',
#   'the',
#   'provoke',
#   'trying',
#   'taught',
#   'that',
#   'not',
#   'before',
#   'beware',
#   'said,',
#   'build',
#   'there',
#   'all',
#   'be',
#   'is',
#   'the',
#   'how',
#   'tomorrow',
#   'all',
#   'give',
#   'your',
#   'knocks,',
#   'waiting.',
#   'not',
#   'so\r\nbegins',
#   'maidens,',
#   'to',
#   'drink',
#   'at',
#   'appoint',
#   'committed',
#   'I',
#   'am',
#   'two',
#   'the',
#   'the',
#   'the',
#   'so',
#   'it',
#   'of',
#   'the\r\njudge',
#   'the',
#   'killed;',
#   'found',
#   'found',
#   'fertilize',
#   'could',
#   'said,\r\nWoman,',
#   'glorified',
#   'be',
#   'the',
#   'turned',
#   'taught',
#   'asked,\r\nLord,',
#   'replied,',
#   'shall',
#   'drunk',
#   'thou\r\nhas',
#   'gnashing',
#   'Isaac,',
#   'all',
#   'you',
#   'the',
#   'the',
#   'tell',
#   'I',
#   'tomorrow,',
#   'the',
#   'tomorrow',
#   'the',
#   'stones',
#   'ye',
#   'Pharisees,',
#   'then',
#   'will',
#   'tell',
#   'he',
#   'you',
#   'invited',
#   'I',
#   'I',
#   'cannot',
#   'reported',
#   'said,',
#   'the\r\nblind',
#   'bring',
#   'said,',
#   'compel',
#   'said',
#   'does',
#   'mother,',
#   'wife,',
#   'children,',
#   'brethren,\r\nand',
#   'his',
#   'come',
#   'are',
#   'say,',
#   'consult',
#   'scribes\r\nmurmured,',
#   'even',
#   'nine',
#   'search\r\nfor',
#   'neighbors',
#   'nine',
#   'seek',
#   'her\r\nneighbors',
#   'the',
#   'had',
#   'to',
#   'I',
#   'go',
#   'will',
#   'before',
#   'went',
#   'had',
#   'fell',
#   'in',
#   'am',
#   'put\r\nit',
#   'shoes',
#   'be',
#   'is',
#   'is',
#   'dancing.',
#   'asked',
#   'thy',
#   'sound.',
#   'would',
#   'all',
#   'be',
#   'is',
#   'now\r\nis',
#   'quickly',
#   'quickly',
#   'do',
#   'you',
#   'love',
#   'despise',
#   'derided\r\nHim.',
#   'the',
#   'every',
#   'earth',
#   'marries',
#   'fine',
#   'often',
#   'saw',
#   'cool',
#   'Lazarus',
#   'you',
#   'the',
#   'the',
#   'he',
#   'seven',
#   'it',
#   'sit',
#   'change',
#   'serve',
#   'drink.',
#   'Galilee.',
#   'go',
#   'lights',
#   'be',
#   'drank,',
#   'were',
#   'destroyed',
#   'drank,',
#   'built.',
#   'brimstone',
#   'destroyed',
#   'his',
#   'whoever',
#   'the',
#   'the',
#   'her',
#   'night',
#   'the',
#   'prayed,\r\nGod,',
#   'I',
#   'he',
#   'said,',
#   'thy',
#   'give\r\nto',
#   'follow\r\nme.',
#   'followed',
#   'in',
#   'said',
#   'shall',
#   'spitefully\r\ntreated,',
#   'spit',
#   'put',
#   'commanded',
#   'could',
#   'climbed',
#   'said,\r\nZacchaeus,',
#   'come',
#   'received',
#   'said',
#   'many',
#   'to',
#   'called',
#   'reap',
#   'reaping',
#   'say',
#   'Bethany',
#   'said,',
#   'bring',
#   'found',
#   'set\r\nJesus',
#   'praise',
#   'wept',
#   'compass',
#   'keep',
#   'thy',
#   'began',
#   'scribes',
#   'said',
#   'he',
#   'sent',
#   'treated',
#   'sent',
#   'cast',
#   'destroy',
#   'shall',
#   'said,',
#   'the',
#   'they',
#   'teach',
#   'said,',
#   'superscription',
#   "said,\r\nCaesar's.",
#   'to',
#   'had',
#   'died',
#   'left',
#   'are',
#   'the\r\nresurrection',
#   'are',
#   'the',
#   'love',
#   'the',
#   'the',
#   'how',
#   'beautiful',
#   'commotions,',
#   'kingdom',
#   'pestilence',
#   'great',
#   'persecute\r\nyou.',
#   'into',
#   'rulers',
#   'wisdom',
#   'friends;\r\nsome',
#   'when',
#   'let',
#   'do',
#   'wrath',
#   'shall',
#   'in',
#   'the',
#   'from',
#   'lift',
#   'all',
#   'earth',
#   'drunkenness,',
#   'cares',
#   'that',
#   'you',
#   'unprepared.',
#   'to',
#   'abode',
#   'scribes',
#   'said',
#   'agreed',
#   'then\r\nsought',
#   'John,',
#   'prepare',
#   'found',
#   'said,\r\nTake',
#   'divide',
#   'gave',
#   'broke',
#   'gave',
#   'he',
#   'sit',
#   'to',
#   'scrip,',
#   'likewise,',
#   'buy',
#   'His',
#   'knelt',
#   'His',
#   'pray',
#   'he',
#   'drew',
#   'cut',
#   'healed',
#   'captains',
#   'the',
#   'led',
#   'warmed',
#   'said,',
#   'said,',
#   'looked',
#   'wept',
#   'smote',
#   'when',
#   'said,',
#   'the',
#   'scribes\r\ncame',
#   'led',
#   'the',
#   'scribes',
#   'his',
#   'mocked',
#   'Herod,',
#   'the',
#   'release',
#   'let\r\nHim',
#   'with',
#   'Pilate',
#   'murder,',
#   'turned',
#   'lamenting.',
#   'your',
#   'the',
#   'the\r\nbreasts',
#   'to',
#   'the\r\ntwo',
#   'the',
#   'offering',
#   'Hebrew:',
#   'the',
#   'He',
#   'watched',
#   'good',
#   'was',
#   'laid',
#   'the',
#   'how',
#   'prepared',
#   'certain\r\nothers',
#   'they',
#   'the',
#   'told',
#   'to',
#   'other',
#   'they\r\ndid',
#   'ran',
#   'he',
#   'walked\r\nwith',
#   'do',
#   'all',
#   'how',
#   'crucified',
#   'said',
#   'found',
#   'slow',
#   'not',
#   'all',
#   'He',
#   'the',
#   'broke',
#   'gave',
#   'they',
#   'He',
#   'while',
#   'returned',
#   'those',
#   'said,',
#   'supposed',
#   'my',
#   'see',
#   'bones',
#   'His',
#   'a',
#   'ate',
#   'in',
#   'rise',
#   'that',
#   'He\r\nlifted',
#   'blessed',
#   'taken',
#   'returned',
#   'blessing'],
#  'ministers': ['of'],
#  'the': ['word',
#   'very',
#   'things',
#   'days',
#   'king',
#   'course',
#   'daughters',
#   'commandments',
#   'custom',
#   "priest's",
#   'Lord.',
#   'Lord',
#   'right',
#   'altar',
#   'angel',
#   'sight',
#   'Lord.\r\nHe',
#   'children',
#   'Lord,',
#   'spirit',
#   'hearts',
#   'children,',
#   'disobedient',
#   'wisdom',
#   'Lord.',
#   'angel,',
#   'presence',
#   'day',
#   'temple.',
#   'temple',
#   'days',
#   'Lord',
#   'sixth',
#   'angel',
#   'house',
#   'angel',
#   'Highest.',
#   'throne',
#   'house',
#   'angel,',
#   'power\r\nof',
#   'Highest',
#   'holiness',
#   'Son',
#   'sixth',
#   'handmaid',
#   'Lord.',
#   'angel',
#   'hill',
#   'house',
#   'babe',
#   'Holy',
#   'fruit',
#   'mother',
#   'voice',
#   'babe\r\nleaped',
#   'Lord,',
#   'low',
#   'proud',
#   'mighty',
#   'hungry\r\nwith',
#   'rich',
#   'Lord',
#   'eighth',
#   'child.',
#   'name',
#   'hill',
#   'hand',
#   'Lord',
#   'Holy',
#   'Lord,',
#   'house\r\nof',
#   'mouth',
#   'world',
#   'hand',
#   'hand',
#   'days',
#   'prophet',
#   'Highest,',
#   'face',
#   'Lord',
#   'remission',
#   'tender',
#   'dayspring',
#   'way',
#   'desert',
#   'house',
#   'city',
#   'time',
#   'inn.',
#   'same',
#   'field',
#   'angel',
#   'Lord',
#   'Lord',
#   'angel\r\nsaid',
#   'Lord,',
#   'city',
#   'babe',
#   'highest',
#   'Lord',
#   'babe',
#   'things',
#   'circumcising',
#   'child,',
#   'angel',
#   'womb.',
#   'days',
#   'purification',
#   'Lord,',
#   'law:',
#   'womb',
#   'Lord.',
#   'Lord,',
#   'sacrifice:',
#   'consolation',
#   "Lord's",
#   'Spirit',
#   'temple.',
#   'parents',
#   'Gentiles,',
#   'glory',
#   'things',
#   'fall',
#   'daughter',
#   'tribe',
#   'temple',
#   'Lord,',
#   'law',
#   'feast',
#   'passover.\r\nWhen',
#   'feast.',
#   'days,',
#   'child',
#   'caravan,',
#   'first',
#   'temple.',
#   'doctors,',
#   'fifteenth',
#   'reign',
#   'region',
#   'high',
#   'son',
#   'country',
#   'remission',
#   'book',
#   'prophet:',
#   'wilderness,',
#   'way',
#   'Lord,',
#   'crooked',
#   'salvation\r\nof',
#   'multitude',
#   'wrath',
#   'axe',
#   'root',
#   'trees.',
#   'fire.',
#   'Christ.\r\nJohn',
#   'latchet',
#   'Holy',
#   'wheat',
#   'chaff',
#   'tetrarch,',
#   'evils',
#   'heaven',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son\r\nof',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'son',
#   'Holy',
#   'Spirit',
#   'wilderness.',
#   'devil.',
#   'Son',
#   'world',
#   'power',
#   'Lord',
#   'Son',
#   'Lord',
#   'devil',
#   'temptation,',
#   'power',
#   'Spirit.',
#   'region.',
#   'synagogues',
#   'synagogue',
#   'sabbath',
#   'book',
#   'prophet',
#   'place',
#   'Lord\r\nis',
#   'gospel',
#   'brokenhearted,',
#   'captives,',
#   'blind,',
#   'acceptable',
#   'Lord.',
#   'book,',
#   'synagogue',
#   'gracious',
#   'days',
#   'heaven\r\nwas',
#   'land;',
#   'time',
#   'prophet;',
#   'Syrian.',
#   'synagogue',
#   'city.',
#   'top',
#   'hill',
#   'midst',
#   'sabbath\r\ndays.',
#   'synagogue',
#   'Holy',
#   'midst,',
#   'unclean',
#   'synagogue',
#   'fever,',
#   'sun',
#   'Son',
#   'kingdom\r\nof',
#   'synagogues',
#   'people',
#   'word',
#   'lake',
#   'ships,',
#   'land.',
#   'ship.',
#   'deep\r\nand',
#   'net.',
#   'sons',
#   'great',
#   'leprosy',
#   'priest.',
#   'wilderness',
#   'power',
#   'Lord',
#   'law\r\n\r\nsat',
#   'multitude,',
#   'housetop',
#   'tiling\r\nand',
#   'midst',
#   'Pharisees',
#   'Son',
#   'sick',
#   'receipt',
#   'righteous,',
#   'disciples',
#   'disciples',
#   'Pharisees;',
#   'children\r\nof',
#   'bridechamber',
#   'bridegroom',
#   'bridegroom',
#   'new',
#   'piece',
#   'new',
#   'old.',
#   'new',
#   'bottles,',
#   'bottles',
#   'second',
#   'first,\r\nJesus',
#   'Pharisees\r\nsaid',
#   'sabbath\r\ndays?',
#   'house',
#   'showbread',
#   'priests?\r\nJesus',
#   'sabbath.',
#   'synagogue',
#   'sabbath',
#   'man',
#   'withered\r\nhand,',
#   'midst.',
#   'sabbath',
#   'man,',
#   'man',
#   'son',
#   'brother',
#   'traitor.\n',
#   'company',
#   'sea',
#   'kingdom',
#   'prophets',
#   'same',
#   'ancestors',
#   'false',
#   'same',
#   'one',
#   'same',
#   'children',
#   'unthankful',
#   'evil.',
#   'same',
#   'blind',
#   'blind?',
#   'ditch?',
#   'mote',
#   'mote',
#   'beam',
#   'beam',
#   'mote',
#   'good',
#   'evil',
#   'abundance',
#   'heart,',
#   'mouth\r\nspeaks.',
#   'things',
#   'flood',
#   'stream',
#   'things',
#   'earth',
#   'stream',
#   'ruin',
#   'centurion',
#   'elders',
#   'Jews',
#   "centurion's\r\nbehalf",
#   'nation',
#   'house,',
#   'centurion\r\nreturned',
#   'house',
#   'servant',
#   'gate',
#   'city,',
#   'only',
#   'city',
#   'Lord',
#   'surrounding',
#   'disciples',
#   'same',
#   'blind',
#   'lame',
#   'deaf',
#   'dead',
#   'gospel',
#   'people',
#   'wind?',
#   'Baptist,',
#   'kingdom',
#   'people',
#   'publicans,\r\nwho',
#   'baptism',
#   'Pharisees',
#   'counsel',
#   'Baptist',
#   'Pharisees',
#   'city,',
#   "Pharisee's",
#   'ointment.',
#   'Pharisee',
#   'other',
#   'woman,',
#   'hair',
#   'same',
#   'woman,',
#   'glad',
#   'kingdom',
#   'fowls',
#   'air',
#   'seed',
#   'seed',
#   'mysteries',
#   'kingdom',
#   'parable',
#   'word',
#   'devil',
#   'word\r\nout',
#   'word',
#   'light.',
#   'press',
#   'multitude.',
#   'word\r\nof',
#   'other',
#   'lake.',
#   'wind',
#   'raging',
#   'winds',
#   'country',
#   'Gadarenes,',
#   'city,',
#   'bands,',
#   'devil',
#   'wilderness.',
#   'unclean',
#   'man.',
#   'nearby\r\ndeep',
#   'mountain.',
#   'swine.',
#   'man',
#   'swine',
#   'herd',
#   'lake',
#   'city',
#   'man',
#   'devils',
#   'feet',
#   'man',
#   'devils',
#   'whole',
#   'country\r\naround',
#   'Gadarenes',
#   'boat.',
#   'great',
#   'whole',
#   'great',
#   'people',
#   'synagogue.',
#   'people',
#   'border',
#   'multitude',
#   'woman',
#   'people',
#   'ruler',
#   'house,',
#   'father',
#   'mother',
#   'maiden.',
#   'hand,',
#   'kingdom',
#   'sick.',
#   'very',
#   'gospel',
#   'tetrarch,',
#   'Baptist',
#   'dead;',
#   'prophets',
#   'apostles',
#   'kingdom',
#   'day',
#   'twelve',
#   'towns',
#   'five',
#   'disciples',
#   'multitude.',
#   'people',
#   'Baptist;',
#   'whole',
#   'Son',
#   'holy',
#   'kingdom',
#   'two',
#   'cloud,',
#   'voice',
#   'hill,',
#   'group',
#   'boy',
#   'unclean\r\nspirit.',
#   'child',
#   'mighty',
#   'hands',
#   'saying.',
#   'thought',
#   'child',
#   'time',
#   'Samaritans',
#   'air',
#   'man',
#   'dead',
#   'kingdom',
#   'plough,',
#   'kingdom',
#   'Lord',
#   'places',
#   'laborers',
#   'master',
#   'same',
#   'laborer',
#   'sick',
#   'streets',
#   'same,',
#   'very',
#   'kingdom',
#   'mighty',
#   'judgment',
#   'devils',
#   'enemy.',
#   'spirits',
#   'Son\r\nis,',
#   'Father;',
#   'Father',
#   'Son,',
#   'things',
#   'Lord\r\nthy',
#   'lawyer',
#   'other',
#   'other',
#   'next',
#   'man',
#   'thieves?',
#   'serving',
#   'meal.',
#   'one',
#   'Holy',
#   'devil',
#   'man',
#   'chief',
#   'devils.',
#   'finger',
#   'kingdom',
#   'stronger',
#   'armor',
#   'unclean',
#   'house',
#   'last\r\nstate',
#   'first.',
#   'crowd',
#   'womb',
#   'paps',
#   'word',
#   'sign\r\nof',
#   'prophet.',
#   'Ninevites,',
#   'Son',
#   'south',
#   'utmost\r\nparts',
#   'earth',
#   'wisdom',
#   'preaching',
#   'body',
#   'eye.',
#   'light',
#   'whole\r\nshall',
#   'bright',
#   'light.',
#   'meal.',
#   'outside',
#   'cup',
#   'platter',
#   'outside,',
#   'love',
#   'others',
#   'best',
#   'synagogues,',
#   'markets.',
#   'lawyers',
#   'prophets',
#   'deeds',
#   'blood',
#   'foundation',
#   'world,',
#   'blood',
#   'altar',
#   'temple',
#   'key',
#   'scribes',
#   'Pharisees\r\nbegan',
#   'leaven',
#   'Pharisees,',
#   'light;',
#   'housetops.',
#   'body',
#   'one',
#   'very',
#   'Son',
#   'angels',
#   'angels',
#   'Son',
#   'Holy',
#   'synagogues,',
#   'spot.',
#   'group',
#   'abundance',
#   'body,',
#   'body',
#   'ravens.',
#   'fowls',
#   'rest?',
#   'lilies',
#   'grass,',
#   'oven;',
#   'nations',
#   'world',
#   'kingdom.',
#   'heavens',
#   'wedding',
#   'lord',
#   'good',
#   'house',
#   'Son',
#   'portions',
#   'menservants',
#   'lord',
#   'servant\r\ndoes',
#   'unbelievers.\r\nThat',
#   'earth',
#   'son,',
#   'son',
#   'father;',
#   'mother',
#   'daughter',
#   'mother;',
#   'mother',
#   'daughter',
#   'people,',
#   'south\r\nwind',
#   'face',
#   'sky',
#   'earth;',
#   'way',
#   'judge,',
#   'officer,',
#   'officer',
#   'Galilaeans',
#   'eighteen',
#   'dresser\r\nof',
#   'synagogues',
#   'sabbath.',
#   'synagogue,',
#   'sabbath',
#   'people,',
#   'sabbath',
#   'ruler',
#   'synagogue,',
#   'sabbath',
#   'stall,\r\nand',
#   'sabbath',
#   'rest',
#   'people',
#   'glorious\r\nthings',
#   'the',
#   'Kingdom',
#   'fowls',
#   'air',
#   'whole\r\nbatch',
#   'way.',
#   'strait',
#   'master',
#   'house',
#   'door',
#   'door,',
#   'door\r\nto',
#   'prophets',
#   'kingdom',
#   'east,',
#   'west,',
#   'north,',
#   'south,',
#   'kingdom',
#   'last',
#   'first',
#   'Pharisees',
#   'third',
#   'day\r\nfollowing',
#   'prophets,',
#   'time',
#   'name',
#   'Lord.',
#   'house',
#   'sabbath',
#   'sabbath',
#   'afflicted',
#   'sabbath',
#   'highest',
#   'room',
#   'lowest',
#   'lowest',
#   'host',
#   'respect',
#   'poor,',
#   'maimed,',
#   'blind.',
#   'resurrection',
#   'just.',
#   'table',
#   'kingdom',
#   'house',
#   'streets',
#   'city.',
#   'poor,',
#   'maimed,',
#   'halt,',
#   'cost,',
#   'foundation,',
#   'other\r\nis',
#   'salt',
#   'land,',
#   'Pharisees',
#   'ninety',
#   'wilderness,',
#   'one',
#   'house,',
#   'piece\r\nthat',
#   'presence',
#   'portion',
#   'younger',
#   'husks',
#   'swine\r\nate',
#   'father',
#   'best',
#   'field.',
#   'house,',
#   'servants',
#   'fatted',
#   'rich',
#   'steward.',
#   'steward',
#   'rich',
#   'unjust',
#   'children',
#   'least,',
#   'true',
#   'one,',
#   'other;',
#   'one,',
#   'other.',
#   'sight',
#   'prophets',
#   'law\r\nto',
#   'dogs',
#   'crumbs',
#   'poor',
#   'angels',
#   'tip',
#   'evil',
#   'rich',
#   'prophets.',
#   'dead',
#   'prophets,',
#   'dead.',
#   'disciples,',
#   'apostles\r\nsaid',
#   'Lord,',
#   'root',
#   'sea;',
#   'servant',
#   'things',
#   'middle',
#   'priests.',
#   'ten,',
#   'only',
#   'Pharisees',
#   'kingdom',
#   'kingdom',
#   'disciples,',
#   'days',
#   'Son',
#   'heavens',
#   'Son',
#   'days',
#   'days\r\nof',
#   'Son',
#   'day',
#   'ark',
#   'flood\r\ncame',
#   'same',
#   'days',
#   'same',
#   'day',
#   'Son',
#   'housetop,',
#   'house',
#   'field\r\nshould',
#   'other',
#   'other',
#   'field;',
#   'other',
#   'body',
#   'vultures',
#   'judge',
#   'unjust',
#   'Son',
#   'temple',
#   'other',
#   'first',
#   'disciples',
#   'large',
#   'little',
#   'kingdom',
#   'kingdom',
#   'commandments.',
#   'poor.',
#   'kingdom',
#   'kingdom',
#   'twelve',
#   'Son',
#   'Gentiles,',
#   'third',
#   'wayside.',
#   'blind',
#   'man,',
#   'publicans.',
#   'town,',
#   'press',
#   'crowd.',
#   'place,',
#   'tree',
#   'half',
#   'poor.',
#   'people',
#   'kingdom',
#   'citizens',
#   'kingdom,',
#   'servants',
#   'talents.',
#   'talents',
#   'bank,',
#   'servant',
#   'little',
#   'Lord',
#   'colt,',
#   'owners',
#   'colt?',
#   'colt,',
#   'way.\r\nWhen',
#   'descent',
#   'mount',
#   'whole\r\nmultitude',
#   'disciples',
#   'mighty',
#   'King',
#   'name',
#   'Lord.',
#   'highest.',
#   'Pharisees',
#   'multitude',
#   'stones',
#   'city,',
#   'things',
#   'days\r\nshall',
#   'ground,',
#   'time',
#   'temple',
#   'house\r\nof',
#   'temple.',
#   'chief',
#   'people',
#   'people',
#   'people',
#   'temple',
#   'gospel,',
#   'chief',
#   'baptism',
#   'people',
#   'season',
#   'fruit',
#   'vineyard,',
#   'husbandmen\r\nbeat',
#   'lord',
#   'vineyard',
#   'heir.',
#   'vineyard',
#   'lord',
#   'vineyard',
#   'vineyard',
#   'people',
#   'builders',
#   'cornerstone?',
#   'scribes',
#   'people',
#   'power',
#   'governor.',
#   'way',
#   'things\r\nthat',
#   'things',
#   'Sadducees,',
#   'resurrection,',
#   'woman',
#   'resurrection,',
#   'seven\r\nhad',
#   'dead,',
#   'angels;',
#   'children',
#   'resurrection.',
#   'bush,',
#   'Lord',
#   'God',
#   'God',
#   'God',
#   'living.',
#   'scribes',
#   'book',
#   'multitude,',
#   'highest',
#   'synagogues,',
#   'chief',
#   'rich',
#   'rest\r\nput',
#   'living',
#   'temple',
#   'days',
#   'end',
#   'synagogues,',
#   'words',
#   'desolation',
#   'mountains;',
#   'midst',
#   'country\r\nenter',
#   'days',
#   'land',
#   'people.\r\n\r\nThey',
#   'sword,',
#   'time',
#   'sun,',
#   'moon,',
#   'stars.',
#   'waves',
#   'earth,',
#   'powers',
#   'Son',
#   'fig',
#   'kingdom',
#   'face',
#   'earth.',
#   'Son',
#   'day',
#   'temple.',
#   'mount',
#   'mount',
#   'morning',
#   'Passover,\r\nwas',
#   'people.',
#   'twelve.',
#   'chief',
#   'day',
#   'passover',
#   'passover\r\nthat',
#   'city,',
#   'house',
#   'house,',
#   'passover',
#   'passover.',
#   'hour',
#   'twelve',
#   'fruit',
#   'vine',
#   'kingdom',
#   'new',
#   'hand',
#   'table.\r\nThe',
#   'greatest.',
#   'Gentiles',
#   'younger;',
#   'table',
#   'table?',
#   'ones',
#   'twelve\r\ntribes',
#   'cock\r\nshall',
#   'transgressors.',
#   'mount',
#   'ground.',
#   'twelve,',
#   'Son',
#   'disciples',
#   'sword?',
#   'high',
#   "servant's",
#   'chief',
#   ...],
#  'word': ['have\r\nset',
#   'of',
#   'of',
#   'was',
#   'of',
#   'of',
#   'with',
#   'of',
#   'before'],
#  'have\r\nset': ['forth'],
#  'forth': ['and',
#   'a',
#   'a',
#   'her\r\nfirstborn',
#   'fruits',
#   'good\r\nfruit',
#   'and',
#   'in',
#   'corrupt',
#   'good',
#   'that\r\nwhich',
#   'throughout',
#   'fruit',
#   'more',
#   'as',
#   'your'],
#  'delivered': ['to',
#   'out',
#   'him',
#   'into',
#   'to',
#   'from',
#   'over',
#   'into',
#   'Him'],
#  'to': ['us',
#   'me',
#   'you,',
#   'the',
#   'burn',
#   'pray',
#   'him',
#   'him,',
#   'the',
#   'turn',
#   'the',
#   'the',
#   'make',
#   'the',
#   'him,',
#   'speak',
#   'thee,',
#   'them.',
#   'pass,',
#   'a',
#   'a',
#   'Joseph,',
#   'her,',
#   'her,',
#   'the',
#   'a',
#   'me?',
#   'me.',
#   'generation.',
#   'our\r\nfathers,',
#   'Abraham,',
#   'His',
#   'her',
#   'circumcise',
#   'her,',
#   'his\r\nfather',
#   'perform',
#   'our',
#   'remember',
#   'our',
#   'serve',
#   'prepare',
#   'give\r\nknowledge',
#   'His',
#   'give',
#   'those',
#   'guide',
#   'Israel.',
#   'the\r\ndecree',
#   'go',
#   'his',
#   'be',
#   'the',
#   'be',
#   'be',
#   'them,',
#   'all',
#   'God',
#   'Bethlehem',
#   'us.',
#   'them.',
#   'Jerusalem',
#   'the',
#   'the',
#   'him',
#   'thy',
#   'lighten',
#   'His',
#   'the',
#   'the',
#   'their',
#   'Jerusalem',
#   'Jerusalem',
#   'have',
#   'find',
#   'them',
#   'Him,\r\nSon,',
#   'us?',
#   'them.',
#   'Nazareth',
#   'John',
#   'the',
#   'be',
#   'flee',
#   'Abraham',
#   'him',
#   'him',
#   'be',
#   'them,',
#   'no',
#   'them',
#   'him,',
#   'Him,\r\nI',
#   'him,',
#   'Jerusalem,',
#   'Galilee',
#   'Nazareth,',
#   'preach',
#   'the\r\npoor;',
#   'heal',
#   'preach',
#   'the',
#   'set',
#   'preach',
#   'them,',
#   'me',
#   'none',
#   'a',
#   'the',
#   'Capernaum',
#   'do\r\nwith',
#   'destroy',
#   'help',
#   'them.',
#   'Him.',
#   'prevent',
#   'them,',
#   'other',
#   'hear',
#   'Simon,',
#   'Him,',
#   'their',
#   'come',
#   'sink.',
#   'pass,',
#   'tell',
#   'the',
#   'them.',
#   'hear',
#   'pray.',
#   'heal',
#   'bring',
#   'bring',
#   'question,',
#   'them,',
#   'say,',
#   'forgive',
#   'the',
#   'your',
#   'his',
#   'him,',
#   'them,',
#   'call',
#   'call\r\nsinners',
#   'repentance.',
#   'Him,',
#   'them,',
#   'them.',
#   'pass',
#   'eat,',
#   'them,',
#   'eat,',
#   'those',
#   'eat',
#   'them,',
#   'pass',
#   'the',
#   'them,',
#   'do',
#   'do',
#   'the',
#   'pass',
#   'pray.\r\n\r\nHe',
#   'God.',
#   'hear',
#   'be',
#   'touch',
#   'His',
#   'you',
#   'you',
#   'you\r\nwho',
#   'you,',
#   'you',
#   'those',
#   'everyone',
#   'others',
#   'you.',
#   'those',
#   'those',
#   'receive',
#   'sinners',
#   'receive',
#   'the',
#   'the',
#   'you;',
#   'you',
#   'them,',
#   'your',
#   'pull',
#   'me,',
#   'him,',
#   'die.',
#   'Him,',
#   'Jesus',
#   'say,',
#   'come',
#   'thee.',
#   'one,',
#   'another,\r\nCome,',
#   'my',
#   'the\r\npeople',
#   'Jesus',
#   'the',
#   'a',
#   'her,',
#   'thee,',
#   'speak',
#   'his',
#   'Jesus',
#   'ask,',
#   'many',
#   "John's",
#   'the\r\npoor',
#   'see?',
#   'see?',
#   'you,',
#   'another,',
#   'you,',
#   'eat',
#   'wash',
#   'himself,',
#   'say',
#   'thee.',
#   'pay,',
#   'the',
#   'Simon,',
#   'kiss',
#   'thee,',
#   'whom',
#   'her,',
#   'wonder,',
#   'Him.',
#   'sow',
#   'hear,',
#   'know',
#   'perfection.',
#   'him\r\nmore',
#   'have.',
#   'Him,',
#   'see',
#   'all\r\nthose',
#   'pass.',
#   'the',
#   'them,',
#   'come',
#   'do',
#   'command',
#   'go',
#   'let',
#   'see',
#   'leave.',
#   'the',
#   'go',
#   'pass',
#   'come',
#   'his',
#   'heal',
#   'Him',
#   'the',
#   'go',
#   'scorn,',
#   'cure',
#   'heal',
#   'see',
#   'the\r\ncity',
#   'them',
#   'wear',
#   'Him,',
#   'them,',
#   'eat.',
#   'His',
#   'heaven,',
#   'the',
#   'set\r\nbefore',
#   'pass,',
#   'them,',
#   'tell',
#   'pray.',
#   'say,',
#   'Jesus,\r\nMaster,',
#   'be',
#   'cast',
#   'his',
#   'His\r\ndisciples,',
#   'Him.',
#   'him,\r\nForbid',
#   'pass,',
#   'make',
#   'come',
#   "destroy\r\nmen's",
#   'save',
#   'another',
#   'lay',
#   'go',
#   'him,',
#   'those',
#   'the',
#   'go',
#   'the',
#   'them,',
#   'this',
#   'you.',
#   'house.',
#   'them,\r\nThe',
#   'us,',
#   'you.',
#   'you,',
#   'thee,',
#   'thee,',
#   'heaven,',
#   'hell.',
#   'us',
#   'them,',
#   'tread',
#   'babes',
#   'me',
#   'whom\r\nthe',
#   'His',
#   'see',
#   'hear\r\nthe',
#   'him,',
#   'him,',
#   'justify',
#   'Jericho',
#   'the',
#   'him.',
#   'an',
#   'the',
#   'him,',
#   'a',
#   'Jesus\r\nand',
#   'serve\r\nalone?',
#   'help',
#   'her,',
#   'pray',
#   'them,',
#   'us.',
#   'them,',
#   'him',
#   'me,',
#   'feed',
#   'you.',
#   'the',
#   'give',
#   'your',
#   'those\r\nwho',
#   'pass,',
#   'speak.',
#   'produce',
#   'destruction;',
#   'the',
#   'Him,',
#   'say,',
#   'them,',
#   'the',
#   'hear',
#   'dinner',
#   'him,',
#   'you.',
#   'you,',
#   'you,',
#   'you,',
#   'you',
#   'you!',
#   'the',
#   'the',
#   'you,',
#   'them,',
#   'urge',
#   'speak',
#   'catch',
#   'fear.',
#   'cast',
#   'the',
#   'say',
#   'divide',
#   'them.',
#   'store',
#   'my',
#   'last\r\nmany',
#   'take',
#   'him,',
#   'whom',
#   'His',
#   'his',
#   'do',
#   'you,',
#   'you.',
#   'give\r\nyou',
#   'return',
#   'welcome',
#   'be',
#   'Him,',
#   'all?',
#   'beat',
#   'eat',
#   'his',
#   'set',
#   'be',
#   'give',
#   'the',
#   'be',
#   'pass.',
#   'court,',
#   'the',
#   'the',
#   'them,',
#   'get',
#   'the',
#   'him,',
#   'Him,',
#   'the',
#   'work.',
#   'the',
#   'be',
#   'enter',
#   'enter',
#   'Him,',
#   'thee;',
#   'you,\r\nYe',
#   'pass,',
#   'eat',
#   'heal',
#   'a',
#   'come',
#   'the',
#   'you\r\nand',
#   'his',
#   'say',
#   'those',
#   'see\r\nit.',
#   'claim',
#   'his',
#   'come',
#   'you,',
#   'them,',
#   'me,',
#   'build',
#   'see',
#   'finish',
#   'finish\r\nit,',
#   'mock',
#   'finish.',
#   'meet',
#   'discuss',
#   'hear,',
#   'his',
#   'you,',
#   'you,',
#   'his\r\nfather,',
#   'be',
#   'eat.',
#   'his',
#   'spare,',
#   'my',
#   'him,',
#   'be\r\ncalled',
#   'his',
#   'him,',
#   'be',
#   'his',
#   'celebrate.',
#   'his',
#   'him,',
#   'celebrate',
#   'himself,',
#   'do',
#   'my',
#   'another,',
#   'commend',
#   'your\r\ntrust',
#   'another,',
#   'the',
#   'them,',
#   'pass',
#   'dip',
#   "my\r\nfather's",
#   'them',
#   'them\r\nfrom',
#   'him,',
#   'the',
#   'him,',
#   'have',
#   'the',
#   'this',
#   'eat?',
#   'him,\r\nWash',
#   'do?',
#   'do.',
#   'pass,',
#   'the',
#   'return',
#   'God',
#   'him,',
#   'know',
#   'the',
#   'you,',
#   'another;',
#   'save',
#   'them,',
#   'him\r\nand',
#   'himself,',
#   'me',
#   'Him,',
#   'those',
#   'pray.',
#   'me',
#   'Jesus',
#   'Him',
#   'me.',
#   'inherit\r\neternal',
#   'him,',
#   'him,',
#   'enter',
#   'go',
#   'enter',
#   'them,\r\nVerily',
#   'you,',
#   'them,',
#   'Jerusalem',
#   'the',
#   'death.',
#   'pass,',
#   'hold\r\nhis',
#   'Him.',
#   'the',
#   'do',
#   'God.',
#   'see',
#   'see',
#   'the',
#   'be\r\nthe',
#   'the',
#   'him,',
#   'this',
#   'seek',
#   'these',
#   'receive',
#   'return.',
#   'them',
#   'them,',
#   'him,',
#   'this',
#   'the',
#   'pass,',
#   'them.',
#   'them,\r\nWhy',
#   'Jesus,',
#   'rejoice',
#   'Him,',
#   'thy',
#   'cast',
#   'them,',
#   'destroy',
#   'hear',
#   'Him,',
#   'them,',
#   'them,',
#   'husbandmen,',
#   'get',
#   'them?',
#   'powder.',
#   'lay',
#   'the',
#   'give',
#   'them,',
#   'Caesar',
#   'God',
#   'hold',
#   'Him',
#   'his',
#   'them,',
#   'the',
#   'my',
#   'His',
#   'walk',
#   'His',
#   'pass?',
#   'pass.',
#   'the',
#   'meditate',
#   'refute',
#   'be',
#   'death.',
#   'the',
#   'come',
#   'pass,',
#   'you,\r\nThis',
#   'escape',
#   'pass,',
#   'stand',
#   'hear',
#   'betray',
#   'them.',
#   'give',
#   'betray',
#   'Him,',
#   'go',
#   'thee,',
#   'them.',
#   'sharing',
#   'that',
#   'enquire',
#   'me,',
#   'have',
#   'go',
#   'death.',
#   'them,',
#   'you,',
#   'Him,',
#   'them,',
#   'them,',
#   'strengthen',
#   'His',
#   'them,\r\nWhy',
#   'Jesus',
#   'him,',
#   'happen,',
#   'Him,\r\n\r\nLord,',
#   'the',
#   'him,',
#   'them,',
#   'Pilate.',
#   'Caesar,',
#   'the',
#   'this\r\nplace.',
#   "Herod's\r\njurisdiction,",
#   'Herod,',
#   'see\r\nHim',
#   'see',
#   'Pilate.',
#   'them,',
#   'me',
#   'us.',
#   'release',
#   'them.',
#   'them',
#   'put',
#   'death.',
#   'them',
#   'them.',
#   'carry\r\nfor',
#   'them\r\nand',
#   'the',
#   'the',
#   'be',
#   'death.',
#   'the',
#   'Him',
#   'Him,',
#   'him,',
#   'this',
#   'Pilate',
#   'begin.',
#   'the\r\ncommandment.',
#   'the',
#   'them,',
#   'you',
#   'the\r\neleven,',
#   'all',
#   'the',
#   'the',
#   'a',
#   'them,',
#   'Him,',
#   'them,',
#   'be',
#   'death',
#   'the',
#   'the',
#   'them,',
#   'believe',
#   'them',
#   'eachother,',
#   'us?',
#   'Jerusalem.',
#   'Simon.',
#   'them',
#   'you.',
#   'them,',
#   'them,',
#   'you',
#   'them,',
#   'these',
#   'Jerusalem'],
#  'us': ['a',
#   'in',
#   'to',
#   'go',
#   'alone;',
#   'go',
#   'to',
#   'make',
#   'is',
#   'through',
#   'to',
#   'not',
#   'from',
#   'also.\r\nJesus',
#   'eat',
#   'to',
#   'that',
#   'by',
#   'for',
#   'kill',
#   'to',
#   'to',
#   'went',
#   'along'],
#  'a': ['declaration',
#   'priest',
#   'son',
#   'people',
#   'vision',
#   'city',
#   'virgin',
#   'son,',
#   'man?\r\nThe',
#   'son',
#   'city',
#   'demonstration',
#   'son.',
#   'writing\r\ntable,',
#   'horn',
#   'manger.',
#   'heavenly',
#   'manger.',
#   'pair',
#   'man',
#   'just',
#   'light',
#   'sign\r\nwhich',
#   'prophetess',
#   'fire\r\nwhose',
#   'bodily',
#   'dove,',
#   'high',
#   'moment',
#   'pinnacle',
#   'stone.',
#   'city',
#   'woman',
#   'widow.',
#   'man',
#   'spirit',
#   'loud',
#   'serious',
#   'desert',
#   'little',
#   'great',
#   'sinful',
#   'certain',
#   'man,',
#   'testimony',
#   'bed',
#   'man',
#   'palsy.',
#   'way',
#   'way',
#   'publican',
#   'great',
#   'large',
#   'physician;',
#   'parable',
#   'piece',
#   'new',
#   'rent,',
#   'man',
#   'mountain',
#   'great',
#   'parable',
#   'good',
#   'corrupt',
#   'bramble',
#   'man',
#   'house',
#   'deep',
#   'rock.',
#   'man',
#   'foundation',
#   'house',
#   'worthy',
#   'word,',
#   'man',
#   'city',
#   'dead\r\nman',
#   'widow',
#   'fear',
#   'prophet.',
#   'greater',
#   'devil.',
#   'gluttonous',
#   'winebibber,',
#   'woman',
#   'prophet,',
#   'sinner.',
#   'creditor',
#   'hundredfold.',
#   'while',
#   'candle,',
#   'vessel,',
#   'bed.',
#   'candlestick',
#   'ship',
#   'windstorm',
#   'man',
#   'long',
#   'loud',
#   'herd',
#   'steep',
#   'man',
#   'ruler',
#   'messenger',
#   'testimony',
#   'private',
#   'man',
#   'mountain',
#   'cloud',
#   'voice',
#   'discussion',
#   'village',
#   'way\r\nfor',
#   'man',
#   'lawyer',
#   'priest',
#   'Levite\r\ncame',
#   'Samaritan',
#   'neighbor',
#   'village',
#   'woman',
#   'sister,',
#   'friend,',
#   'stone?',
#   'serpent',
#   'fish?',
#   'scorpion?',
#   'devil',
#   'man',
#   'sign',
#   'house',
#   'house\r\nfalls.',
#   'strong',
#   'man',
#   'man,',
#   'woman',
#   'sign',
#   'sign',
#   'lighted',
#   'secret',
#   'candlestick',
#   'candle,',
#   'Pharisee',
#   'finger',
#   'word\r\nagainst',
#   'judge',
#   'divider\r\nover',
#   'parable',
#   'rich',
#   'plentiful',
#   'doubtful',
#   'treasure',
#   'servant',
#   'day',
#   'baptism',
#   'cloud',
#   'fig',
#   'woman,',
#   'daughter',
#   'grain',
#   'garden.',
#   'great',
#   'few',
#   'while,',
#   'follower',
#   'few',
#   'prophet',
#   'hen',
#   'pit',
#   'parable.',
#   'wedding,',
#   'dinner',
#   'supper,',
#   'feast,',
#   'great',
#   'tower,',
#   'great',
#   'hundred',
#   'candle,',
#   'far',
#   'mighty',
#   "countryman's",
#   'great',
#   'ring',
#   'fatted',
#   'rich',
#   'steward',
#   'woman',
#   'rich',
#   'poor',
#   'millstone',
#   'day,',
#   'grain',
#   'village,\r\nten',
#   'distance,',
#   'Samaritan,',
#   'loud',
#   'bed;\r\none',
#   'certain',
#   'publican.',
#   'week',
#   'sinner.',
#   'little',
#   'camel',
#   "needle's",
#   'rich',
#   'great',
#   'blind',
#   'man',
#   'sinner.',
#   'son',
#   'parable,',
#   'great',
#   'kingdom,',
#   'message',
#   'cloth',
#   'hard\r\nman.',
#   'hard',
#   'colt',
#   'loud\r\nvoice',
#   'trench',
#   'den',
#   'way',
#   'parable.',
#   'vineyard,',
#   'far',
#   'long',
#   'servant',
#   'third\r\nservant.',
#   'wife,\r\nand',
#   'wife',
#   'wife\r\nand',
#   'wife.',
#   'God',
#   'show,',
#   'poor',
#   'testimony.',
#   'hair',
#   'cloud',
#   'parable.',
#   'snare,',
#   'promise',
#   'man,',
#   'pitcher\r\nof',
#   'large',
#   'cup,',
#   'cup,',
#   'strife',
#   'kingdom,',
#   'purse',
#   'certain',
#   "stone's",
#   'crowd',
#   'kiss?',
#   'thief',
#   'fire',
#   'little',
#   'truth,',
#   'Galilaean.',
#   'king.',
#   'long',
#   'gorgeous',
#   'man',
#   'Cyrenian,\r\nwho',
#   'sign\r\nwritten',
#   'darkness',
#   'loud',
#   'righteous',
#   'just',
#   'member',
#   'new',
#   'village',
#   'stranger',
#   'prophet',
#   'spirit.',
#   'spirit\r\ndoes',
#   'piece',
#   'piece'],
#  'declaration': ['of'],
#  'those': ['things',
#   'things',
#   'of',
#   'who',
#   'who',
#   'who',
#   'who',
#   'days,',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'from',
#   'who',
#   'who',
#   'that',
#   'who',
#   'who',
#   'who',
#   'with',
#   'with',
#   'things',
#   'at',
#   'who',
#   'who',
#   'who\r\nkill',
#   'things',
#   'present',
#   'days,',
#   'who\r\nare',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'out',
#   'things',
#   'things',
#   'who\r\nwere',
#   'who'],
#  'things': ['which',
#   'from',
#   'thou',
#   'are',
#   'which',
#   'to',
#   'and',
#   'that',
#   'which',
#   'today.',
#   'I',
#   'I',
#   'God',
#   'Jesus\r\nhad',
#   'which',
#   'as',
#   'from\r\nthe',
#   'are',
#   'that',
#   'ye',
#   'ye',
# ...
#  'parents': ['brought', 'went', 'saw', 'were'],
#  'the\r\nchild': ['Jesus,'],
#  'Simeon': ['took'],
#  'took': ['Him',
#   'Him',
#   'the',
#   'her',
#   'the',
#   'Peter,',
#   'a\r\nchild,',
#   'care',
#   'out',
#   'the',
#   'her',
#   'her;',
#   'a',
#   'bread,',
#   'a',
#   'Him,',
#   'His',
#   'the',
#   'bread,',
#   'it'],
#  'arms,': ['blessed'],
#  'said,\r\nLord,': ['now'],
#  'let': ['thy',
#   'him',
#   'him\r\ndo',
#   'down',
#   'him',
#   'me',
#   'him',
#   'them',
#   'him',
#   'me',
#   'it',
#   'him\r\nhear.',
#   'it',
#   'those',
#   'those',
#   'him',
#   'him',
#   'him',
#   'me'],
#  'depart': ['in', 'from', 'from'],
#  'peace,': ['according', 'and', 'he'],
#  'word,': ['for\r\nmy', 'I', 'and'],
#  'for\r\nmy': ['eyes'],
#  'eyes': ['have', 'of', 'to', 'to\r\nheaven,', 'were', 'were'],
#  'the\r\nface': ['of'],
#  'people;': ['a'],
#  'lighten': ['the'],
#  'Gentiles,': ['and', 'and'],
#  'glory': ['of\r\nthy', 'of', 'and'],
#  'spoken': ['of', 'against.', 'in', 'this'],
#  'Him.\r\nSimeon': ['blessed'],
#  'mother,': ['Mary,', 'and'],
#  'child\r\nis': ['set'],
#  'set': ['for', 'Him', 'at', 'under', 'the', 'His', 'before', 'the'],
#  'fall': ['and', 'into', 'away.', 'into\r\ntemptation;', 'into', 'on', 'by'],
#  'rising': ['again'],
#  'again': ['of', 'to', 'he', 'until'],
#  'sign\r\nwhich': ['will'],
#  'against.': ['A'],
#  'sword': ['shall'],
#  'pierce': ['thy'],
#  'the\r\nthoughts': ['of'],
#  'may': ['be',
#   'know',
#   'see',
#   'go',
#   'see',
#   'be\r\nrequired',
#   'come',
#   'be',
#   'no',
#   'receive',
#   'be',
#   'eat.',
#   'eat',
#   'sift'],
#  'revealed.': ['Then', 'On\r\nthat'],
#  'prophetess': ['also'],
#  'Him.': ['Anna',
#   'After',
#   'A\r\nvoice',
#   'Jesus',
#   'He',
#   'When',
#   'It',
#   'Jesus\r\nwithdrew',
#   'Levi',
#   'Jesus',
#   'When',
#   'She',
#   'A',
#   'When',
#   'He',
#   'Jesus\r\ncommanded',
#   'But',
#   'There',
#   'A',
#   'When',
#   'Jesus\r\nreceived',
#   'Later,',
#   'When',
#   'He',
#   'But',
#   'Jesus',
#   '12',
#   'Then',
#   'Jesus',
#   'Standing',
#   'Jesus',
#   'Then\r\nJesus',
#   'Zacchaeus',
#   '20',
#   'Then',
#   '22',
#   'Then',
#   'At',
#   'But',
#   'Peter',
#   'and',
#   'Herod\r\nhoped',
#   'Then',
#   'Herod',
#   'They',
#   '(For',
#   'Jesus\r\nsaid',
#   'Then'],
#  'Anna': ['was'],
#  'daughter': ['of', 'is', 'against', 'in', 'in', 'of'],
#  'Phanuel,\r\nof': ['the'],
#  'tribe': ['of'],
#  'Aser.': ['She'],
#  'aged': ['widow'],
#  'widow': ['who,', 'and\r\nmany', 'in', 'casting', 'has'],
#  'who,': ['for', 'when', 'when', 'after', 'when', 'for'],
#  'fourscore': ['and\r\nfour'],
#  'and\r\nfour': ['years,'],
#  'years,': ['did', 'had'],
#  'did': ['not',
#   'not',
#   'not',
#   'so,',
#   'I',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'with',
#   'what',
#   'not',
#   'you\r\nnot',
#   'you',
#   'you',
#   'Herod',
#   'not',
#   'not',
#   'not'],
#  'leave': ['the', 'that', 'there', 'the', 'in'],
#  'served': ['God', 'thee.'],
#  'fasting': ['and\r\nprayer'],
#  'and\r\nprayer': ['night'],
#  'night': ['and', 'in', 'there', 'to', 'He'],
#  'day.': ['She', 'Then', 'The', 'A', 'Lying', 'But'],
#  'gave': ['thanks',
#   'it',
#   'me',
#   'me',
#   'them\r\npower',
#   'them',
#   'it',
#   'him',
#   'his',
#   'her',
#   'a',
#   'thanks,',
#   'thanks,',
#   'it',
#   'sentence\r\nthat',
#   'it',
#   'Him'],
#  'thanks': ['to', 'have', 'have', 'to'],
#  'to\r\nthose': ['in'],
#  'awaited': ['redemption.'],
#  'redemption.': ['When'],
#  'required': ['according', 'of', 'of'],
#  'of\r\nthe': ['Lord,', 'prophets', 'hall'],
#  'returned': ['to',
#   'from',
#   'to',
#   'it,',
#   'and',
#   'and',
#   'with',
#   'and',
#   'and',
#   'and',
#   'home\r\nbeating',
#   'and',
#   'to',
#   'to'],
#  'Galilee.': ['The\r\nchild', '5', 'As'],
#  'The\r\nchild': ['grew,'],
#  'grew,': ['became'],
#  'spirit,': ['and', 'and'],
#  'and\r\nthe': ['grace', 'Holy', 'only', 'elders', 'people,'],
#  'grace': ['of'],
#  'year': ['His', 'of', 'of', 'also,'],
#  'feast': ['of', 'in\r\nhis', 'of'],
#  'passover.\r\nWhen': ['He'],
#  'twelve': ['years',
#   'whom',
#   'years',
#   'years',
#   'disciples',
#   'came',
#   'baskets\r\nof',
#   'aside',
#   'apostles.'],
#  'years': ['old,', 'of', 'and', 'of\r\nage,', 'and', 'I', 'I\r\nhave'],
#  'old,': ['they'],
#  'the\r\ncustom': ['of'],
#  'feast.': ['When'],
#  'days,': ['they', 'they', 'Jesus', 'therefore,'],
#  'returned,\r\nbut': ['the'],
#  'behind': ['in', 'me,', 'Him'],
#  'Jerusalem.': ['Joseph', 'Pharisees', 'Peter', 'He', 'They', 'They', 'You'],
#  'mother\r\ndid': ['not'],
#  'it.': ['Supposing',
#   'If',
#   'When',
#   'Other',
#   'Now',
#   'Whoever',
#   'The',
#   'If',
#   'Far',
#   'In',
#   'Then'],
#  'Supposing': ['Him'],
#  'caravan,': ['at'],
#  'the\r\nend': ['of'],
#  'first': ["day's",
#   'cast',
#   'to',
#   'go\r\nbid',
#   'say,',
#   'washed',
#   'shall',
#   'said,',
#   'sit',
#   'said,',
#   'you',
#   'man,\r\nfor',
#   'day'],
#  "day's": ['journey,'],
#  'journey,': ['they', 'neither'],
#  'sought': ['Him', 'me?', 'to', 'to', 'how'],
#  'kinsfolk\r\nand': ['acquaintances.'],
#  'acquaintances.': ['When'],
#  'Him,': ['they',
#   'they',
#   'they',
#   'Master,',
#   'Why',
#   'and',
#   'beseeching',
#   'I',
#   'even',
#   'What',
#   'Thy',
#   'and',
#   'she',
#   'and',
#   'Send\r\nthe',
#   'Peter,',
#   'saying,',
#   'Blessed',
#   'Lord,',
#   'and',
#   'Get',
#   'though',
#   'Good',
#   'glorifying',
#   'Master,\r\nrebuke',
#   'but',
#   'Tell',
#   'Master,',
#   'Master,',
#   'Where',
#   'Lord,',
#   'and',
#   'saying,',
#   'and',
#   'they',
#   'saying,',
#   'Art',
#   'nor',
#   'crucify\r\nHim.',
#   'saying,',
#   'coming',
#   'they',
#   'If',
#   'Are\r\nyou'],
#  'turned': ['back',
#   'around',
#   'and',
#   'to',
#   'and',
#   'to',
#   'into',
#   'back,\r\nand',
#   'and',
#   'Jesus',
#   'to'],
#  'back': ['toward\r\nJerusalem', 'to', 'with', 'to', 'and'],
#  'toward\r\nJerusalem': ['to'],
#  'After': ['three', 'these', 'this', 'Jesus', 'he', 'he'],
#  'sitting': ['in', 'at', 'in\r\nthe', 'in', 'at'],
#  'the\r\nmidst': ['of'],
#  'doctors,': ['listening'],
#  'listening': ['to'],
#  'questions.\r\nThose': ['who'],
#  'astonished': ['at', 'at', 'at', 'us.'],
#  'answers.': ['When'],
#  'amazed.': ['His'],
#  'Him,\r\nSon,': ['why'],
#  'why': ['has', 'I', 'behold', 'call', 'take\r\nthought', 'do', 'have', 'do'],
#  'us?': ['Thy', 'I', 'They'],
#  'father': ['and',
#   'and',
#   'shall',
#   'gave\r\nhim',
#   'saw',
#   'said',
#   'has\r\nkilled',
#   'came',
#   'said',
#   'Abraham.',
#   'and'],
#  'very\r\nworried.': ['He'],
#  'ye': ['sought',
#   'may',
#   'eat',
#   'make',
#   'do',
#   'not',
#   'love',
#   'do',
#   'expect',
#   'shall',
#   'shall',
#   'shall',
#   'have',
#   'out',
#   'out\r\nto',
#   'out',
#   'have',
#   'have',
#   'say,',
#   'say,',
#   'hear:',
#   'enter,',
#   'leave',
#   'them',
#   'are',
#   'enter,',
#   'enter,',
#   'enter',
#   'sure',
#   'see.',
#   'see',
#   'hear',
#   'pray,',
#   'lawyers!',
#   'have',
#   'have',
#   'shall',
#   'shall\r\nsay.',
#   'shall',
#   'shall',
#   'of',
#   'shall',
#   'have',
#   'see',
#   'say,',
#   'see',
#   'say,',
#   'can',
#   'do',
#   'shall',
#   'see',
#   'would',
#   'say,',
#   'have',
#   'hear',
#   'shall',
#   'shall',
#   'see',
#   'see'],
#  'Do': ['you',
#   'violence',
#   'good',
#   'to',
#   'this,',
#   'not',
#   'this',
#   'not',
#   'you',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'this'],
#  'I\r\nmust': ['be'],
#  "Father's": ['business?', 'good'],
#  'business?': ['But'],
#  'understand': ['what\r\nHe'],
#  'what\r\nHe': ['said'],
#  'obedient\r\nto': ['them;'],
#  'them;': ['but', 'and', 'and\r\nthey'],
#  'but': ['His',
#   'one\r\nmightier',
#   'He',
#   'by',
#   'to',
#   'God',
#   'they\r\nthat',
#   'to',
#   'your\r\ndisciples',
#   'everyone',
#   'not',
#   'to',
#   'in',
#   'could',
#   'lived',
#   'he\r\nbroke',
#   'sleeps.',
#   'He',
#   'some',
#   'they',
#   'to',
#   'you',
#   'let',
#   'the',
#   'rejoice',
#   'the',
#   'the',
#   'deliver',
#   'can',
#   'it',
#   'no',
#   'prevented',
#   'did',
#   'He',
#   'was',
#   'if',
#   'make',
#   'he',
#   'woe',
#   'you',
#   'struck',
#   'not',
#   'ye',
#   'could',
#   'the',
#   'on',
#   'of',
#   'she,',
#   'my',
#   'woe',
#   'thine',
#   'He',
#   'weep',
#   'this',
#   'did',
#   'is'],
#  'kept': ['all', 'bound', 'burning.', 'from', 'tied'],
#  'increased': ['in\r\nwisdom,'],
#  'in\r\nwisdom,': ['in'],
#  'stature,': ['and'],
#  'favor': ['with', 'in'],
#  'man.': ['3',
#   'With',
#   'People',
#   'A',
#   'During',
#   'They',
#   'Release\r\nBarabbas',
#   'All'],
#  '3': [''],
#  'fifteenth': ['year'],
#  'Tiberius': ['Caesar.\r\nPontius'],
#  'Caesar.\r\nPontius': ['Pilate'],
#  'Pilate': ['was',
#   'mingled\r\nblood',
#   'asked',
#   'said',
#   'heard',
#   'and',
#   'said',
#   'therefore,',
#   'said',
#   'gave',
#   'and\r\nasked'],
#  'governor': ['of'],
#  'Judaea;': ['Herod'],
#  'Herod': ['was', 'had', 'heard', 'said,', 'saw', 'had', 'and', 'for'],
#  'tetrarch': ['of', 'of', 'of'],
#  'Galilee;\r\nand': ['his'],
#  'brother,': ['Philip,', 'was'],
#  'Philip,': ['was'],
#  'Ituraea': ['and'],
#  'region': ['of\r\nTrachonitis;'],
#  'of\r\nTrachonitis;': ['and'],
#  'Lysanias': ['was'],
#  'Abilene.': ['Annas'],
#  'Annas': ['and'],
#  'Caiaphas\r\nwere': ['the'],
#  'high': ['priests.', 'mountain', 'priest', "priest's"],
#  'priests.': ['The', 'And,'],
#  'John': ['the',
#   'said',
#   'on',
#   'was\r\nsaying,',
#   'imprisoned.',
#   'fast',
#   'told',
#   'sent',
#   'the\r\nthings',
#   'the',
#   'the',
#   'the',
#   'so',
#   'the',
#   'said,',
#   'taught',
#   'was'],
#  'the\r\nwilderness.': ['He'],
#  'around': ['Jordan,', 'at', 'and', 'it', 'and', 'his'],
#  'Jordan,': ['preaching'],
#  'preaching': ['the\r\nbaptism', 'the', 'of'],
#  'the\r\nbaptism': ['of'],
#  'repentance': ['for', 'for\r\nthe'],
#  'sins.': ['This'],
#  'to\r\nwhat': ['is'],
#  'book': ['of', 'of', 'of'],
#  'Esaias': ['the'],
#  'prophet:': ['The'],
#  'one\r\ncrying': ['in'],
#  'wilderness,': ['Prepare', 'and'],
#  'Prepare': ['the', 'everything'],
#  'paths\r\nstraight.': ['Every'],
#  'valley': ['shall'],
#  'filled,': ['and'],
#  'mountain': ['and', 'and', 'to', 'to'],
#  'hill\r\nshall': ['be'],
#  'low;': ['and'],
#  'crooked': ['shall'],
#  'straight,': ['and', 'and'],
#  'the\r\nrough': ['ways'],
#  'ways': ['shall', 'to\r\ntake'],
#  'smooth;': ['and'],
#  'flesh': ['shall', 'and'],
#  'salvation\r\nof': ['God.'],
#  'baptized': ['by', 'also', 'by', 'with;'],
#  'O\r\ngeneration': ['of'],
#  'vipers,': ['who'],
#  'warned': ['you'],
#  'flee': ['from', 'to'],
#  'wrath': ['to\r\ncome?', 'upon'],
#  'to\r\ncome?': ['Bring'],
#  'Bring': ['forth', 'thy', 'out'],
#  'fruits': ['worthy'],
#  'worthy': ['of',
#   'to\r\nunloose.',
#   'man',
#   'to',
#   'of',
#   'of',
#   'to',
#   'to',
#   'of',
#   'to'],
#  'repentance.': ['Stop', 'Then', 'What'],
#  'Stop': ['saying'],
#  'saying': ['to\r\nyourselves,', 'to', 'this', 'this,', 'to', 'that'],
#  'to\r\nyourselves,': ['We'],
#  'We': ['have', 'have', 'have', 'have', 'have', 'will', 'found', 'have'],
#  'Abraham:': ['for'],
#  'tell': ['you,',
#   'no',
#   'you',
#   'John',
#   'no',
#   'no',
#   'you,',
#   'you,',
#   'you,',
#   'you',
#   'my',
#   'you,',
#   'you,',
#   'you',
#   'you',
#   'you,',
#   'that',
#   'you',
#   'you,',
#   'you,',
#   'you,',
#   'where',
#   'you',
#   'you,',
#   'you,',
#   'you,',
#   'you,'],
#  'able\r\nto': ['raise'],
#  'raise': ['up'],
#  'Abraham': ['from', 'far', 'said,', 'answered,', 'said'],
#  'stones.': ['Now'],
#  'Now': ['the', 'when', 'the', 'it', 'which', 'there', 'he', 'there'],
#  'axe': ['is'],
#  'laid\r\nto': ['the'],
#  'root': ['of', 'and\r\nplanted'],
#  'trees.': ['Every'],
#  'tree': ['which', 'does', 'is', 'planted', 'and', 'that', 'and'],
#  'good\r\nfruit': ['is'],
#  'hewn': ['down', 'in'],
#  'cast': ['into',
#   'thyself',
#   'Him',
#   'out',
#   'away?',
#   'him',
#   'out',
#   'out',
#   'them',
#   'out',
#   'you',
#   'into',
#   'him',
#   'thee',
#   'into',
#   'out\r\ndevils',
#   'it',
#   'into\r\nthe',
#   'their',
#   'a',
#   'out',
#   'him',
#   'him',
#   'their',
#   'in',
#   'in'],
#  'fire.': ['The'],
#  'What': ['shall',
#   'shall',
#   'words',
#   'went',
#   'went',
#   'might',
#   'kind\r\nof',
#   'have',
#   'is\r\nthy',
#   'is',
#   'shall',
#   'man',
#   'woman,',
#   'do',
#   'shall',
#   'is',
#   'need',
#   'were',
#   'things?'],
#  'do?': ['He', 'He', 'I\r\nhave', 'Likewise,', 'I'],
#  'two\r\ncoats,': ['let'],
#  'none.': ['He', 'Then', 'He', 'Cut'],
#  'food,': ['let'],
#  'him\r\ndo': ['likewise.'],
#  'likewise.': ['The', 'Later'],
#  'publicans': ['who', 'and', 'and', 'and', 'and\r\nsinners'],
#  'asked,\r\nMaster,': ['what'],
#  'Exact': ['no'],
#  'more': ['than',
#   'abroad.',
#   'laborers',
#   'tolerable',
#   'tolerable',
#   'you',
#   'shall',
#   'they',
#   'value',
#   'than',
#   'will',
#   'about',
#   'will',
#   'honorable',
#   'joy',
#   'shall',
#   'questions.',
#   'than',
#   'earnestly,',
#   'of'],
#  'than': ['that\r\nwhich',
#   'I',
#   'a',
#   'he.',
#   'five',
#   'for',
#   'for',
#   'he',
#   'himself.',
#   'the',
#   'Solomon',
#   'Jonas',
#   'many',
#   'raiment.',
#   'the',
#   'you',
#   'over',
#   'the',
#   'for',
#   'to',
#   'all'],
#  'that\r\nwhich': ['is', 'is'],
#  'appointed': ['you.', 'seventy', 'to'],
#  'you.': ['The',
#   'Pray',
#   'If',
#   'Remain',
#   'Heal',
#   'But,',
#   'But',
#   'And\r\nCapernaum,',
#   'However,',
#   'For',
#   'When',
#   'But',
#   'Fear',
#   'Yet,',
#   'Who',
#   'Then',
#   'Do',
#   'But,',
#   'But',
#   'Stay'],
#  'soldiers,': ['likewise,'],
#  'likewise,': ['asked,', 'a', 'any', 'the', 'when', 'his'],
#  'asked,': ['What', 'Who'],
#  'we\r\ndo?': ['He'],
#  'violence': ['to'],
#  'man,': ['do',
#   'O',
#   'full',
#   'having',
#   'Stretch\r\nforth',
#   'out',
#   'out',
#   'and',
#   'when',
#   'having',
#   'he',
#   'it',
#   'but',
#   'What',
#   'taking',
#   'bearing'],
#  'do': ['not',
#   'also',
#   'not',
#   'the',
#   'ye',
#   'that',
#   'good,',
#   'evil?',
#   'to\r\nJesus.',
#   'not\r\nask',
#   'to',
#   'good',
#   'good',
#   'even',
#   'good,',
#   'not',
#   'they',
#   'the',
#   'the',
#   'not',
#   'we',
#   'it.',
#   'with',
#   'the',
#   'you',
#   'not',
#   'not',
#   'you',
#   'thou',
#   'you',
#   'your',
#   'not',
#   'not',
#   'that',
#   'all',
#   'not',
#   'not',
#   'you',
#   'you',
#   'not',
#   'not',
#   'cures',
#   'so',
#   'you',
#   'you',
#   'good',
#   'not',
#   'to',
#   'you',
#   'you',
#   'for',
#   'you',
#   'these',
#   'I',
#   'to',
#   'not',
#   'not',
#   'you',
#   'this',
#   'not',
#   'you',
#   'you',
#   'not',
#   'doubts'],
#  'accuse': ['anyone', 'Him,'],
#  'anyone': ['falsely;'],
#  'falsely;': ['and\r\nbe'],
#  'and\r\nbe': ['content'],
#  'content': ['with'],
#  'your': ['wages.',
#   'ears.',
#   'nets.',
#   'home.',
#   'name',
#   'enemies.',
#   'cloak',
#   'coat\r\nalso.',
#   'goods',
#   'enemies,',
#   'reward',
#   'Father',
#   'bosom.',
#   'brother,\r\nBrother,',
#   'own',
#   'house,',
#   'house,',
#   'faith?',
#   'journey,',
#   'ears:',
#   'way.',
#   'peace',
#   'names',
#   'circumstances,',
#   'son',
#   'children,\r\nhow',
#   'heavenly',
#   'sons',
#   'eye',
#   'eye',
#   'body\r\nis',
#   'fathers',
#   'fathers,\r\nfor',
#   'head',
#   'life,\r\nwhat',
#   "Father's",
#   'heart',
#   'loins',
#   'lights',
#   'adversary',
#   'house',
#   'friends,',
#   'brethren,',
#   'bill',
#   'bill',
#   'own?',
#   'hearts.',
#   'good',
#   'lifetime',
#   'servant',
#   'clothes;',
#   'house.\r\nHe',
#   'talent',
#   'eyes.',
#   'enemies',
#   'footstool.',
#   'hearts',
#   'patience',
#   'souls,',
#   'heads;',
#   'redemption',
#   'hearts',
#   'hands',
#   'children.',
#   'kingdom.'],
#  'wages.': ['People'],
#  'People': ['lived', 'ate', 'came'],
#  'lived': ['in', 'in', 'in'],
#  'expectation': ['and'],
#  'whether': ['he', 'it', 'He', 'you', 'he', 'the'],
#  'Christ.\r\nJohn': ['answered'],
#  'answered': ['by',
#   'and\r\nsaid',
#   'and',
#   'and\r\nsaid,',
#   'right.',
#   'this',
#   'and',
#   'nothing.'],
#  'all,': ['I', 'rose', 'and'],
#  'baptize': ['you', 'you'],
#  'water;': ['but'],
#  'one\r\nmightier': ['than'],
#  'comes,': ['the', 'He', 'shall', 'shall'],
#  'latchet': ['of'],
#  'whose': ['shoes', 'right', 'servant', 'wife', 'name'],
#  'shoes': ['I', 'on'],
#  'to\r\nunloose.': ['He'],
#  'fire\r\nwhose': ['fan'],
#  'fan': ['is'],
#  'hand.': ['He', 'As', 'So,', 'I'],
#  'thoroughly': ['purge'],
#  'purge': ['His'],
#  'floor.': ['He'],
#  'will\r\ngather': ['the'],
#  'wheat': ['into'],
#  'garner;': ['but'],
#  'chaff': ['with'],
#  'fire\r\nunquenchable.': ['Herod,'],
#  'tetrarch,': ['had', 'heard'],
#  'reproved': ['by'],
#  'account': ['of', 'of'],
#  'Herodias,\r\nhis': ['brother'],
#  'brother': ["Philip's", 'of', 'to', 'is', 'trespasses', 'dies,', 'should'],
#  "Philip's": ['wife'],
#  'evils': ['which'],
#  'done.\r\nHerod': ['held'],
#  'held': ['this', 'their', 'their\r\npeace,', 'Jesus'],
#  'against': ['him.',
#   'a',
#   'His',
#   'Him.',
#   'them.',
#   'us',
#   'you',
#   'a',
#   'himself,',
#   'me,',
#   'Him.',
#   'the',
#   'two,',
#   'three.',
#   'the',
#   'the',
#   'her\r\nmother',
#   'another',
#   'him',
#   'heaven,',
#   'thee,',
#   'you',
#   'nation,',
#   'a',
#   'me?'],
#  'Then,': ['when', 'wanting', 'likewise,', 'before', 'as'],
#  ...}

# %%
generate_sentence(luke_dict)
# Out:
# 'Espoused wife, Elisabeth, conceived, and he asks\r\nfor an account of the body, they were amazed.'

# %%
#considering we're basing this off of KJV this isn't that bad
